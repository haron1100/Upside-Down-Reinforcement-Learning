# %% [markdown]
# ### This file is for testing radical changes to the codebase. Upside Down Reinforcement Learning.py is the working version.

# %%
import gym
env = gym.make('LunarLander-v2')

# %%
#command takes form [derired reward, desired horizon]
import numpy as np
def random_policy(obs, command):
    return np.random.randint(env.action_space.n)

# %%
import time
from copy import deepcopy
#Visualise agent function
def visualise_agent(policy, command, n=5):
    try:
        for trial_i in range(n):
            current_command = deepcopy(command)
            observation = env.reset()
            done=False
            t=0
            episode_return=0
            while not done:
                env.render()
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                observation, reward, done, info = env.step(action)
                episode_return+=reward
                current_command[0]-= reward
                current_command[1] = max(1, current_command[1]-1)
                t+=1
            env.render()
            time.sleep(1.5)
            print("Episode {} finished after {} timesteps. Return = {}".format(trial_i, t, episode_return))
        env.close()
    except KeyboardInterrupt:
        env.close()

# %%
#visualise_agent(random_policy, command=[500, 500], 1)

# %%
import torch
import torch.nn.functional as F

class FCNN_AGENT(torch.nn.Module):
    def __init__(self, command_scale):
        super().__init__()
        hidden_size=64
        self.command_scale=command_scale
        self.observation_embedding = torch.nn.Sequential(
            torch.nn.Linear(np.prod(env.observation_space.shape), hidden_size),
            torch.nn.Sigmoid()
        )
        self.command_embedding = torch.nn.Sequential(
            torch.nn.Linear(2, hidden_size),
            torch.nn.Sigmoid()
        )
        self.to_output = torch.nn.Sequential(
            torch.nn.Linear(hidden_size, hidden_size),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_size, env.action_space.n)
        )
    
    def forward(self, observation, command):
        obs_emebdding = self.observation_embedding(observation)
        cmd_embedding = self.command_embedding(command*self.command_scale)
        embedding = torch.mul(obs_emebdding, cmd_embedding)
        action_prob_logits = self.to_output(embedding)
        return action_prob_logits
    
    def create_optimizer(self, lr):
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)

# %%
from copy import deepcopy
def collect_experience(policy, replay_buffer, replay_size, last_few, n_episodes=100, log_to_tensorboard=True):
    global i_episode
    init_replay_buffer = deepcopy(replay_buffer)
    try:
        for _ in range(n_episodes):
            command = sample_command(init_replay_buffer, last_few)
            writer.add_scalar('Command desired reward/Episode', command[0], i_episode)    # write loss to a graph
            writer.add_scalar('Command horizon/Episode', command[1], i_episode)    # write loss to a graph
            observation = env.reset()
            episode_mem = {'observation':[],
                           'action':[],
                           'reward':[],}
            done=False
            while not done:
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                
                observation=new_observation
                command[0]-= reward
                command[1] = max(1, command[1]-1)
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            replay_buffer.append(episode_mem)
            i_episode+=1
            if log_to_tensorboard: writer.add_scalar('Return/Episode', sum(episode_mem['reward']), i_episode)    # write loss to a graph
            print("Episode {} finished after {} timesteps. Return = {}".format(i_episode, len(episode_mem['observation']), sum(episode_mem['reward'])))
        env.close()
    except KeyboardInterrupt:
        env.close()
    replay_buffer = sorted(replay_buffer, key=lambda x:x['return'])[-replay_size:]
    return replay_buffer

def sample_command(replay_buffer, last_few):
    if len(replay_buffer)==0:
        return [1, 1]
    else:
        command_samples = replay_buffer[-last_few:]
        lengths = [mem['episode_len'] for mem in command_samples]
        returns = [mem['return'] for mem in command_samples]
        mean_return, std_return = np.mean(returns), np.std(returns)
        command_horizon = np.mean(lengths)
        desired_reward = np.random.uniform(mean_return, mean_return+std_return)
        return [desired_reward, command_horizon]

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64, log_to_tensorboard=True):
    global i_updates
    all_costs = []
    for i in range(n_updates):
        batch_observations = np.zeros((batch_size, np.prod(env.observation_space.shape)))
        batch_commands = np.zeros((batch_size, 2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
            sample_t2 = len(replay_buffer[sample_episode]['observation'])
            ##sample_t2 = np.random.randint(sample_t1+1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_horizon = sample_t2-sample_t1
            sample_mem = replay_buffer[sample_episode]['observation'][sample_t1]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_t1:sample_t2])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_t1]
            batch_observations[b] = sample_mem
            batch_commands[b] = [sample_desired_reward, sample_horizon]
            batch_label[b] = label
        batch_observations = torch.tensor(batch_observations).double()
        batch_commands = torch.tensor(batch_commands).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_observations, batch_commands)
        cost = F.cross_entropy(pred, batch_label)
        if log_to_tensorboard: writer.add_scalar('Cost/NN update', cost.item() , i_updates)    # write loss to a graph
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
        i_updates+=1
    return np.mean(all_costs)

# %%
def create_greedy_policy(policy_network):
    def policy(obs, command):
        action_logits = policy_network(obs, command)
        action_probs = F.softmax(action_logits, dim=-1)
        action = np.argmax(action_probs.detach().numpy())
        return action
    return policy

def create_stochastic_policy(policy_network):
    def policy(obs, command):
        action_logits = policy_network(obs, command)
        action_probs = F.softmax(action_logits, dim=-1)
        action = torch.distributions.Categorical(action_probs).sample().item()
        return action
    return policy

# %%
i_episode=0
i_updates=0 #number of parameter updates to the neural network
replay_buffer = []
log_to_tensorboard = True 

replay_size = 700
last_few = 50
batch_size = 256
n_warm_up_episodes = 50
n_episodes_per_iter = 25
n_updates_per_iter = 150
command_scale = 0.02
lr = 0.001

agent = FCNN_AGENT(command_scale).double()
agent.create_optimizer(lr)

stochastic_policy = create_stochastic_policy(agent)
greedy_policy = create_greedy_policy(agent)

# %%
# SET UP TRAINING VISUALISATION
# SET UP TRAINING VISUALISATION
if log_to_tensorboard: from torch.utils.tensorboard import SummaryWriter
if log_to_tensorboard: writer = SummaryWriter() # we will use this to show our models performance on a graph using tensorboard

# %%
#Collect warm up episodes
replay_buffer = collect_experience(random_policy, replay_buffer, replay_size, last_few, n_warm_up_episodes, log_to_tensorboard)
train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
# Out:
# Episode 1 finished after 87 timesteps. Return = -95.47832481120317
# Episode 2 finished after 90 timesteps. Return = -308.23957663490256
# Episode 3 finished after 125 timesteps. Return = -273.56608353239596
# Episode 4 finished after 143 timesteps. Return = -122.86663265739914
# Episode 5 finished after 109 timesteps. Return = -132.6634608656605
# Episode 6 finished after 65 timesteps. Return = -92.29343003244614
# Episode 7 finished after 101 timesteps. Return = -103.48110808986972
# Episode 8 finished after 81 timesteps. Return = -305.7735218283285
# Episode 9 finished after 113 timesteps. Return = -296.6817198263583
# Episode 10 finished after 116 timesteps. Return = -113.86090220688554
# Episode 11 finished after 144 timesteps. Return = -207.7920988171057
# Episode 12 finished after 112 timesteps. Return = -125.24642596146685
# Episode 13 finished after 70 timesteps. Return = -99.61956186253272
# Episode 14 finished after 64 timesteps. Return = -64.96988286530956
# Episode 15 finished after 84 timesteps. Return = -294.6984468280157
# Episode 16 finished after 120 timesteps. Return = -263.87499172353864
# Episode 17 finished after 89 timesteps. Return = -220.43895866204932
# Episode 18 finished after 89 timesteps. Return = -194.54253830930787
# Episode 19 finished after 79 timesteps. Return = -122.20732574191125
# Episode 20 finished after 81 timesteps. Return = -99.35837362023702
# Episode 21 finished after 89 timesteps. Return = -142.55927337276535
# Episode 22 finished after 104 timesteps. Return = -121.44423171459204
# Episode 23 finished after 94 timesteps. Return = -370.1562363591147
# Episode 24 finished after 111 timesteps. Return = -239.69616542194987
# Episode 25 finished after 87 timesteps. Return = -119.05198886751452
# Episode 26 finished after 103 timesteps. Return = -312.80332141604924
# Episode 27 finished after 102 timesteps. Return = -446.56986781970613
# Episode 28 finished after 99 timesteps. Return = -328.5643540406837
# Episode 29 finished after 81 timesteps. Return = -132.4922228307742
# Episode 30 finished after 81 timesteps. Return = -375.44455577314227
# Episode 31 finished after 141 timesteps. Return = -227.48710903119908
# Episode 32 finished after 63 timesteps. Return = -84.26360793225075
# Episode 33 finished after 63 timesteps. Return = -58.534755497090785
# Episode 34 finished after 66 timesteps. Return = -101.85331687064595
# Episode 35 finished after 108 timesteps. Return = -356.6345521591801
# Episode 36 finished after 102 timesteps. Return = -124.01656152001658
# Episode 37 finished after 111 timesteps. Return = -191.34594805333947
# Episode 38 finished after 128 timesteps. Return = -49.958552310991834
# Episode 39 finished after 94 timesteps. Return = -136.05929996645673
# Episode 40 finished after 80 timesteps. Return = -128.0460930137403
# Episode 41 finished after 96 timesteps. Return = -446.53678438524753
# Episode 42 finished after 64 timesteps. Return = -96.17735860353189
# Episode 43 finished after 124 timesteps. Return = -103.20963556024698
# Episode 44 finished after 102 timesteps. Return = -127.38429400980725
# Episode 45 finished after 74 timesteps. Return = -92.5490177934468
# Episode 46 finished after 79 timesteps. Return = -249.31772719650783
# Episode 47 finished after 115 timesteps. Return = -334.8170573875248
# Episode 48 finished after 107 timesteps. Return = -359.1034929548945
# Episode 49 finished after 66 timesteps. Return = -79.76943027222745
# Episode 50 finished after 115 timesteps. Return = -325.04037352174066
# 1.386259598678298

# %%
n_iters = 1000
for i in range(n_iters):
    replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
    train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
# Out:
# Episode 51 finished after 82 timesteps. Return = -88.50429894304365
# Episode 52 finished after 99 timesteps. Return = -31.286976850922926
# Episode 53 finished after 60 timesteps. Return = -106.35597449901124
# Episode 54 finished after 121 timesteps. Return = -140.90086400630838
# Episode 55 finished after 83 timesteps. Return = -257.39099441858366
# Episode 56 finished after 122 timesteps. Return = -68.64573689433801
# Episode 57 finished after 114 timesteps. Return = -222.94524424918393
# Episode 58 finished after 111 timesteps. Return = -400.5598424644172
# Episode 59 finished after 61 timesteps. Return = -98.51600008178612
# Episode 60 finished after 125 timesteps. Return = -122.94159869312136
# Episode 61 finished after 66 timesteps. Return = -105.29468327867619
# Episode 62 finished after 100 timesteps. Return = -485.4342377708204
# Episode 63 finished after 86 timesteps. Return = -98.73458116870694
# Episode 64 finished after 86 timesteps. Return = -145.48005166040318
# Episode 65 finished after 93 timesteps. Return = -139.95768759295822
# Episode 66 finished after 77 timesteps. Return = -110.91095017461373
# Episode 67 finished after 73 timesteps. Return = -106.0313915960841
# Episode 68 finished after 117 timesteps. Return = -515.6275909768962
# Episode 69 finished after 101 timesteps. Return = -118.92927948239873
# Episode 70 finished after 67 timesteps. Return = -121.79181918175158
# Episode 71 finished after 101 timesteps. Return = -256.2288637646079
# Episode 72 finished after 64 timesteps. Return = -133.56864371118337
# Episode 73 finished after 97 timesteps. Return = -298.8677384893923
# Episode 74 finished after 66 timesteps. Return = -98.3315788567224
# Episode 75 finished after 113 timesteps. Return = -99.35492390261197
# Episode 76 finished after 128 timesteps. Return = -226.98187358708168
# Episode 77 finished after 97 timesteps. Return = -169.840941729967
# Episode 78 finished after 80 timesteps. Return = -158.42000536777977
# Episode 79 finished after 116 timesteps. Return = -157.2713655923879
# Episode 80 finished after 110 timesteps. Return = -236.46622932846645
# Episode 81 finished after 92 timesteps. Return = -58.22772081661618
# Episode 82 finished after 73 timesteps. Return = -220.60389679142483
# Episode 83 finished after 115 timesteps. Return = -95.66555986520929
# Episode 84 finished after 62 timesteps. Return = -200.26866905646446
# Episode 85 finished after 137 timesteps. Return = -148.96360664333923
# Episode 86 finished after 98 timesteps. Return = -161.84827100897883
# Episode 87 finished after 86 timesteps. Return = -127.37535940131167
# Episode 88 finished after 86 timesteps. Return = -118.28054836695374
# Episode 89 finished after 71 timesteps. Return = -116.11340574717563
# Episode 90 finished after 97 timesteps. Return = -184.06552897661578
# Episode 91 finished after 61 timesteps. Return = -244.9901194485895
# Episode 92 finished after 63 timesteps. Return = -106.72247901813189
# Episode 93 finished after 116 timesteps. Return = -78.31272537481743
# Episode 94 finished after 58 timesteps. Return = -149.65880447444508
# Episode 95 finished after 123 timesteps. Return = -33.24240579417416
# Episode 96 finished after 97 timesteps. Return = -249.84780884499483
# Episode 97 finished after 75 timesteps. Return = -162.56648605674536
# Episode 98 finished after 66 timesteps. Return = -98.13930120564545
# Episode 99 finished after 80 timesteps. Return = -198.82790854905744
# Episode 100 finished after 109 timesteps. Return = -240.86321164029303
# Episode 101 finished after 112 timesteps. Return = -120.04473302355001
# Episode 102 finished after 76 timesteps. Return = -93.87635284408111
# Episode 103 finished after 127 timesteps. Return = -180.14537265704394
# Episode 104 finished after 64 timesteps. Return = -82.51683858450895
# Episode 105 finished after 108 timesteps. Return = -24.085416099568747
# Episode 106 finished after 62 timesteps. Return = -93.18723301880448
# Episode 107 finished after 130 timesteps. Return = -508.6307310664937
# Episode 108 finished after 58 timesteps. Return = -73.2464092625188
# Episode 109 finished after 77 timesteps. Return = -204.44193698598946
# Episode 110 finished after 92 timesteps. Return = -129.51067833218065
# Episode 111 finished after 78 timesteps. Return = -141.00330122300352
# Episode 112 finished after 113 timesteps. Return = -270.6762384185596
# Episode 113 finished after 91 timesteps. Return = -171.18190157156974
# Episode 114 finished after 71 timesteps. Return = -108.6548901469244
# Episode 115 finished after 69 timesteps. Return = -76.44051158664362
# Episode 116 finished after 127 timesteps. Return = -230.8559432319217
# Episode 117 finished after 129 timesteps. Return = -357.26216393498
# Episode 118 finished after 118 timesteps. Return = -375.8775999621738
# Episode 119 finished after 91 timesteps. Return = -179.22839288504616
# Episode 120 finished after 76 timesteps. Return = -226.49498143080785
# Episode 121 finished after 72 timesteps. Return = -103.93776589288804
# Episode 122 finished after 112 timesteps. Return = -370.2523101489354
# Episode 123 finished after 84 timesteps. Return = -278.044255494915
# Episode 124 finished after 87 timesteps. Return = -146.03252710909885
# Episode 125 finished after 111 timesteps. Return = -148.7575632564829
# Episode 126 finished after 71 timesteps. Return = -155.26669213032486
# Episode 127 finished after 96 timesteps. Return = -333.16685964489835
# Episode 128 finished after 92 timesteps. Return = -384.83259019614945
# Episode 129 finished after 77 timesteps. Return = -202.62407394016407
# Episode 130 finished after 97 timesteps. Return = -315.572164885465
# Episode 131 finished after 113 timesteps. Return = -213.6755624305202
# Episode 132 finished after 80 timesteps. Return = -91.1339605460627
# Episode 133 finished after 92 timesteps. Return = -207.3686318890007
# Episode 134 finished after 132 timesteps. Return = -169.78011216904193
# Episode 135 finished after 103 timesteps. Return = -192.05182501818274
# Episode 136 finished after 111 timesteps. Return = -265.4042614798002
# Episode 137 finished after 90 timesteps. Return = -238.9649484639025
# Episode 138 finished after 73 timesteps. Return = -237.46259163457916
# Episode 139 finished after 85 timesteps. Return = -154.66057743601783
# Episode 140 finished after 103 timesteps. Return = -162.43769483796558
# Episode 141 finished after 89 timesteps. Return = -221.01071893538602
# Episode 142 finished after 76 timesteps. Return = -91.70710026583173
# Episode 143 finished after 91 timesteps. Return = -151.73997045856544
# Episode 144 finished after 92 timesteps. Return = -271.118047804114
# Episode 145 finished after 108 timesteps. Return = -321.2407620466291
# Episode 146 finished after 114 timesteps. Return = -194.87612602590954
# Episode 147 finished after 68 timesteps. Return = -83.72895880329793
# Episode 148 finished after 102 timesteps. Return = -294.50995475010586
# Episode 149 finished after 96 timesteps. Return = -126.9817528613399
# Episode 150 finished after 93 timesteps. Return = -414.1465443549904
# Episode 151 finished after 76 timesteps. Return = -278.88474962656824
# Episode 152 finished after 106 timesteps. Return = -346.93710604346745
# Episode 153 finished after 90 timesteps. Return = -239.3000741042557
# Episode 154 finished after 60 timesteps. Return = -95.12334132287391
# Episode 155 finished after 91 timesteps. Return = -66.68426547313084
# Episode 156 finished after 89 timesteps. Return = -155.94535570066492
# Episode 157 finished after 113 timesteps. Return = -273.80591716145676
# Episode 158 finished after 65 timesteps. Return = -28.075149935953775
# Episode 159 finished after 94 timesteps. Return = -138.6146427118078
# Episode 160 finished after 61 timesteps. Return = -65.41977480104482
# Episode 161 finished after 81 timesteps. Return = -108.05715458802874
# Episode 162 finished after 102 timesteps. Return = -235.3097301301015
# Episode 163 finished after 96 timesteps. Return = -442.50865427127246
# Episode 164 finished after 112 timesteps. Return = -112.32336779094247
# Episode 165 finished after 73 timesteps. Return = -130.6537446616489
# Episode 166 finished after 91 timesteps. Return = -119.97452879359763
# Episode 167 finished after 60 timesteps. Return = -219.29005008705974
# Episode 168 finished after 117 timesteps. Return = -163.8714661364308
# Episode 169 finished after 71 timesteps. Return = -198.5273898935058
# Episode 170 finished after 67 timesteps. Return = -97.54594130720751
# Episode 171 finished after 96 timesteps. Return = -122.90533551388233
# Episode 172 finished after 92 timesteps. Return = -109.05428713969451
# Episode 173 finished after 89 timesteps. Return = -89.78004538567173
# Episode 174 finished after 81 timesteps. Return = -253.22509801292728
# Episode 175 finished after 98 timesteps. Return = -96.02678130481621
# Episode 176 finished after 89 timesteps. Return = -249.26062406162904
# Episode 177 finished after 122 timesteps. Return = -233.5291243935175
# Episode 178 finished after 103 timesteps. Return = -318.2945691992227
# Episode 179 finished after 69 timesteps. Return = -80.03359124678876
# Episode 180 finished after 84 timesteps. Return = -92.18732160777816
# Episode 181 finished after 117 timesteps. Return = -257.7732291949321
# Episode 182 finished after 79 timesteps. Return = -134.51195262160724
# Episode 183 finished after 63 timesteps. Return = -83.54952571407415
# Episode 184 finished after 106 timesteps. Return = -159.09405809497804
# Episode 185 finished after 93 timesteps. Return = -205.28865121756732
# Episode 186 finished after 104 timesteps. Return = -150.40715097969945
# Episode 187 finished after 68 timesteps. Return = -112.89441916841183
# Episode 188 finished after 103 timesteps. Return = -323.3774625200398
# Episode 189 finished after 86 timesteps. Return = -350.84945774532366
# Episode 190 finished after 103 timesteps. Return = -227.96234935298182
# Episode 191 finished after 57 timesteps. Return = -97.16552160564676
# Episode 192 finished after 55 timesteps. Return = -170.5040484253293
# Episode 193 finished after 88 timesteps. Return = -98.55877708331144
# Episode 194 finished after 66 timesteps. Return = -57.23522804253187
# Episode 195 finished after 102 timesteps. Return = -126.74699257631477
# Episode 196 finished after 99 timesteps. Return = -431.71365656648413
# Episode 197 finished after 100 timesteps. Return = -124.38302242665051
# Episode 198 finished after 103 timesteps. Return = -160.57774745300247
# Episode 199 finished after 83 timesteps. Return = -146.30842911349504
# Episode 200 finished after 93 timesteps. Return = -117.14509477927423
# Episode 201 finished after 90 timesteps. Return = -182.7094173670963
# Episode 202 finished after 84 timesteps. Return = -385.84791670910624
# Episode 203 finished after 90 timesteps. Return = -366.2558965092331
# Episode 204 finished after 106 timesteps. Return = -309.1233208560092
# Episode 205 finished after 101 timesteps. Return = -318.7692915348674
# Episode 206 finished after 83 timesteps. Return = -102.70170816725665
# Episode 207 finished after 106 timesteps. Return = -315.0803504525562
# Episode 208 finished after 84 timesteps. Return = -169.45336742206297
# Episode 209 finished after 103 timesteps. Return = -136.90540890545947
# Episode 210 finished after 98 timesteps. Return = -115.1841707314115
# Episode 211 finished after 101 timesteps. Return = -289.7220466231438
# Episode 212 finished after 98 timesteps. Return = -306.5118502446912
# Episode 213 finished after 98 timesteps. Return = -78.35519733345346
# Episode 214 finished after 85 timesteps. Return = -135.56563706104373
# Episode 215 finished after 76 timesteps. Return = -86.50550929018152
# Episode 216 finished after 113 timesteps. Return = -226.80184393397153
# Episode 217 finished after 115 timesteps. Return = -344.340866951199
# Episode 218 finished after 84 timesteps. Return = -287.2037130596473
# Episode 219 finished after 75 timesteps. Return = -79.47469195752817
# Episode 220 finished after 97 timesteps. Return = -411.83449627271784
# Episode 221 finished after 100 timesteps. Return = -116.95166111500038
# Episode 222 finished after 100 timesteps. Return = -326.9812131476592
# Episode 223 finished after 115 timesteps. Return = -118.58708805806965
# Episode 224 finished after 99 timesteps. Return = -239.60272695892718
# Episode 225 finished after 71 timesteps. Return = -82.3384155648194
# Episode 226 finished after 69 timesteps. Return = -87.09778538098561
# Episode 227 finished after 93 timesteps. Return = -237.73709663723264
# Episode 228 finished after 77 timesteps. Return = -187.64300246177686
# Episode 229 finished after 105 timesteps. Return = -302.5849114673657
# Episode 230 finished after 113 timesteps. Return = -240.65238920119018
# Episode 231 finished after 82 timesteps. Return = -153.6299479498271
# Episode 232 finished after 109 timesteps. Return = -241.6365131478557
# Episode 233 finished after 106 timesteps. Return = -100.43161102025782
# Episode 234 finished after 67 timesteps. Return = -72.7138269212043
# Episode 235 finished after 64 timesteps. Return = -127.70038040873246
# Episode 236 finished after 64 timesteps. Return = -72.5091655960722
# Episode 237 finished after 57 timesteps. Return = -113.0959002123943
# Episode 238 finished after 78 timesteps. Return = -139.8323136189533
# Episode 239 finished after 94 timesteps. Return = -189.11222146485255
# Episode 240 finished after 73 timesteps. Return = -315.25105523818655
# Episode 241 finished after 74 timesteps. Return = -89.8055844708517
# Episode 242 finished after 76 timesteps. Return = -104.7360280850638
# Episode 243 finished after 69 timesteps. Return = -61.429789896228684
# Episode 244 finished after 77 timesteps. Return = -130.7896768667622
# Episode 245 finished after 110 timesteps. Return = -156.38941344651093
# Episode 246 finished after 106 timesteps. Return = -203.03878503590246
# Episode 247 finished after 69 timesteps. Return = -104.05578183875042
# Episode 248 finished after 86 timesteps. Return = -123.43498235523248
# Episode 249 finished after 122 timesteps. Return = -327.2015059753652
# Episode 250 finished after 109 timesteps. Return = -127.9016450164069
# Episode 251 finished after 72 timesteps. Return = -69.6901930894414
# Episode 252 finished after 98 timesteps. Return = -109.78683655166661
# Episode 253 finished after 93 timesteps. Return = -136.34769165540857
# Episode 254 finished after 93 timesteps. Return = -136.40628811951308
# Episode 255 finished after 70 timesteps. Return = -108.0583374688494
# Episode 256 finished after 133 timesteps. Return = -124.73534923166112
# Episode 257 finished after 63 timesteps. Return = -116.91582586664548
# Episode 258 finished after 104 timesteps. Return = -130.00098991562965
# Episode 259 finished after 64 timesteps. Return = -99.20154860987893
# Episode 260 finished after 71 timesteps. Return = -200.01757747745546
# Episode 261 finished after 102 timesteps. Return = -127.55107847405793
# Episode 262 finished after 131 timesteps. Return = -107.41312947650394
# Episode 263 finished after 105 timesteps. Return = -162.56740117318805
# Episode 264 finished after 59 timesteps. Return = -98.77019646546943
# Episode 265 finished after 81 timesteps. Return = -108.37687914279498
# Episode 266 finished after 71 timesteps. Return = -252.89492410547734
# Episode 267 finished after 142 timesteps. Return = -344.65897492460965
# Episode 268 finished after 97 timesteps. Return = -117.85063589256436
# Episode 269 finished after 93 timesteps. Return = -251.79744967668825
# Episode 270 finished after 69 timesteps. Return = -104.32652345953517
# Episode 271 finished after 104 timesteps. Return = -158.73300799132522
# Episode 272 finished after 86 timesteps. Return = -93.28153397362433
# Episode 273 finished after 85 timesteps. Return = -169.74399800814953
# Episode 274 finished after 93 timesteps. Return = -264.39619801114065
# Episode 275 finished after 72 timesteps. Return = -106.95957821178725
# Episode 276 finished after 74 timesteps. Return = -95.545959258963
# Episode 277 finished after 84 timesteps. Return = -402.46205229869986
# Episode 278 finished after 76 timesteps. Return = -67.3422716331421
# Episode 279 finished after 99 timesteps. Return = -274.01568770437376
# Episode 280 finished after 74 timesteps. Return = -46.89385100991677
# Episode 281 finished after 81 timesteps. Return = -102.69353352574561
# Episode 282 finished after 85 timesteps. Return = -322.7061460375062
# Episode 283 finished after 70 timesteps. Return = -77.5952199622734
# Episode 284 finished after 73 timesteps. Return = -187.67065472027906
# Episode 285 finished after 76 timesteps. Return = -173.79543988353873
# Episode 286 finished after 95 timesteps. Return = -138.4272915302911
# Episode 287 finished after 89 timesteps. Return = -232.58769307506967
# Episode 288 finished after 70 timesteps. Return = -87.58739337761818
# Episode 289 finished after 77 timesteps. Return = -254.46531302503385
# Episode 290 finished after 99 timesteps. Return = -111.62614756397174
# Episode 291 finished after 78 timesteps. Return = -168.97072417254174
# Episode 292 finished after 69 timesteps. Return = -98.66902771649995
# Episode 293 finished after 115 timesteps. Return = -236.43702651590846
# Episode 294 finished after 85 timesteps. Return = -126.0037485336344
# Episode 295 finished after 73 timesteps. Return = 27.76311832448603
# Episode 296 finished after 114 timesteps. Return = -230.20626827005844
# Episode 297 finished after 73 timesteps. Return = -131.32228304311974
# Episode 298 finished after 111 timesteps. Return = -200.32606374557756
# Episode 299 finished after 123 timesteps. Return = -112.84515176928736
# Episode 300 finished after 128 timesteps. Return = -393.04631925175516
# Episode 301 finished after 84 timesteps. Return = -233.68582909925703
# Episode 302 finished after 93 timesteps. Return = -127.23728443783573
# Episode 303 finished after 109 timesteps. Return = -349.6832399973654
# Episode 304 finished after 68 timesteps. Return = -109.18632531529221
# Episode 305 finished after 78 timesteps. Return = -243.44523087336688
# Episode 306 finished after 101 timesteps. Return = -279.52461562215603
# Episode 307 finished after 84 timesteps. Return = -68.7949216172403
# Episode 308 finished after 77 timesteps. Return = -202.1257851391876
# Episode 309 finished after 102 timesteps. Return = -107.4925377990892
# Episode 310 finished after 75 timesteps. Return = -122.66811516711013
# Episode 311 finished after 125 timesteps. Return = -124.42599476526804
# Episode 312 finished after 119 timesteps. Return = -293.7308169039936
# Episode 313 finished after 133 timesteps. Return = -272.974652323796
# Episode 314 finished after 87 timesteps. Return = -412.6649926475426
# Episode 315 finished after 64 timesteps. Return = -64.87940788122319
# Episode 316 finished after 95 timesteps. Return = -120.79598441003947
# Episode 317 finished after 85 timesteps. Return = -91.52795813098953
# Episode 318 finished after 100 timesteps. Return = -167.79298346190717
# Episode 319 finished after 94 timesteps. Return = -298.6538606840531
# Episode 320 finished after 119 timesteps. Return = -318.08802515717025
# Episode 321 finished after 80 timesteps. Return = -87.06010844796722
# Episode 322 finished after 77 timesteps. Return = -115.94828548858686
# Episode 323 finished after 83 timesteps. Return = -129.4048991663942
# Episode 324 finished after 119 timesteps. Return = -164.3327644508197
# Episode 325 finished after 63 timesteps. Return = -78.41422581735195
# Episode 326 finished after 83 timesteps. Return = -75.84504840754451
# Episode 327 finished after 74 timesteps. Return = -310.911604552929
# Episode 328 finished after 89 timesteps. Return = -92.01290522824218
# Episode 329 finished after 73 timesteps. Return = -91.5830477939026
# Episode 330 finished after 88 timesteps. Return = -176.46200386133876
# Episode 331 finished after 86 timesteps. Return = 29.704020300277932
# Episode 332 finished after 118 timesteps. Return = -168.33510203150988
# Episode 333 finished after 135 timesteps. Return = -184.6698387611639
# Episode 334 finished after 98 timesteps. Return = -112.82479603676568
# Episode 335 finished after 58 timesteps. Return = -109.70452562977701
# Episode 336 finished after 90 timesteps. Return = -235.93734415794668
# Episode 337 finished after 76 timesteps. Return = -87.93933026589792
# Episode 338 finished after 64 timesteps. Return = -89.38941414137727
# Episode 339 finished after 129 timesteps. Return = -359.372260993456
# Episode 340 finished after 120 timesteps. Return = -63.48261302122842
# Episode 341 finished after 92 timesteps. Return = -161.52939236075963
# Episode 342 finished after 82 timesteps. Return = -295.9310155275055
# Episode 343 finished after 61 timesteps. Return = -69.94107529282506
# Episode 344 finished after 128 timesteps. Return = -131.66235416075548
# Episode 345 finished after 124 timesteps. Return = -65.30829695721454
# Episode 346 finished after 104 timesteps. Return = -183.90378982145722
# Episode 347 finished after 114 timesteps. Return = -164.9829666097445
# Episode 348 finished after 154 timesteps. Return = -110.0371608120747
# Episode 349 finished after 62 timesteps. Return = -114.43934936789526
# Episode 350 finished after 92 timesteps. Return = -429.7092545919733
# Episode 351 finished after 79 timesteps. Return = -122.36556795285784
# Episode 352 finished after 104 timesteps. Return = -123.89963411464637
# Episode 353 finished after 75 timesteps. Return = -149.19813581582792
# Episode 354 finished after 93 timesteps. Return = -213.96290360830488
# Episode 355 finished after 88 timesteps. Return = -116.76907454662987
# Episode 356 finished after 101 timesteps. Return = -102.10127159298808
# Episode 357 finished after 94 timesteps. Return = -322.20881901129076
# Episode 358 finished after 74 timesteps. Return = -102.96218935379441
# Episode 359 finished after 96 timesteps. Return = -105.5427935586074
# Episode 360 finished after 128 timesteps. Return = -163.17865151510853
# Episode 361 finished after 114 timesteps. Return = -129.79141938613728
# Episode 362 finished after 71 timesteps. Return = -90.73216081989987
# Episode 363 finished after 123 timesteps. Return = -205.99010375035584
# Episode 364 finished after 126 timesteps. Return = -32.24932760731711
# Episode 365 finished after 113 timesteps. Return = -88.00466065175881
# Episode 366 finished after 114 timesteps. Return = -148.09602044606117
# Episode 367 finished after 70 timesteps. Return = -92.98245556663582
# Episode 368 finished after 97 timesteps. Return = -155.62325254566738
# Episode 369 finished after 79 timesteps. Return = -120.32005253401262
# Episode 370 finished after 133 timesteps. Return = -296.4595514108878
# Episode 371 finished after 62 timesteps. Return = -94.87737272276422
# Episode 372 finished after 85 timesteps. Return = -195.12058152410938
# Episode 373 finished after 100 timesteps. Return = -184.81791445894038
# Episode 374 finished after 104 timesteps. Return = -145.25580613645315
# Episode 375 finished after 101 timesteps. Return = -220.6964296963893
# Episode 376 finished after 106 timesteps. Return = -33.27589991601734
# Episode 377 finished after 59 timesteps. Return = -136.60598527468233
# Episode 378 finished after 101 timesteps. Return = -181.4811542296449
# Episode 379 finished after 80 timesteps. Return = -121.95485281535035
# Episode 380 finished after 94 timesteps. Return = -105.30814452868083
# Episode 381 finished after 117 timesteps. Return = -138.43594981744656
# Episode 382 finished after 68 timesteps. Return = -98.63157031567056
# Episode 383 finished after 91 timesteps. Return = -164.72100738321313
# Episode 384 finished after 100 timesteps. Return = -174.3585420046165
# Episode 385 finished after 66 timesteps. Return = -40.13202638090753
# Episode 386 finished after 113 timesteps. Return = -188.4518987273632
# Episode 387 finished after 83 timesteps. Return = -183.33045510095235
# Episode 388 finished after 107 timesteps. Return = -181.17405203782175
# Episode 389 finished after 72 timesteps. Return = -54.944572532179976
# Episode 390 finished after 61 timesteps. Return = -92.2126984498184
# Episode 391 finished after 95 timesteps. Return = -78.8123603672768
# Episode 392 finished after 68 timesteps. Return = -128.44676075220235
# Episode 393 finished after 94 timesteps. Return = -257.2176176703957
# Episode 394 finished after 64 timesteps. Return = -50.16694929835777
# Episode 395 finished after 94 timesteps. Return = -129.83936280783118
# Episode 396 finished after 129 timesteps. Return = -279.6613259811902
# Episode 397 finished after 97 timesteps. Return = -111.23235054862958
# Episode 398 finished after 114 timesteps. Return = -126.44977590431263
# Episode 399 finished after 82 timesteps. Return = -118.82433828871054
# Episode 400 finished after 80 timesteps. Return = -87.33725189623038
# Episode 401 finished after 95 timesteps. Return = -167.3692087636325
# Episode 402 finished after 85 timesteps. Return = -77.6078059021595
# Episode 403 finished after 103 timesteps. Return = -165.17775788238453
# Episode 404 finished after 136 timesteps. Return = -472.3605289965223
# Episode 405 finished after 86 timesteps. Return = -179.49593534737352
# Episode 406 finished after 92 timesteps. Return = -95.82816824815974
# Episode 407 finished after 82 timesteps. Return = -14.024955855806098
# Episode 408 finished after 67 timesteps. Return = -221.1564475862093
# Episode 409 finished after 79 timesteps. Return = -178.11543501407962
# Episode 410 finished after 68 timesteps. Return = -170.11156839866163
# Episode 411 finished after 103 timesteps. Return = -127.26610323000759
# Episode 412 finished after 120 timesteps. Return = -105.27522039156193
# Episode 413 finished after 66 timesteps. Return = -112.31815932052145
# Episode 414 finished after 105 timesteps. Return = -151.99457695462803
# Episode 415 finished after 76 timesteps. Return = -106.25244697232887
# Episode 416 finished after 145 timesteps. Return = -113.05781858131893
# Episode 417 finished after 128 timesteps. Return = -119.34912835434582
# Episode 418 finished after 85 timesteps. Return = -88.28367932697964
# Episode 419 finished after 68 timesteps. Return = -96.15438728091526
# Episode 420 finished after 96 timesteps. Return = -89.44083523172363
# Episode 421 finished after 124 timesteps. Return = -224.83247172256063
# Episode 422 finished after 107 timesteps. Return = -137.82523572752984
# Episode 423 finished after 146 timesteps. Return = -300.4324796036036
# Episode 424 finished after 65 timesteps. Return = -82.16372147028201
# Episode 425 finished after 127 timesteps. Return = -128.6986768325242
# Episode 426 finished after 75 timesteps. Return = -94.71366666494853
# Episode 427 finished after 130 timesteps. Return = -137.3552830325895
# Episode 428 finished after 75 timesteps. Return = -98.08435647758374
# Episode 429 finished after 109 timesteps. Return = -106.82149238062533
# Episode 430 finished after 100 timesteps. Return = -123.7653884626383
# Episode 431 finished after 59 timesteps. Return = -85.38838697294365
# Episode 432 finished after 84 timesteps. Return = -121.10908264067311
# Episode 433 finished after 62 timesteps. Return = -70.73056126232922
# Episode 434 finished after 104 timesteps. Return = -214.35693073550624
# Episode 435 finished after 72 timesteps. Return = -60.97767095963542
# Episode 436 finished after 86 timesteps. Return = -172.77792882719996
# Episode 437 finished after 95 timesteps. Return = -90.30371319144827
# Episode 438 finished after 96 timesteps. Return = -141.70563340701145
# Episode 439 finished after 72 timesteps. Return = -98.97427669231942
# Episode 440 finished after 76 timesteps. Return = -182.21173927515233
# Episode 441 finished after 65 timesteps. Return = -53.4482945482717
# Episode 442 finished after 82 timesteps. Return = -71.48091116699254
# Episode 443 finished after 112 timesteps. Return = -93.66059558246408
# Episode 444 finished after 140 timesteps. Return = -135.560914770779
# Episode 445 finished after 62 timesteps. Return = -148.41344323387526
# Episode 446 finished after 90 timesteps. Return = -150.1447775799673
# Episode 447 finished after 65 timesteps. Return = -109.77464794017585
# Episode 448 finished after 118 timesteps. Return = -101.50230854849056
# Episode 449 finished after 61 timesteps. Return = -90.25574230773884
# Episode 450 finished after 97 timesteps. Return = -21.239399107709787
# Episode 451 finished after 83 timesteps. Return = -84.36807952614484
# Episode 452 finished after 112 timesteps. Return = -208.9694122366541
# Episode 453 finished after 75 timesteps. Return = -25.15172512121515
# Episode 454 finished after 103 timesteps. Return = -163.40899320526597
# Episode 455 finished after 92 timesteps. Return = -112.28575582452285
# Episode 456 finished after 95 timesteps. Return = -142.23797907021935
# Episode 457 finished after 102 timesteps. Return = -79.52633905002241
# Episode 458 finished after 84 timesteps. Return = -118.86475551217603
# Episode 459 finished after 65 timesteps. Return = -91.19896004914463
# Episode 460 finished after 83 timesteps. Return = -88.07519334064587
# Episode 461 finished after 84 timesteps. Return = -94.80399258158691
# Episode 462 finished after 91 timesteps. Return = -110.32570681186692
# Episode 463 finished after 63 timesteps. Return = -116.70126435171647
# Episode 464 finished after 116 timesteps. Return = -84.55514811245183
# Episode 465 finished after 73 timesteps. Return = -106.86580901602329
# Episode 466 finished after 88 timesteps. Return = -149.46257359853482
# Episode 467 finished after 125 timesteps. Return = -82.60356938404585
# Episode 468 finished after 84 timesteps. Return = -105.43374778163223
# Episode 469 finished after 88 timesteps. Return = -116.41041003312725
# Episode 470 finished after 108 timesteps. Return = -160.0687862455461
# Episode 471 finished after 81 timesteps. Return = -117.05694149366077
# Episode 472 finished after 78 timesteps. Return = -112.56235508226828
# Episode 473 finished after 70 timesteps. Return = -73.73457233889629
# Episode 474 finished after 106 timesteps. Return = -179.74104694862658
# Episode 475 finished after 67 timesteps. Return = -106.15807549589576
# Episode 476 finished after 79 timesteps. Return = -117.38637618152244
# Episode 477 finished after 70 timesteps. Return = -124.48395778224389
# Episode 478 finished after 129 timesteps. Return = -144.0859662382772
# Episode 479 finished after 113 timesteps. Return = -195.12945405905077
# Episode 480 finished after 99 timesteps. Return = -129.5136036400538
# Episode 481 finished after 87 timesteps. Return = -108.553936564064
# Episode 482 finished after 116 timesteps. Return = -186.46188682378235
# Episode 483 finished after 98 timesteps. Return = -122.00035770104782
# Episode 484 finished after 78 timesteps. Return = -72.27021794892603
# Episode 485 finished after 81 timesteps. Return = -118.45343168515684
# Episode 486 finished after 75 timesteps. Return = -103.97379218921803
# Episode 487 finished after 108 timesteps. Return = -154.2850568356945
# Episode 488 finished after 128 timesteps. Return = -126.79552610386875
# Episode 489 finished after 69 timesteps. Return = -80.81674130431307
# Episode 490 finished after 122 timesteps. Return = -296.85888332443926
# Episode 491 finished after 71 timesteps. Return = -101.43768114349456
# Episode 492 finished after 112 timesteps. Return = -46.05399485127828
# Episode 493 finished after 104 timesteps. Return = -185.4492324023995
# Episode 494 finished after 96 timesteps. Return = -152.93832635339584
# Episode 495 finished after 112 timesteps. Return = -324.20518875224514
# Episode 496 finished after 92 timesteps. Return = -49.20326868883755
# Episode 497 finished after 131 timesteps. Return = -114.81317930702821
# Episode 498 finished after 138 timesteps. Return = -131.92035831554995
# Episode 499 finished after 109 timesteps. Return = -109.74634259972507
# Episode 500 finished after 65 timesteps. Return = -82.57563790999555
# Episode 501 finished after 128 timesteps. Return = -168.12506005082702
# Episode 502 finished after 92 timesteps. Return = -113.05626746847344
# Episode 503 finished after 102 timesteps. Return = -147.92917494260374
# Episode 504 finished after 93 timesteps. Return = -105.69303487856963
# Episode 505 finished after 66 timesteps. Return = -92.9904334422922
# Episode 506 finished after 110 timesteps. Return = -160.37344951898527
# Episode 507 finished after 96 timesteps. Return = -163.34657831454751
# Episode 508 finished after 77 timesteps. Return = -100.39584846188316
# Episode 509 finished after 87 timesteps. Return = -84.53220164352321
# Episode 510 finished after 75 timesteps. Return = -76.61644332549943
# Episode 511 finished after 72 timesteps. Return = -98.41557105426693
# Episode 512 finished after 120 timesteps. Return = -108.81183165199049
# Episode 513 finished after 68 timesteps. Return = -103.14085680424853
# Episode 514 finished after 113 timesteps. Return = -126.85798227089182
# Episode 515 finished after 97 timesteps. Return = -93.0223593975666
# Episode 516 finished after 146 timesteps. Return = -4.549714227068037
# Episode 517 finished after 88 timesteps. Return = -94.84345293966753
# Episode 518 finished after 98 timesteps. Return = -131.21816817762192
# Episode 519 finished after 108 timesteps. Return = -243.0206407822205
# Episode 520 finished after 80 timesteps. Return = -91.19088822590479
# Episode 521 finished after 92 timesteps. Return = -107.13092376878627
# Episode 522 finished after 52 timesteps. Return = -97.71771151932566
# Episode 523 finished after 98 timesteps. Return = -120.75075357689522
# Episode 524 finished after 95 timesteps. Return = -124.38130355224935
# Episode 525 finished after 98 timesteps. Return = -109.03792990990905
# Episode 526 finished after 103 timesteps. Return = -24.82951122933727
# Episode 527 finished after 100 timesteps. Return = -152.84882845832772
# Episode 528 finished after 98 timesteps. Return = -222.82447300466632
# Episode 529 finished after 100 timesteps. Return = -91.52827246523478
# Episode 530 finished after 125 timesteps. Return = -182.88432710376497
# Episode 531 finished after 76 timesteps. Return = -148.55279344421956
# Episode 532 finished after 78 timesteps. Return = -79.69809037529723
# Episode 533 finished after 76 timesteps. Return = -114.25030120332511
# Episode 534 finished after 69 timesteps. Return = -115.07426605386777
# Episode 535 finished after 92 timesteps. Return = -111.68962523968472
# Episode 536 finished after 86 timesteps. Return = -83.47590449023022
# Episode 537 finished after 67 timesteps. Return = -41.70727044393706
# Episode 538 finished after 91 timesteps. Return = -189.525057140691
# Episode 539 finished after 82 timesteps. Return = -131.2452231913116
# Episode 540 finished after 115 timesteps. Return = -128.15092422916277
# Episode 541 finished after 65 timesteps. Return = -84.82986449779435
# Episode 542 finished after 59 timesteps. Return = -100.80065354439678
# Episode 543 finished after 87 timesteps. Return = -115.62451413522399
# Episode 544 finished after 90 timesteps. Return = -224.50738097013908
# Episode 545 finished after 136 timesteps. Return = -170.03072775256896
# Episode 546 finished after 86 timesteps. Return = -117.82303255624005
# Episode 547 finished after 76 timesteps. Return = -101.49954226029566
# Episode 548 finished after 121 timesteps. Return = -351.3109949477501
# Episode 549 finished after 115 timesteps. Return = -288.35421335617366
# Episode 550 finished after 154 timesteps. Return = -90.24164911156849
# Episode 551 finished after 109 timesteps. Return = -136.11889821337752
# Episode 552 finished after 100 timesteps. Return = -5.629277343660561
# Episode 553 finished after 129 timesteps. Return = -185.17747041791495
# Episode 554 finished after 64 timesteps. Return = -78.04255355521838
# Episode 555 finished after 99 timesteps. Return = -134.99035839701472
# Episode 556 finished after 66 timesteps. Return = -49.225577509393005
# Episode 557 finished after 107 timesteps. Return = -307.217524267297
# Episode 558 finished after 125 timesteps. Return = -77.4547827442147
# Episode 559 finished after 128 timesteps. Return = -291.84166324167325
# Episode 560 finished after 67 timesteps. Return = -57.163978001181334
# Episode 561 finished after 90 timesteps. Return = -86.86444439123
# Episode 562 finished after 103 timesteps. Return = -125.77759661852085
# Episode 563 finished after 71 timesteps. Return = -149.2799202644032
# Episode 564 finished after 100 timesteps. Return = -131.96319378418448
# Episode 565 finished after 109 timesteps. Return = -64.37660911438932
# Episode 566 finished after 123 timesteps. Return = -103.80950521845325
# Episode 567 finished after 88 timesteps. Return = -117.82048023723729
# Episode 568 finished after 89 timesteps. Return = -118.09725987755583
# Episode 569 finished after 112 timesteps. Return = -36.10577362270908
# Episode 570 finished after 112 timesteps. Return = -160.5877826771616
# Episode 571 finished after 118 timesteps. Return = -184.25523339206268
# Episode 572 finished after 82 timesteps. Return = -105.69293214927357
# Episode 573 finished after 80 timesteps. Return = -109.55417900256255
# Episode 574 finished after 88 timesteps. Return = -146.26543794473474
# Episode 575 finished after 109 timesteps. Return = -176.76043451811225
# Episode 576 finished after 77 timesteps. Return = -78.05395983804613
# Episode 577 finished after 139 timesteps. Return = -148.07434829399756
# Episode 578 finished after 112 timesteps. Return = -119.85888697509127
# Episode 579 finished after 76 timesteps. Return = -137.18681809226004
# Episode 580 finished after 110 timesteps. Return = -68.89887910987652
# Episode 581 finished after 130 timesteps. Return = -173.09622637367585
# Episode 582 finished after 98 timesteps. Return = -52.88655129273693
# Episode 583 finished after 110 timesteps. Return = -125.92430383140032
# Episode 584 finished after 142 timesteps. Return = -60.67397704291309
# Episode 585 finished after 81 timesteps. Return = -121.28826894839617
# Episode 586 finished after 104 timesteps. Return = -150.18366630242798
# Episode 587 finished after 131 timesteps. Return = -124.29544858799105
# Episode 588 finished after 79 timesteps. Return = -112.08980584843738
# Episode 589 finished after 88 timesteps. Return = -106.28122997368371
# Episode 590 finished after 108 timesteps. Return = -179.32333894649423
# Episode 591 finished after 92 timesteps. Return = -93.66623572928523
# Episode 592 finished after 89 timesteps. Return = -177.03045505111925
# Episode 593 finished after 102 timesteps. Return = -161.140287841565
# Episode 594 finished after 62 timesteps. Return = -88.85437899067746
# Episode 595 finished after 98 timesteps. Return = -114.37431990385382
# Episode 596 finished after 75 timesteps. Return = -94.17686917652208
# Episode 597 finished after 73 timesteps. Return = -137.28217114938423
# Episode 598 finished after 98 timesteps. Return = -138.3564377771217
# Episode 599 finished after 95 timesteps. Return = -104.75981879796882
# Episode 600 finished after 109 timesteps. Return = -134.2518583778084
# Episode 601 finished after 97 timesteps. Return = -136.06159026806318
# Episode 602 finished after 60 timesteps. Return = -74.41384173221233
# Episode 603 finished after 121 timesteps. Return = -184.5465486508213
# Episode 604 finished after 100 timesteps. Return = -123.36074578707672
# Episode 605 finished after 108 timesteps. Return = -266.1592200766408
# Episode 606 finished after 114 timesteps. Return = -123.66635595748909
# Episode 607 finished after 84 timesteps. Return = -81.31770418265896
# Episode 608 finished after 66 timesteps. Return = -103.81501337861572
# Episode 609 finished after 90 timesteps. Return = -333.743355520874
# Episode 610 finished after 70 timesteps. Return = -102.2937712608247
# Episode 611 finished after 91 timesteps. Return = -93.3889900500207
# Episode 612 finished after 137 timesteps. Return = -58.915613712966824
# Episode 613 finished after 114 timesteps. Return = -187.0711776477968
# Episode 614 finished after 79 timesteps. Return = -73.09425967046135
# Episode 615 finished after 69 timesteps. Return = -69.97060718137473
# Episode 616 finished after 62 timesteps. Return = -79.56947895847793
# Episode 617 finished after 97 timesteps. Return = -140.3906239434782
# Episode 618 finished after 99 timesteps. Return = -186.84673413009176
# Episode 619 finished after 123 timesteps. Return = -171.5820498246166
# Episode 620 finished after 129 timesteps. Return = -221.23255243093857
# Episode 621 finished after 94 timesteps. Return = -116.92398471862305
# Episode 622 finished after 91 timesteps. Return = -105.2925557626957
# Episode 623 finished after 59 timesteps. Return = -100.95964924554862
# Episode 624 finished after 63 timesteps. Return = -74.19612987352669
# Episode 625 finished after 63 timesteps. Return = -60.00412801921446
# Episode 626 finished after 97 timesteps. Return = -147.2265651759286
# Episode 627 finished after 67 timesteps. Return = -44.369221765111575
# Episode 628 finished after 110 timesteps. Return = -132.42088637824736
# Episode 629 finished after 144 timesteps. Return = -235.13336943880697
# Episode 630 finished after 83 timesteps. Return = -85.02576091352279
# Episode 631 finished after 89 timesteps. Return = -118.97136806066077
# Episode 632 finished after 78 timesteps. Return = -122.36972929508927
# Episode 633 finished after 87 timesteps. Return = -44.71641183163665
# Episode 634 finished after 67 timesteps. Return = -47.035803916409435
# Episode 635 finished after 74 timesteps. Return = -96.80840798063888
# Episode 636 finished after 106 timesteps. Return = -121.55133806449595
# Episode 637 finished after 106 timesteps. Return = -104.65573621687012
# Episode 638 finished after 124 timesteps. Return = -275.6064889414627
# Episode 639 finished after 97 timesteps. Return = -158.74755913438005
# Episode 640 finished after 122 timesteps. Return = -72.57701343579956
# Episode 641 finished after 105 timesteps. Return = -104.94658030931309
# Episode 642 finished after 86 timesteps. Return = -167.66513916603475
# Episode 643 finished after 73 timesteps. Return = -76.48732436769399
# Episode 644 finished after 92 timesteps. Return = -120.44137194984884
# Episode 645 finished after 118 timesteps. Return = -160.96241240187007
# Episode 646 finished after 104 timesteps. Return = -122.31368337265708
# Episode 647 finished after 90 timesteps. Return = -144.11082384104236
# Episode 648 finished after 70 timesteps. Return = -75.84915046655759
# Episode 649 finished after 122 timesteps. Return = -146.23580930694237
# Episode 650 finished after 121 timesteps. Return = -118.87487624368184
# Episode 651 finished after 106 timesteps. Return = -343.7907690917052
# Episode 652 finished after 98 timesteps. Return = -98.43697050971615
# Episode 653 finished after 119 timesteps. Return = -86.13530868465847
# Episode 654 finished after 123 timesteps. Return = -210.10378240165647
# Episode 655 finished after 133 timesteps. Return = -26.672983530495443
# Episode 656 finished after 113 timesteps. Return = -134.98546760577028
# Episode 657 finished after 127 timesteps. Return = -131.5316422323762
# Episode 658 finished after 64 timesteps. Return = -69.38928481105091
# Episode 659 finished after 57 timesteps. Return = -79.92259276383822
# Episode 660 finished after 103 timesteps. Return = -91.98825507899232
# Episode 661 finished after 87 timesteps. Return = -130.6173668827214
# Episode 662 finished after 85 timesteps. Return = -93.85414018039091
# Episode 663 finished after 69 timesteps. Return = -74.74660038738372
# Episode 664 finished after 120 timesteps. Return = -107.96117804753933
# Episode 665 finished after 106 timesteps. Return = -154.43750635472455
# Episode 666 finished after 84 timesteps. Return = -117.11207266445787
# Episode 667 finished after 91 timesteps. Return = -73.8618263075322
# Episode 668 finished after 73 timesteps. Return = -79.65439858586
# Episode 669 finished after 117 timesteps. Return = -80.93030519506138
# Episode 670 finished after 102 timesteps. Return = -85.23760695344275
# Episode 671 finished after 80 timesteps. Return = -83.89798939049018
# Episode 672 finished after 80 timesteps. Return = -166.71425123772326
# Episode 673 finished after 82 timesteps. Return = -59.66581891297703
# Episode 674 finished after 98 timesteps. Return = -150.42571363186573
# Episode 675 finished after 120 timesteps. Return = -156.53031958475472
# Episode 676 finished after 109 timesteps. Return = -113.5854798008762
# Episode 677 finished after 99 timesteps. Return = -183.65149672858078
# Episode 678 finished after 103 timesteps. Return = -154.43250904058914
# Episode 679 finished after 87 timesteps. Return = -98.87815207909631
# Episode 680 finished after 88 timesteps. Return = -104.2722050164171
# Episode 681 finished after 92 timesteps. Return = -138.73804498632944
# Episode 682 finished after 123 timesteps. Return = -216.1180303889719
# Episode 683 finished after 83 timesteps. Return = -125.64895018625141
# Episode 684 finished after 70 timesteps. Return = -65.5698396256407
# Episode 685 finished after 73 timesteps. Return = -94.89913337523846
# Episode 686 finished after 82 timesteps. Return = -86.53491249274579
# Episode 687 finished after 88 timesteps. Return = -96.58330161387015
# Episode 688 finished after 98 timesteps. Return = -116.90042419414925
# Episode 689 finished after 90 timesteps. Return = -104.76530981540942
# Episode 690 finished after 96 timesteps. Return = -96.51555464506235
# Episode 691 finished after 136 timesteps. Return = -131.16043515054434
# Episode 692 finished after 75 timesteps. Return = -59.55668296935932
# Episode 693 finished after 108 timesteps. Return = -105.65148982306103
# Episode 694 finished after 122 timesteps. Return = -169.52074802672917
# Episode 695 finished after 68 timesteps. Return = -82.38062899351402
# Episode 696 finished after 59 timesteps. Return = -60.744936992638856
# Episode 697 finished after 119 timesteps. Return = -216.1035821271746
# Episode 698 finished after 134 timesteps. Return = -67.81947181399053
# Episode 699 finished after 78 timesteps. Return = -87.83682803643921
# Episode 700 finished after 110 timesteps. Return = -76.07924865024644
# Episode 701 finished after 110 timesteps. Return = -64.89189298554655
# Episode 702 finished after 115 timesteps. Return = -78.76876854946556
# Episode 703 finished after 115 timesteps. Return = -134.85605925672775
# Episode 704 finished after 72 timesteps. Return = -111.34826170661007
# Episode 705 finished after 101 timesteps. Return = -138.60426323720804
# Episode 706 finished after 105 timesteps. Return = -152.64621858851157
# Episode 707 finished after 80 timesteps. Return = -118.13108024184768
# Episode 708 finished after 112 timesteps. Return = -139.60831306270902
# Episode 709 finished after 103 timesteps. Return = -95.31291912725716
# Episode 710 finished after 88 timesteps. Return = -84.00883562760265
# Episode 711 finished after 62 timesteps. Return = -99.99570414784358
# Episode 712 finished after 77 timesteps. Return = -73.60416886405437
# Episode 713 finished after 81 timesteps. Return = -72.96594615494689
# Episode 714 finished after 109 timesteps. Return = -216.06628977990397
# Episode 715 finished after 84 timesteps. Return = -85.493454169421
# Episode 716 finished after 93 timesteps. Return = -89.35504253691587
# Episode 717 finished after 81 timesteps. Return = -103.68613255899878
# Episode 718 finished after 97 timesteps. Return = -136.36089594408762
# Episode 719 finished after 111 timesteps. Return = -122.91672301896453
# Episode 720 finished after 80 timesteps. Return = -96.69365196616167
# Episode 721 finished after 76 timesteps. Return = -102.08294775926757
# Episode 722 finished after 121 timesteps. Return = -104.61103378833988
# Episode 723 finished after 70 timesteps. Return = -123.48409938356899
# Episode 724 finished after 65 timesteps. Return = -48.854486364654235
# Episode 725 finished after 120 timesteps. Return = -156.99495558566406
# Episode 726 finished after 60 timesteps. Return = -78.92568870558976
# Episode 727 finished after 102 timesteps. Return = -139.51594841465163
# Episode 728 finished after 121 timesteps. Return = -119.52598730811286
# Episode 729 finished after 80 timesteps. Return = -138.10638730356527
# Episode 730 finished after 62 timesteps. Return = -62.92537015873758
# Episode 731 finished after 96 timesteps. Return = -169.55590128232672
# Episode 732 finished after 95 timesteps. Return = -132.07955620320183
# Episode 733 finished after 61 timesteps. Return = -81.32699734572822
# Episode 734 finished after 71 timesteps. Return = -117.03822944381167
# Episode 735 finished after 63 timesteps. Return = -73.46615950373592
# Episode 736 finished after 86 timesteps. Return = -104.90516975552404
# Episode 737 finished after 85 timesteps. Return = -122.15920552027454
# Episode 738 finished after 113 timesteps. Return = -168.50520022641672
# ...
# Episode 1866 finished after 85 timesteps. Return = -3.7995316810067976
# Episode 1867 finished after 74 timesteps. Return = -15.0830205404975
# Episode 1868 finished after 86 timesteps. Return = -101.99865107900578
# Episode 1869 finished after 124 timesteps. Return = -351.4798584143488
# Episode 1870 finished after 80 timesteps. Return = -114.25376519839071
# Episode 1871 finished after 79 timesteps. Return = -56.57184799867187
# Episode 1872 finished after 69 timesteps. Return = -52.422455425868506
# Episode 1873 finished after 89 timesteps. Return = -0.8250884395395417
# Episode 1874 finished after 77 timesteps. Return = -109.41793927244515
# Episode 1875 finished after 78 timesteps. Return = -192.70673772388486
# Episode 1876 finished after 103 timesteps. Return = -29.123855273266443
# Episode 1877 finished after 106 timesteps. Return = -149.38873995746073
# Episode 1878 finished after 99 timesteps. Return = -177.78443984931363
# Episode 1879 finished after 71 timesteps. Return = -21.401635621332105
# Episode 1880 finished after 95 timesteps. Return = -286.23105121684165
# Episode 1881 finished after 81 timesteps. Return = -11.296685741999994
# Episode 1882 finished after 91 timesteps. Return = -341.13319420136907
# Episode 1883 finished after 86 timesteps. Return = -51.88569287166257
# Episode 1884 finished after 106 timesteps. Return = -303.4577438560052
# Episode 1885 finished after 92 timesteps. Return = -122.11062274445347
# Episode 1886 finished after 98 timesteps. Return = -107.06490327507272
# Episode 1887 finished after 74 timesteps. Return = -36.69748641399923
# Episode 1888 finished after 87 timesteps. Return = -291.6969376726623
# Episode 1889 finished after 86 timesteps. Return = -224.1890386043656
# Episode 1890 finished after 86 timesteps. Return = -175.82349636348906
# Episode 1891 finished after 114 timesteps. Return = -328.18588180989616
# Episode 1892 finished after 73 timesteps. Return = -112.87130741124129
# Episode 1893 finished after 82 timesteps. Return = -87.11030649563877
# Episode 1894 finished after 71 timesteps. Return = -60.6552137024956
# Episode 1895 finished after 125 timesteps. Return = -129.43257932433045
# Episode 1896 finished after 86 timesteps. Return = -224.14791348038335
# Episode 1897 finished after 131 timesteps. Return = -69.30516625190239
# Episode 1898 finished after 114 timesteps. Return = -323.5155744861545
# Episode 1899 finished after 90 timesteps. Return = -232.29943445547812
# Episode 1900 finished after 98 timesteps. Return = -151.82635113246354
# Episode 1901 finished after 78 timesteps. Return = -58.872558722289014
# Episode 1902 finished after 69 timesteps. Return = -40.41504623591884
# Episode 1903 finished after 78 timesteps. Return = -21.027106211227405
# Episode 1904 finished after 80 timesteps. Return = -139.0762227595126
# Episode 1905 finished after 94 timesteps. Return = -247.5746472099671
# Episode 1906 finished after 1000 timesteps. Return = 175.64047098427054
# Episode 1907 finished after 103 timesteps. Return = -98.59730614578687
# Episode 1908 finished after 81 timesteps. Return = -110.45807426458309
# Episode 1909 finished after 116 timesteps. Return = -227.1330472086096
# Episode 1910 finished after 117 timesteps. Return = -120.026574743915
# Episode 1911 finished after 102 timesteps. Return = -273.68755830559064
# Episode 1912 finished after 90 timesteps. Return = -204.27770270681532
# Episode 1913 finished after 68 timesteps. Return = -65.30954701696878
# Episode 1914 finished after 83 timesteps. Return = -108.24844133240718
# Episode 1915 finished after 63 timesteps. Return = -41.53427864528558
# Episode 1916 finished after 115 timesteps. Return = -84.94226476813412
# Episode 1917 finished after 109 timesteps. Return = -3.4599688694586774
# Episode 1918 finished after 83 timesteps. Return = -118.46964340478792
# Episode 1919 finished after 101 timesteps. Return = -132.4361884848849
# Episode 1920 finished after 106 timesteps. Return = -131.54643136865172
# Episode 1921 finished after 114 timesteps. Return = -69.0176748573895
# Episode 1922 finished after 72 timesteps. Return = -71.52986224513458
# Episode 1923 finished after 68 timesteps. Return = -70.38027761983146
# Episode 1924 finished after 88 timesteps. Return = -56.281242213113245
# Episode 1925 finished after 98 timesteps. Return = -111.81776041684066
# Episode 1926 finished after 65 timesteps. Return = -55.577499565358956
# Episode 1927 finished after 89 timesteps. Return = -38.54828983608074
# Episode 1928 finished after 118 timesteps. Return = -146.17419429268332
# Episode 1929 finished after 77 timesteps. Return = -238.87802656642828
# Episode 1930 finished after 105 timesteps. Return = -67.84945678854885
# Episode 1931 finished after 96 timesteps. Return = -182.72304168056726
# Episode 1932 finished after 104 timesteps. Return = -294.8468279431055
# Episode 1933 finished after 146 timesteps. Return = -115.64637195592533
# Episode 1934 finished after 75 timesteps. Return = -163.11397103616292
# Episode 1935 finished after 110 timesteps. Return = -57.73862750326366
# Episode 1936 finished after 161 timesteps. Return = -115.69111962084648
# Episode 1937 finished after 103 timesteps. Return = -340.17104246789387
# Episode 1938 finished after 98 timesteps. Return = -285.36225000523973
# Episode 1939 finished after 97 timesteps. Return = -209.09459747178227
# Episode 1940 finished after 121 timesteps. Return = -90.0054917430236
# Episode 1941 finished after 82 timesteps. Return = -31.25115584841572
# Episode 1942 finished after 78 timesteps. Return = -16.141406445105986
# Episode 1943 finished after 66 timesteps. Return = -87.59352412583812
# Episode 1944 finished after 118 timesteps. Return = -254.4467634084532
# Episode 1945 finished after 79 timesteps. Return = -128.09557179795922
# Episode 1946 finished after 70 timesteps. Return = -11.264799342787626
# Episode 1947 finished after 108 timesteps. Return = -166.66173397140022
# Episode 1948 finished after 75 timesteps. Return = -14.916452136069736
# Episode 1949 finished after 106 timesteps. Return = -176.48364497879135
# Episode 1950 finished after 119 timesteps. Return = -272.9363263832763
# Episode 1951 finished after 59 timesteps. Return = -119.82935012944895
# Episode 1952 finished after 98 timesteps. Return = -231.40374806527745
# Episode 1953 finished after 91 timesteps. Return = -83.69075381258412
# Episode 1954 finished after 122 timesteps. Return = -94.19560062142756
# Episode 1955 finished after 91 timesteps. Return = -112.93266103292417
# Episode 1956 finished after 67 timesteps. Return = -166.8623805581858
# Episode 1957 finished after 103 timesteps. Return = -181.18088254807236
# Episode 1958 finished after 100 timesteps. Return = -186.99489337691153
# Episode 1959 finished after 86 timesteps. Return = -87.52312060072776
# Episode 1960 finished after 107 timesteps. Return = -153.09282783868807
# Episode 1961 finished after 69 timesteps. Return = -41.989056723956224
# Episode 1962 finished after 134 timesteps. Return = -325.1456171103845
# Episode 1963 finished after 72 timesteps. Return = -160.41130806676196
# Episode 1964 finished after 92 timesteps. Return = -297.87438956316305
# Episode 1965 finished after 66 timesteps. Return = -102.981916859791
# Episode 1966 finished after 61 timesteps. Return = -41.214858218812
# Episode 1967 finished after 110 timesteps. Return = -191.98854039698398
# Episode 1968 finished after 89 timesteps. Return = -35.12474721163788
# Episode 1969 finished after 106 timesteps. Return = -187.17244960436506
# Episode 1970 finished after 115 timesteps. Return = -251.96833662070193
# Episode 1971 finished after 95 timesteps. Return = -56.695087978048676
# Episode 1972 finished after 81 timesteps. Return = -95.1098894039616
# Episode 1973 finished after 107 timesteps. Return = -178.9891311724874
# Episode 1974 finished after 123 timesteps. Return = -223.30274533870747
# Episode 1975 finished after 70 timesteps. Return = -48.96222883648506
# Episode 1976 finished after 80 timesteps. Return = -123.53415040959284
# Episode 1977 finished after 75 timesteps. Return = -4.8288500032496415
# Episode 1978 finished after 85 timesteps. Return = -155.30530456034592
# Episode 1979 finished after 88 timesteps. Return = -140.1121290879525
# Episode 1980 finished after 111 timesteps. Return = -143.0361883212949
# Episode 1981 finished after 76 timesteps. Return = -99.67249564037765
# Episode 1982 finished after 74 timesteps. Return = -101.94039279677574
# Episode 1983 finished after 64 timesteps. Return = -122.78729910036274
# Episode 1984 finished after 93 timesteps. Return = -79.20324129672795
# Episode 1985 finished after 74 timesteps. Return = -19.982164582815315
# Episode 1986 finished after 130 timesteps. Return = -67.94082806715207
# Episode 1987 finished after 117 timesteps. Return = -116.08389010827378
# Episode 1988 finished after 97 timesteps. Return = -189.3693376917211
# Episode 1989 finished after 73 timesteps. Return = -86.4895605175673
# Episode 1990 finished after 106 timesteps. Return = -168.43916642640767
# Episode 1991 finished after 101 timesteps. Return = -90.51658131023275
# Episode 1992 finished after 107 timesteps. Return = -77.58949257220769
# Episode 1993 finished after 63 timesteps. Return = -97.51369547926028
# Episode 1994 finished after 87 timesteps. Return = -37.441840755314445
# Episode 1995 finished after 112 timesteps. Return = -241.59206598971505
# Episode 1996 finished after 75 timesteps. Return = -154.83231386372387
# Episode 1997 finished after 120 timesteps. Return = -133.9120505372395
# Episode 1998 finished after 103 timesteps. Return = -203.7159829652414
# Episode 1999 finished after 86 timesteps. Return = -142.6966585150976
# Episode 2000 finished after 89 timesteps. Return = -352.3770920624775
# Episode 2001 finished after 87 timesteps. Return = -141.79576692566104
# Episode 2002 finished after 86 timesteps. Return = -84.5609856527209
# Episode 2003 finished after 95 timesteps. Return = -236.14904603607116
# Episode 2004 finished after 110 timesteps. Return = -93.77372321566033
# Episode 2005 finished after 79 timesteps. Return = -97.05628795002181
# Episode 2006 finished after 63 timesteps. Return = -79.80324861228561
# Episode 2007 finished after 121 timesteps. Return = 63.13170502373001
# Episode 2008 finished after 98 timesteps. Return = -150.73278820417295
# Episode 2009 finished after 91 timesteps. Return = -132.84617581069242
# Episode 2010 finished after 93 timesteps. Return = -98.79532041294087
# Episode 2011 finished after 103 timesteps. Return = -83.29829268379893
# Episode 2012 finished after 76 timesteps. Return = -90.18063906743717
# Episode 2013 finished after 112 timesteps. Return = -34.99881545690022
# Episode 2014 finished after 76 timesteps. Return = -77.86213448214838
# Episode 2015 finished after 71 timesteps. Return = -181.35190048534696
# Episode 2016 finished after 82 timesteps. Return = -49.85547948611041
# Episode 2017 finished after 89 timesteps. Return = -28.695712933911423
# Episode 2018 finished after 97 timesteps. Return = -109.78608827138093
# Episode 2019 finished after 68 timesteps. Return = -49.33587998370753
# Episode 2020 finished after 86 timesteps. Return = -263.6134628231316
# Episode 2021 finished after 122 timesteps. Return = -158.1424332075643
# Episode 2022 finished after 80 timesteps. Return = -78.8242239694915
# Episode 2023 finished after 66 timesteps. Return = -122.38844120831365
# Episode 2024 finished after 88 timesteps. Return = 48.57000628026995
# Episode 2025 finished after 84 timesteps. Return = -190.0579766554328
# Episode 2026 finished after 85 timesteps. Return = -67.23031606016355
# Episode 2027 finished after 103 timesteps. Return = -85.06547143752553
# Episode 2028 finished after 88 timesteps. Return = -76.34077682738183
# Episode 2029 finished after 113 timesteps. Return = -249.57294822617126
# Episode 2030 finished after 119 timesteps. Return = -179.77298347261325
# Episode 2031 finished after 78 timesteps. Return = -98.2945656820486
# Episode 2032 finished after 78 timesteps. Return = -151.1646212357464
# Episode 2033 finished after 100 timesteps. Return = -246.29534383894946
# Episode 2034 finished after 71 timesteps. Return = -115.78032564641258
# Episode 2035 finished after 83 timesteps. Return = -5.70188409222736
# Episode 2036 finished after 107 timesteps. Return = -182.28708861242143
# Episode 2037 finished after 80 timesteps. Return = -89.06757412727862
# Episode 2038 finished after 113 timesteps. Return = -117.71245561659516
# Episode 2039 finished after 86 timesteps. Return = -11.182854625011473
# Episode 2040 finished after 78 timesteps. Return = -143.7440240910212
# Episode 2041 finished after 102 timesteps. Return = -241.38908754577758
# Episode 2042 finished after 73 timesteps. Return = -116.2572295212958
# Episode 2043 finished after 81 timesteps. Return = -117.81112873599623
# Episode 2044 finished after 97 timesteps. Return = -343.90187818434015
# Episode 2045 finished after 127 timesteps. Return = -287.41723648145
# Episode 2046 finished after 92 timesteps. Return = -163.19596298219466
# Episode 2047 finished after 98 timesteps. Return = -112.80333004352144
# Episode 2048 finished after 83 timesteps. Return = -157.9354933558855
# Episode 2049 finished after 121 timesteps. Return = -87.36913304209017
# Episode 2050 finished after 100 timesteps. Return = -112.20864805942728
# Episode 2051 finished after 100 timesteps. Return = -176.31565019708228
# Episode 2052 finished after 122 timesteps. Return = -249.69824838852037
# Episode 2053 finished after 81 timesteps. Return = -87.24233211519658
# Episode 2054 finished after 77 timesteps. Return = -4.490095245396944
# Episode 2055 finished after 105 timesteps. Return = -146.094252833781
# Episode 2056 finished after 118 timesteps. Return = -134.54119918045294
# Episode 2057 finished after 106 timesteps. Return = -280.46130573742096
# Episode 2058 finished after 106 timesteps. Return = -205.44412047476726
# Episode 2059 finished after 71 timesteps. Return = -63.49238069575415
# Episode 2060 finished after 84 timesteps. Return = -91.56439039751396
# Episode 2061 finished after 83 timesteps. Return = -92.54024651082656
# Episode 2062 finished after 66 timesteps. Return = -123.62079093516668
# Episode 2063 finished after 114 timesteps. Return = -166.74515289341218
# Episode 2064 finished after 68 timesteps. Return = -82.45976224363793
# Episode 2065 finished after 75 timesteps. Return = -187.04629426202695
# Episode 2066 finished after 146 timesteps. Return = 13.385553069859554
# Episode 2067 finished after 114 timesteps. Return = -188.40181363329611
# Episode 2068 finished after 83 timesteps. Return = -150.06896240202147
# Episode 2069 finished after 67 timesteps. Return = -150.64498811625515
# Episode 2070 finished after 102 timesteps. Return = -79.14562455957616
# Episode 2071 finished after 75 timesteps. Return = -83.19923898326715
# Episode 2072 finished after 82 timesteps. Return = -115.1715655920146
# Episode 2073 finished after 109 timesteps. Return = -120.21874220938076
# Episode 2074 finished after 80 timesteps. Return = -105.76977962752366
# Episode 2075 finished after 66 timesteps. Return = -91.67761262412168
# Episode 2076 finished after 106 timesteps. Return = -237.79104496348899
# Episode 2077 finished after 122 timesteps. Return = -99.24278136282159
# Episode 2078 finished after 76 timesteps. Return = -30.896545153378483
# Episode 2079 finished after 92 timesteps. Return = -58.31661129519672
# Episode 2080 finished after 113 timesteps. Return = -219.64150044477546
# Episode 2081 finished after 65 timesteps. Return = -89.81533948030405
# Episode 2082 finished after 116 timesteps. Return = -135.33102885205128
# Episode 2083 finished after 103 timesteps. Return = -215.86749181948022
# Episode 2084 finished after 105 timesteps. Return = -192.53331102964893
# Episode 2085 finished after 102 timesteps. Return = -254.8444673981078
# Episode 2086 finished after 121 timesteps. Return = -237.26226323361652
# Episode 2087 finished after 88 timesteps. Return = -295.53249398916984
# Episode 2088 finished after 108 timesteps. Return = -212.084833074075
# Episode 2089 finished after 112 timesteps. Return = -104.72452356164585
# Episode 2090 finished after 121 timesteps. Return = -231.5455355014792

# %%
#torch.save(agent.state_dict(), 'checkpoints/lunar_lander_64x64_checkpoint_0.pt')
#agent.load_state_dict(torch.load('checkpoints/lunar_lander_32x32_checkpoint_0.pt'))

# %%
visualise_agent(greedy_policy, command=[150, 400], n=5)
# Out:
# Episode 0 finished after 833 timesteps. Return = -360.375805006002

# %%
visualise_agent(stochastic_policy, command=[150, 400], n=5)
# Out:
# Episode 0 finished after 213 timesteps. Return = -27.11786348432311
# Episode 1 finished after 271 timesteps. Return = -226.95918413035955
# Episode 2 finished after 325 timesteps. Return = -26.1805768711521

# %%
print([mem['return'] for mem in replay_buffer])

# %% [markdown]
# # Previous Code

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64):
    all_costs = []
    for i in range(n_updates):
        batch_input = np.zeros((batch_size, np.prod(env.observation_space.shape)+2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_horizon = np.random.randint(1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_mem_idx = np.random.randint(0, len(replay_buffer[sample_episode]['observation'])+1-sample_horizon)
            sample_mem = replay_buffer[sample_episode]['observation'][sample_mem_idx]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_mem_idx]
            batch_input[b] = network_input
            batch_label[b] = label
        batch_input = torch.tensor(batch_input).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_input)
        cost = F.cross_entropy(pred, batch_label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train_net(policy_net, episode_mem, n_samples = 5): #stochastic gradient descent
    all_costs = []
    for i in range(n_samples):
        sample_horizon = np.random.randint(1, len(episode_mem['observation'])+1)
        sample_mem_idx = np.random.randint(0, len(episode_mem['observation'])+1-sample_horizon)
        sample_mem = episode_mem['observation'][sample_mem_idx]
        sample_desired_reward = sum(episode_mem['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
        network_input = torch.tensor(np.append(sample_mem, [sample_desired_reward, sample_horizon])).double()
        label = torch.tensor([episode_mem['action'][sample_mem_idx]]).double()
        
        pred = policy_net(network_input)
        cost = F.binary_cross_entropy(pred, label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train(policy_net, n_episodes=100):
    global i_episode
    global epsilon
    try:
        for _ in range(n_episodes):
            observation = env.reset()
            episode_mem = {'observation':[],
                            'action':[],
                            'reward':[],
                            'done':[]}
            done=False
            while not done:
                network_input = torch.tensor(np.append(observation, [desired_reward, command_horizon])).double()
                action_prob = policy_net(network_input)
                action = np.random.binomial(1, action_prob.item())
                #action = int(action_prob.item()>0.5)
                if np.random.rand()<epsilon: action = np.random.randint(0, 2)
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                episode_mem['done'].append(done)
                
                observation=new_observation
                epsilon*=0.999
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            mean_cost = train_net(policy_net, episode_mem)
            
            i_episode+=1
            print("Episode {} finished after {} timesteps. Epsilon={} Mean Cost={}".format(i_episode, len(episode_mem['observation']), epsilon, mean_cost))
        env.close()
    except KeyboardInterrupt:
        env.close()

# %% [markdown]
# ## Previous version

# %%
import gym
import time
import torch
import numpy as np
from copy import deepcopy
import torch.nn.functional as F

env = gym.make('CartPole-v1')

def random_policy(obs):
    return np.random.randint(env.action_space.n)

#Visualise agent function
def visualise_agent(policy, command, n=5):
    try:
        for trial_i in range(n):
            current_command = deepcopy(command)
            observation = env.reset()
            done=False
            t=0
            episode_return=0
            while not done:
                env.render()
                network_input = torch.tensor(np.append(observation, current_command)).double()
                policy_action = policy(network_input)
                observation, reward, done, info = env.step(policy_action)
                episode_return+=reward
                #time.sleep(0.1)
                current_command[0]-= reward
                current_command[1] = max(1, current_command[1]-1)
                
                t+=1
            env.render()
            time.sleep(1.5)
            print("Episode {} finished after {} timesteps. Return = {}".format(trial_i, t, episode_return))
        env.close()
    except KeyboardInterrupt:
        env.close()
        
#Behaviour function - Neural Network
class FCNN_AGENT(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(np.prod(env.observation_space.shape)+2, 10),
            torch.nn.ReLU(),
            torch.nn.Linear(10, 10),
            torch.nn.ReLU(),
            torch.nn.Linear(10, env.action_space.n)
        )
    
    def forward(self, x):
        x = self.fc(x)
        return F.softmax(x, dim=-1)
    
    def create_optimizer(self, lr):
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)

#Full the replay buffer with more experience
def collect_experience(policy, replay_buffer, replay_size, last_few, n_episodes=100, log_to_tensorboard=True):
    global i_episode
    init_replay_buffer = deepcopy(replay_buffer)
    try:
        for _ in range(n_episodes):
            command = sample_command(init_replay_buffer, last_few)
            if log_to_tensorboard: writer.add_scalar('Command desired reward', command[0], i_episode)    # write loss to a graph
            if log_to_tensorboard: writer.add_scalar('Command horizon', command[1], i_episode)    # write loss to a graph
            observation = env.reset()
            episode_mem = {'observation':[],
                            'action':[],
                            'reward':[]}
            done=False
            while not done:
                network_input = torch.tensor(np.append(observation, command)).double()
                action = policy(network_input)
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                
                observation=new_observation
                #command[0]-= reward
                command[0] = max(1, command[0]-reward)
                command[1] = max(1, command[1]-1)
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            replay_buffer.append(episode_mem)
            i_episode+=1
            if log_to_tensorboard: writer.add_scalar('Return', sum(episode_mem['reward']), i_episode)    # write loss to a graph
            print("Episode {} finished after {} timesteps. Return = {}".format(i_episode, len(episode_mem['observation']), sum(episode_mem['reward'])))
        env.close()
    except KeyboardInterrupt:
        env.close()
    replay_buffer = sorted(replay_buffer, key=lambda x:x['return'])[-replay_size:]
    return replay_buffer

#Sample exploratory command
def sample_command(replay_buffer, last_few):
    if len(replay_buffer)==0:
        return [1, 1]
    else:
        command_samples = replay_buffer[-last_few:]
        lengths = [mem['episode_len'] for mem in command_samples]
        returns = [mem['return'] for mem in command_samples]
        mean_return, std_return = np.mean(returns), np.std(returns)
        command_horizon = np.mean(lengths)
        desired_reward = np.random.uniform(mean_return, mean_return+std_return)
        return [desired_reward, command_horizon]

#Improve behviour function by training on replay buffer
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64):
    all_costs = []
    for i in range(n_updates):
        batch_input = np.zeros((batch_size, np.prod(env.observation_space.shape)+2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
            sample_t2 = len(replay_buffer[sample_episode]['observation'])
            sample_horizon = sample_t2-sample_t1
            sample_mem = replay_buffer[sample_episode]['observation'][sample_t1]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_t1:sample_t2])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_t1]
            batch_input[b] = network_input
            batch_label[b] = label
        batch_input = torch.tensor(batch_input).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_input)
        cost = F.cross_entropy(pred, batch_label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

#Return a greedy policy from a given network
def create_greedy_policy(policy_network):
    def policy(obs):
        action_prob = policy_network(obs)
        action = np.argmax(action_prob.detach().numpy())
        return action
    return policy

#Return a stochastic policy from a given network
def create_stochastic_policy(policy_network):
    def policy(obs):
        action_prob = policy_network(obs)
        action_sample = np.random.multinomial(1, action_prob.detach().numpy())
        action = np.argmax(action_sample)
        return action
    return policy


#Define hyperparameters, initialize behaviour function
i_episode=0
replay_buffer = []
replay_size = 600
last_few = 50
log_to_tensorboard = False 

batch_size = 64
n_warm_up_episodes = 50
n_episodes_per_iter = 50
n_updates_per_iter = 100

lr = 0.001
agent = FCNN_AGENT().double()
agent.create_optimizer(lr)

stochastic_policy = create_stochastic_policy(agent)
greedy_policy = create_greedy_policy(agent)

# SET UP TRAINING VISUALISATION
if log_to_tensorboard: from torch.utils.tensorboard import SummaryWriter
if log_to_tensorboard: writer = SummaryWriter() # we will use this to show our models performance on a graph using tensorboard

#Collect warm up episodes
replay_buffer = collect_experience(random_policy, replay_buffer, replay_size, last_few, n_warm_up_episodes, log_to_tensorboard)
train_net(agent, replay_buffer, n_updates=n_updates_per_iter, batch_size=batch_size)

#Collect experience and train behaviour function for given number of iterations
n_iters = 1000
for i in range(n_iters):
    replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
    train_net(agent, replay_buffer, n_updates=n_updates_per_iter, batch_size=batch_size)

#Visualise final trained agent
visualise_agent(greedy_policy, command=[250, 200], n=5)
