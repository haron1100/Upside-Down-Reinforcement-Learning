# %% [markdown]
# ### This file is for testing radical changes to the codebase. Upside Down Reinforcement Learning.py is the working version.

# %%
import gym
env = gym.make('LunarLander-v2')

# %%
#command takes form [derired reward, desired horizon]
import numpy as np
def random_policy(obs, command):
    return np.random.randint(env.action_space.n)

# %%
import time
from copy import deepcopy
#Visualise agent function
def visualise_agent(policy, command, n=5):
    try:
        for trial_i in range(n):
            current_command = deepcopy(command)
            observation = env.reset()
            done=False
            t=0
            episode_return=0
            while not done:
                env.render()
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                observation, reward, done, info = env.step(action)
                episode_return+=reward
                current_command[0]-= reward
                current_command[1] = max(1, current_command[1]-1)
                t+=1
            env.render()
            time.sleep(1.5)
            print("Episode {} finished after {} timesteps. Return = {}".format(trial_i, t, episode_return))
        env.close()
    except KeyboardInterrupt:
        env.close()

# %%
#visualise_agent(random_policy, command=[500, 500], 1)

# %%
import torch
import torch.nn.functional as F

class FCNN_AGENT(torch.nn.Module):
    def __init__(self, command_scale):
        super().__init__()
        hidden_size=64
        self.command_scale=command_scale
        self.observation_embedding = torch.nn.Sequential(
            torch.nn.Linear(np.prod(env.observation_space.shape), hidden_size),
            torch.nn.Sigmoid()
        )
        self.command_embedding = torch.nn.Sequential(
            torch.nn.Linear(2, hidden_size),
            torch.nn.Sigmoid()
        )
        self.to_output = torch.nn.Sequential(
            torch.nn.Linear(hidden_size, hidden_size),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_size, env.action_space.n)
        )
    
    def forward(self, observation, command):
        obs_emebdding = self.observation_embedding(observation)
        cmd_embedding = self.command_embedding(command*self.command_scale)
        embedding = torch.mul(obs_emebdding, cmd_embedding)
        action_prob_logits = self.to_output(embedding)
        return action_prob_logits
    
    def create_optimizer(self, lr):
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)

# %%
from copy import deepcopy
def collect_experience(policy, replay_buffer, replay_size, last_few, n_episodes=100, log_to_tensorboard=True):
    global i_episode
    init_replay_buffer = deepcopy(replay_buffer)
    try:
        for _ in range(n_episodes):
            command = sample_command(init_replay_buffer, last_few)
            writer.add_scalar('Command desired reward/Episode', command[0], i_episode)    # write loss to a graph
            writer.add_scalar('Command horizon/Episode', command[1], i_episode)    # write loss to a graph
            observation = env.reset()
            episode_mem = {'observation':[],
                           'action':[],
                           'reward':[],}
            done=False
            while not done:
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                
                observation=new_observation
                command[0]-= reward
                command[1] = max(1, command[1]-1)
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            replay_buffer.append(episode_mem)
            i_episode+=1
            if log_to_tensorboard: writer.add_scalar('Return/Episode', sum(episode_mem['reward']), i_episode)    # write loss to a graph
            print("Episode {} finished after {} timesteps. Return = {}".format(i_episode, len(episode_mem['observation']), sum(episode_mem['reward'])))
        env.close()
    except KeyboardInterrupt:
        env.close()
    replay_buffer = sorted(replay_buffer, key=lambda x:x['return'])[-replay_size:]
    return replay_buffer

def sample_command(replay_buffer, last_few):
    if len(replay_buffer)==0:
        return [1, 1]
    else:
        command_samples = replay_buffer[-last_few:]
        lengths = [mem['episode_len'] for mem in command_samples]
        returns = [mem['return'] for mem in command_samples]
        mean_return, std_return = np.mean(returns), np.std(returns)
        command_horizon = np.mean(lengths)
        desired_reward = np.random.uniform(mean_return, mean_return+std_return)
        return [desired_reward, command_horizon]

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64, log_to_tensorboard=True):
    global i_updates
    all_costs = []
    for i in range(n_updates):
        batch_observations = np.zeros((batch_size, np.prod(env.observation_space.shape)))
        batch_commands = np.zeros((batch_size, 2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
            sample_t2 = len(replay_buffer[sample_episode]['observation'])
            ##sample_t2 = np.random.randint(sample_t1+1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_horizon = sample_t2-sample_t1
            sample_mem = replay_buffer[sample_episode]['observation'][sample_t1]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_t1:sample_t2])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_t1]
            batch_observations[b] = sample_mem
            batch_commands[b] = [sample_desired_reward, sample_horizon]
            batch_label[b] = label
        batch_observations = torch.tensor(batch_observations).double()
        batch_commands = torch.tensor(batch_commands).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_observations, batch_commands)
        cost = F.cross_entropy(pred, batch_label)
        if log_to_tensorboard: writer.add_scalar('Cost/NN update', cost.item() , i_updates)    # write loss to a graph
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
        i_updates+=1
    return np.mean(all_costs)

# %%
def create_greedy_policy(policy_network):
    def policy(obs, command):
        action_logits = policy_network(obs, command)
        action_probs = F.softmax(action_logits, dim=-1)
        action = np.argmax(action_probs.detach().numpy())
        return action
    return policy

def create_stochastic_policy(policy_network):
    def policy(obs, command):
        action_logits = policy_network(obs, command)
        action_probs = F.softmax(action_logits, dim=-1)
        action = torch.distributions.Categorical(action_probs).sample().item()
        return action
    return policy

# %%
i_episode=0
i_updates=0 #number of parameter updates to the neural network
replay_buffer = []
log_to_tensorboard = True 

replay_size = 700
last_few = 50
batch_size = 256
n_warm_up_episodes = 50
n_episodes_per_iter = 25
n_updates_per_iter = 15
command_scale = 0.02
lr = 0.001

agent = FCNN_AGENT(command_scale).double()
agent.create_optimizer(lr)

stochastic_policy = create_stochastic_policy(agent)
greedy_policy = create_greedy_policy(agent)

# %%
# SET UP TRAINING VISUALISATION
# SET UP TRAINING VISUALISATION
if log_to_tensorboard: from torch.utils.tensorboard import SummaryWriter
if log_to_tensorboard: writer = SummaryWriter() # we will use this to show our models performance on a graph using tensorboard

# %%
#Collect warm up episodes
replay_buffer = collect_experience(random_policy, replay_buffer, replay_size, last_few, n_warm_up_episodes, log_to_tensorboard)
train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
# Out:
# Episode 1 finished after 64 timesteps. Return = -84.60078681057627
# Episode 2 finished after 95 timesteps. Return = -120.78480124507686
# Episode 3 finished after 63 timesteps. Return = -172.14825381248892
# Episode 4 finished after 71 timesteps. Return = -91.4286045161926
# Episode 5 finished after 88 timesteps. Return = -94.85860439292763
# Episode 6 finished after 103 timesteps. Return = -243.6307219272219
# Episode 7 finished after 94 timesteps. Return = -321.5253342006809
# Episode 8 finished after 123 timesteps. Return = -198.62381016401844
# Episode 9 finished after 71 timesteps. Return = -132.11189604460625
# Episode 10 finished after 67 timesteps. Return = -124.86243874045171
# Episode 11 finished after 85 timesteps. Return = -133.11606950032888
# Episode 12 finished after 67 timesteps. Return = -71.45064283024958
# Episode 13 finished after 92 timesteps. Return = -253.01980387275094
# Episode 14 finished after 127 timesteps. Return = -106.47646839864615
# Episode 15 finished after 70 timesteps. Return = -107.19931140912696
# Episode 16 finished after 69 timesteps. Return = -120.7424664893191
# Episode 17 finished after 98 timesteps. Return = -305.444599497816
# Episode 18 finished after 127 timesteps. Return = -88.10822968861359
# Episode 19 finished after 72 timesteps. Return = -176.90154311340746
# Episode 20 finished after 77 timesteps. Return = -104.81129847693813
# Episode 21 finished after 94 timesteps. Return = -273.0169641551355
# Episode 22 finished after 120 timesteps. Return = -90.51066751364802
# Episode 23 finished after 82 timesteps. Return = -18.52774758676989
# Episode 24 finished after 67 timesteps. Return = -54.781499964066214
# Episode 25 finished after 63 timesteps. Return = -75.20863367299408
# Episode 26 finished after 99 timesteps. Return = -530.8998429759944
# Episode 27 finished after 88 timesteps. Return = -189.65709267598874
# Episode 28 finished after 124 timesteps. Return = -120.0951558446635
# Episode 29 finished after 120 timesteps. Return = -130.96101578425362
# Episode 30 finished after 69 timesteps. Return = -89.68257921597733
# Episode 31 finished after 80 timesteps. Return = -144.00020554787457
# Episode 32 finished after 136 timesteps. Return = -187.2797833252139
# Episode 33 finished after 94 timesteps. Return = 38.0855124653975
# Episode 34 finished after 90 timesteps. Return = -66.05539152789046
# Episode 35 finished after 93 timesteps. Return = -231.7799850840671
# Episode 36 finished after 74 timesteps. Return = -74.73719103526082
# Episode 37 finished after 78 timesteps. Return = -185.5382589978285
# Episode 38 finished after 79 timesteps. Return = -99.59247023897153
# Episode 39 finished after 69 timesteps. Return = -123.86579378616689
# Episode 40 finished after 81 timesteps. Return = -111.66722349296997
# Episode 41 finished after 123 timesteps. Return = -28.90174910927871
# Episode 42 finished after 105 timesteps. Return = -130.02828892086552
# Episode 43 finished after 113 timesteps. Return = -292.0937403974524
# Episode 44 finished after 101 timesteps. Return = -131.94598273242678
# Episode 45 finished after 94 timesteps. Return = -266.38749940032324
# Episode 46 finished after 78 timesteps. Return = -253.23703060898978
# Episode 47 finished after 69 timesteps. Return = -106.6913483578025
# Episode 48 finished after 84 timesteps. Return = -97.43167785518133
# Episode 49 finished after 81 timesteps. Return = -196.9155464156821
# Episode 50 finished after 84 timesteps. Return = -85.24686060222278
# 1.385637102955703

# %%
n_iters = 1000
for i in range(n_iters):
    replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
    train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
# Out:
# Episode 51 finished after 107 timesteps. Return = -113.07739390702349
# Episode 52 finished after 80 timesteps. Return = -316.08569869815676
# Episode 53 finished after 66 timesteps. Return = -36.60251067892713
# Episode 54 finished after 87 timesteps. Return = -69.98392383362653
# Episode 55 finished after 101 timesteps. Return = -270.38410966312466
# Episode 56 finished after 111 timesteps. Return = -110.95990485962744
# Episode 57 finished after 105 timesteps. Return = -166.47410984245352
# Episode 58 finished after 97 timesteps. Return = -156.73295510125288
# Episode 59 finished after 125 timesteps. Return = -374.63088816841736
# Episode 60 finished after 102 timesteps. Return = -104.08481077087355
# Episode 61 finished after 77 timesteps. Return = -215.91439727583327
# Episode 62 finished after 97 timesteps. Return = -186.6302828059158
# Episode 63 finished after 93 timesteps. Return = -122.6390440332899
# Episode 64 finished after 116 timesteps. Return = -83.1758552525774
# Episode 65 finished after 108 timesteps. Return = -223.83206727903246
# Episode 66 finished after 121 timesteps. Return = -189.31181578411915
# Episode 67 finished after 90 timesteps. Return = -354.7756866461989
# Episode 68 finished after 64 timesteps. Return = -132.07515587561477
# Episode 69 finished after 88 timesteps. Return = -113.56745377728002
# Episode 70 finished after 95 timesteps. Return = -229.02879713203214
# Episode 71 finished after 86 timesteps. Return = -127.13408997358573
# Episode 72 finished after 75 timesteps. Return = -156.21594697586258
# Episode 73 finished after 89 timesteps. Return = -128.496172849227
# Episode 74 finished after 83 timesteps. Return = -155.92516673016746
# Episode 75 finished after 66 timesteps. Return = -164.90555612014577
# Episode 76 finished after 89 timesteps. Return = -193.939342604709
# Episode 77 finished after 115 timesteps. Return = -404.34848384181396
# Episode 78 finished after 71 timesteps. Return = -88.61062891549838
# Episode 79 finished after 101 timesteps. Return = -168.22231711539257
# Episode 80 finished after 83 timesteps. Return = -415.2758272192447
# Episode 81 finished after 93 timesteps. Return = -267.913735361665
# Episode 82 finished after 83 timesteps. Return = -391.8702669159874
# Episode 83 finished after 113 timesteps. Return = -268.2861169566488
# Episode 84 finished after 70 timesteps. Return = -123.01314006968273
# Episode 85 finished after 117 timesteps. Return = -93.51150637497133
# Episode 86 finished after 78 timesteps. Return = -117.25936745484623
# Episode 87 finished after 104 timesteps. Return = -464.9250288855992
# Episode 88 finished after 138 timesteps. Return = -423.1458459603063
# Episode 89 finished after 111 timesteps. Return = -79.70712393610525
# Episode 90 finished after 77 timesteps. Return = -142.37096396019416
# Episode 91 finished after 111 timesteps. Return = -87.45291127146486
# Episode 92 finished after 114 timesteps. Return = -483.2406231817303
# Episode 93 finished after 122 timesteps. Return = -334.44310426774996
# Episode 94 finished after 66 timesteps. Return = -125.88517000126697
# Episode 95 finished after 90 timesteps. Return = -545.3988278702744
# Episode 96 finished after 91 timesteps. Return = -261.1415083422816
# Episode 97 finished after 75 timesteps. Return = -149.41295379853875
# Episode 98 finished after 69 timesteps. Return = -104.62406433593719
# Episode 99 finished after 71 timesteps. Return = -213.25701957880682
# Episode 100 finished after 110 timesteps. Return = -137.9306090243531
# Episode 101 finished after 101 timesteps. Return = -349.9944546861651
# Episode 102 finished after 119 timesteps. Return = -215.23991036409154
# Episode 103 finished after 94 timesteps. Return = -116.09371751384418
# Episode 104 finished after 91 timesteps. Return = -206.81796753887983
# Episode 105 finished after 71 timesteps. Return = -126.90114151184301
# Episode 106 finished after 114 timesteps. Return = -138.60390896431485
# Episode 107 finished after 116 timesteps. Return = -312.0909866774613
# Episode 108 finished after 104 timesteps. Return = -72.08443373219441
# Episode 109 finished after 118 timesteps. Return = -117.93260488832286
# Episode 110 finished after 124 timesteps. Return = -188.15653636021497
# Episode 111 finished after 118 timesteps. Return = -261.9244129136312
# Episode 112 finished after 78 timesteps. Return = -195.74692951957542
# Episode 113 finished after 73 timesteps. Return = -97.97012030816214
# Episode 114 finished after 95 timesteps. Return = -337.3227228649556
# Episode 115 finished after 98 timesteps. Return = -455.704271381078
# Episode 116 finished after 85 timesteps. Return = -384.99425112388815
# Episode 117 finished after 104 timesteps. Return = -303.1316832041882
# Episode 118 finished after 64 timesteps. Return = -71.34134555969008
# Episode 119 finished after 100 timesteps. Return = -105.32155022647956
# Episode 120 finished after 119 timesteps. Return = -326.5195282653432
# Episode 121 finished after 96 timesteps. Return = -76.03519690932652
# Episode 122 finished after 67 timesteps. Return = -91.85040064819825
# Episode 123 finished after 82 timesteps. Return = -390.0539311670266
# Episode 124 finished after 89 timesteps. Return = -414.86101297064937
# Episode 125 finished after 124 timesteps. Return = -169.94852964376298
# Episode 126 finished after 84 timesteps. Return = -110.73326055357735
# Episode 127 finished after 84 timesteps. Return = -106.20876124004627
# Episode 128 finished after 97 timesteps. Return = -132.01126858671563
# Episode 129 finished after 94 timesteps. Return = -105.44041730209484
# Episode 130 finished after 101 timesteps. Return = -362.5541856611734
# Episode 131 finished after 89 timesteps. Return = -273.8536331548987
# Episode 132 finished after 69 timesteps. Return = -239.01641197537114
# Episode 133 finished after 89 timesteps. Return = -117.1404518313605
# Episode 134 finished after 77 timesteps. Return = -82.68427745912703
# Episode 135 finished after 101 timesteps. Return = -226.44740943336436
# Episode 136 finished after 110 timesteps. Return = -329.4778883463433
# Episode 137 finished after 112 timesteps. Return = -187.77321177817169
# Episode 138 finished after 91 timesteps. Return = -135.0355216176174
# Episode 139 finished after 104 timesteps. Return = -183.4695683828024
# Episode 140 finished after 96 timesteps. Return = -377.3633135231588
# Episode 141 finished after 63 timesteps. Return = -136.21526671222676
# Episode 142 finished after 75 timesteps. Return = -101.12722636675412
# Episode 143 finished after 73 timesteps. Return = -127.8544864543617
# Episode 144 finished after 111 timesteps. Return = -75.48537809145779
# Episode 145 finished after 85 timesteps. Return = -417.5800419735417
# Episode 146 finished after 86 timesteps. Return = -390.49307819864674
# Episode 147 finished after 75 timesteps. Return = -281.52880281706945
# Episode 148 finished after 120 timesteps. Return = -259.5256955345527
# Episode 149 finished after 86 timesteps. Return = -294.9410523574034
# Episode 150 finished after 127 timesteps. Return = -127.76142724682646
# Episode 151 finished after 80 timesteps. Return = -256.5690365780359
# Episode 152 finished after 70 timesteps. Return = -102.04665372817702
# Episode 153 finished after 99 timesteps. Return = -231.20895457174728
# Episode 154 finished after 72 timesteps. Return = -243.04626109931215
# Episode 155 finished after 135 timesteps. Return = -311.23173253559173
# Episode 156 finished after 75 timesteps. Return = -189.2942140279296
# Episode 157 finished after 74 timesteps. Return = -253.75060046197697
# Episode 158 finished after 104 timesteps. Return = -565.1493209931059
# Episode 159 finished after 63 timesteps. Return = -122.46286786132207
# Episode 160 finished after 114 timesteps. Return = -406.29106447954445
# Episode 161 finished after 70 timesteps. Return = -249.28803690823142
# Episode 162 finished after 69 timesteps. Return = -105.16485025866145
# Episode 163 finished after 98 timesteps. Return = -168.06196955224476
# Episode 164 finished after 59 timesteps. Return = -84.74217475911831
# Episode 165 finished after 74 timesteps. Return = -93.45819031533017
# Episode 166 finished after 140 timesteps. Return = -163.33853750060365
# Episode 167 finished after 102 timesteps. Return = -77.73248735444082
# Episode 168 finished after 66 timesteps. Return = -111.06470614358636
# Episode 169 finished after 73 timesteps. Return = -156.42001260085203
# Episode 170 finished after 102 timesteps. Return = -284.4523883914275
# Episode 171 finished after 117 timesteps. Return = -220.1366820679408
# Episode 172 finished after 58 timesteps. Return = -186.979505323478
# Episode 173 finished after 123 timesteps. Return = -484.90416413501924
# Episode 174 finished after 134 timesteps. Return = -94.8135816933842
# Episode 175 finished after 65 timesteps. Return = -119.26368398829123
# Episode 176 finished after 74 timesteps. Return = -231.0219117660467
# Episode 177 finished after 70 timesteps. Return = -182.83065146736593
# Episode 178 finished after 104 timesteps. Return = -112.85654844140322
# Episode 179 finished after 81 timesteps. Return = -113.5674522833551
# Episode 180 finished after 76 timesteps. Return = -307.01901907722265
# Episode 181 finished after 95 timesteps. Return = -164.99269739893998
# Episode 182 finished after 116 timesteps. Return = -289.68585594369375
# Episode 183 finished after 87 timesteps. Return = -334.6190878335255
# Episode 184 finished after 78 timesteps. Return = -117.93555770267818
# Episode 185 finished after 94 timesteps. Return = -302.73150796601846
# Episode 186 finished after 80 timesteps. Return = -214.45247710468607
# Episode 187 finished after 100 timesteps. Return = -115.56268895749771
# Episode 188 finished after 101 timesteps. Return = -295.46684286658603
# Episode 189 finished after 81 timesteps. Return = -110.46292646974116
# Episode 190 finished after 82 timesteps. Return = -255.33601472075281
# Episode 191 finished after 84 timesteps. Return = -113.38581831069602
# Episode 192 finished after 75 timesteps. Return = -207.06590065319426
# Episode 193 finished after 83 timesteps. Return = -407.5804462651374
# Episode 194 finished after 76 timesteps. Return = -194.29222224291868
# Episode 195 finished after 58 timesteps. Return = -92.57591760183286
# Episode 196 finished after 79 timesteps. Return = -424.78520978368977
# Episode 197 finished after 104 timesteps. Return = -116.73842035579898
# Episode 198 finished after 101 timesteps. Return = -156.7077249296721
# Episode 199 finished after 79 timesteps. Return = -334.9355737901893
# Episode 200 finished after 92 timesteps. Return = -91.78171537813469
# Episode 201 finished after 76 timesteps. Return = -199.67281492039416
# Episode 202 finished after 95 timesteps. Return = -451.06496814986355
# Episode 203 finished after 58 timesteps. Return = -68.55265858756773
# Episode 204 finished after 119 timesteps. Return = -140.3712942904023
# Episode 205 finished after 115 timesteps. Return = -461.95540905017464
# Episode 206 finished after 84 timesteps. Return = -156.6621946930221
# Episode 207 finished after 100 timesteps. Return = -392.33831888965494
# Episode 208 finished after 127 timesteps. Return = -286.7971081285739
# Episode 209 finished after 97 timesteps. Return = -340.71672401521283
# Episode 210 finished after 85 timesteps. Return = -228.7290018385363
# Episode 211 finished after 61 timesteps. Return = -75.73643630955927
# Episode 212 finished after 66 timesteps. Return = -83.39395479505703
# Episode 213 finished after 81 timesteps. Return = -360.70163071819314
# Episode 214 finished after 95 timesteps. Return = -131.50042867520355
# Episode 215 finished after 85 timesteps. Return = -170.96070572594914
# Episode 216 finished after 107 timesteps. Return = -102.71951104487856
# Episode 217 finished after 70 timesteps. Return = -98.62209428517541
# Episode 218 finished after 70 timesteps. Return = -87.1271338787944
# Episode 219 finished after 76 timesteps. Return = -430.60288142307013
# Episode 220 finished after 99 timesteps. Return = -216.81175245328114
# Episode 221 finished after 86 timesteps. Return = -379.50323518539983
# Episode 222 finished after 110 timesteps. Return = -299.86110971672315
# Episode 223 finished after 73 timesteps. Return = -130.30071898599638
# Episode 224 finished after 70 timesteps. Return = -173.42910983823788
# Episode 225 finished after 105 timesteps. Return = -177.78843546485507
# Episode 226 finished after 106 timesteps. Return = -181.5989713541557
# Episode 227 finished after 63 timesteps. Return = -84.83148031196717
# Episode 228 finished after 73 timesteps. Return = -122.87375462011411
# Episode 229 finished after 79 timesteps. Return = -158.60845815761257
# Episode 230 finished after 72 timesteps. Return = 24.52295969855038
# Episode 231 finished after 108 timesteps. Return = -348.9424867447601
# Episode 232 finished after 88 timesteps. Return = -106.05231255662758
# Episode 233 finished after 129 timesteps. Return = -261.3024379856664
# Episode 234 finished after 91 timesteps. Return = -118.94335390519095
# Episode 235 finished after 84 timesteps. Return = -120.85157796600862
# Episode 236 finished after 63 timesteps. Return = -149.0800776585707
# Episode 237 finished after 111 timesteps. Return = -152.84947603429273
# Episode 238 finished after 59 timesteps. Return = -77.51407600906498
# Episode 239 finished after 92 timesteps. Return = -191.98477075224503
# Episode 240 finished after 117 timesteps. Return = -92.85289949602604
# Episode 241 finished after 95 timesteps. Return = -119.60904148623624
# Episode 242 finished after 102 timesteps. Return = -412.7949196720629
# Episode 243 finished after 70 timesteps. Return = -91.52620221968974
# Episode 244 finished after 109 timesteps. Return = -132.09358135210914
# Episode 245 finished after 96 timesteps. Return = -118.6143444405979
# Episode 246 finished after 87 timesteps. Return = -321.21622154387313
# Episode 247 finished after 99 timesteps. Return = -171.18590950191407
# Episode 248 finished after 106 timesteps. Return = -361.45363968493496
# Episode 249 finished after 62 timesteps. Return = -78.78894939759323
# Episode 250 finished after 110 timesteps. Return = -124.12495490357959
# Episode 251 finished after 95 timesteps. Return = -427.1892731056664
# Episode 252 finished after 63 timesteps. Return = -100.19424975117438
# Episode 253 finished after 65 timesteps. Return = -100.72574632436351
# Episode 254 finished after 110 timesteps. Return = -233.1856415296471
# Episode 255 finished after 112 timesteps. Return = -81.37500886901387
# Episode 256 finished after 85 timesteps. Return = -351.5972565726412
# Episode 257 finished after 85 timesteps. Return = -471.1598886706898
# Episode 258 finished after 88 timesteps. Return = -120.77770333179048
# Episode 259 finished after 99 timesteps. Return = -302.2096293514895
# Episode 260 finished after 93 timesteps. Return = -216.8974573251549
# Episode 261 finished after 123 timesteps. Return = -155.65512434552898
# Episode 262 finished after 69 timesteps. Return = -125.91424925182794
# Episode 263 finished after 105 timesteps. Return = -359.13313403089603
# Episode 264 finished after 63 timesteps. Return = -84.22250843534815
# Episode 265 finished after 99 timesteps. Return = -269.77485118547054
# Episode 266 finished after 102 timesteps. Return = -153.6230045203926
# Episode 267 finished after 63 timesteps. Return = -89.1854665707099
# Episode 268 finished after 119 timesteps. Return = -137.52426879677031
# Episode 269 finished after 96 timesteps. Return = -170.5678641432147
# Episode 270 finished after 83 timesteps. Return = -17.705065851579093
# Episode 271 finished after 70 timesteps. Return = -100.23237095267679
# Episode 272 finished after 96 timesteps. Return = -118.22684516217112
# Episode 273 finished after 69 timesteps. Return = -194.8043055345803
# Episode 274 finished after 66 timesteps. Return = -79.64664624126776
# Episode 275 finished after 72 timesteps. Return = -153.81440989372732
# Episode 276 finished after 73 timesteps. Return = -270.1315638803924
# Episode 277 finished after 97 timesteps. Return = -283.74216154399426
# Episode 278 finished after 88 timesteps. Return = -175.48549436634386
# Episode 279 finished after 73 timesteps. Return = -91.72269664888135
# Episode 280 finished after 86 timesteps. Return = -139.8620684160424
# Episode 281 finished after 89 timesteps. Return = -115.18185644961733
# Episode 282 finished after 86 timesteps. Return = -306.8575281332819
# Episode 283 finished after 92 timesteps. Return = -165.53026033242884
# Episode 284 finished after 97 timesteps. Return = -361.11945810357736
# Episode 285 finished after 113 timesteps. Return = -152.57129500674108
# Episode 286 finished after 102 timesteps. Return = -102.91816335281213
# Episode 287 finished after 82 timesteps. Return = -154.80013349206104
# Episode 288 finished after 115 timesteps. Return = -38.73986710148432
# Episode 289 finished after 110 timesteps. Return = -33.72934427488062
# Episode 290 finished after 91 timesteps. Return = -127.0344131504138
# Episode 291 finished after 91 timesteps. Return = -96.51374630685024
# Episode 292 finished after 62 timesteps. Return = -94.54622098899897
# Episode 293 finished after 69 timesteps. Return = -119.57940140864392
# Episode 294 finished after 97 timesteps. Return = -290.01738334475
# Episode 295 finished after 71 timesteps. Return = -115.15766398232832
# Episode 296 finished after 81 timesteps. Return = -319.648145216712
# Episode 297 finished after 99 timesteps. Return = -275.8158543977743
# Episode 298 finished after 120 timesteps. Return = -106.11979481851704
# Episode 299 finished after 86 timesteps. Return = -141.4648956851363
# Episode 300 finished after 92 timesteps. Return = -177.81689133774097
# Episode 301 finished after 123 timesteps. Return = -47.84569632480145
# Episode 302 finished after 101 timesteps. Return = -448.66426100143093
# Episode 303 finished after 105 timesteps. Return = -231.55502098310822
# Episode 304 finished after 75 timesteps. Return = -131.92576576073836
# Episode 305 finished after 101 timesteps. Return = -378.09748751092275
# Episode 306 finished after 74 timesteps. Return = -97.36471595355874
# Episode 307 finished after 85 timesteps. Return = -402.7817236096401
# Episode 308 finished after 70 timesteps. Return = -99.52673565207242
# Episode 309 finished after 71 timesteps. Return = -83.1878189915279
# Episode 310 finished after 95 timesteps. Return = -234.43475385427388
# Episode 311 finished after 80 timesteps. Return = -129.01413606216767
# Episode 312 finished after 74 timesteps. Return = -97.70239214183113
# Episode 313 finished after 103 timesteps. Return = -117.72415051842329
# Episode 314 finished after 111 timesteps. Return = -155.75811173567539
# Episode 315 finished after 92 timesteps. Return = -65.07852131082288
# Episode 316 finished after 64 timesteps. Return = -94.94486803226413
# Episode 317 finished after 65 timesteps. Return = -86.60803168847082
# Episode 318 finished after 97 timesteps. Return = -295.7730713956993
# Episode 319 finished after 110 timesteps. Return = -140.55212594019423
# Episode 320 finished after 84 timesteps. Return = -228.19091712982592
# Episode 321 finished after 101 timesteps. Return = -133.5850445817673
# Episode 322 finished after 84 timesteps. Return = -155.6171726272148
# Episode 323 finished after 116 timesteps. Return = -51.00554864046719
# Episode 324 finished after 92 timesteps. Return = -110.82137064384168
# Episode 325 finished after 86 timesteps. Return = -127.5341130077016
# Episode 326 finished after 78 timesteps. Return = -254.85624569217032
# Episode 327 finished after 120 timesteps. Return = -530.2492221181567
# Episode 328 finished after 104 timesteps. Return = -487.0111786223943
# Episode 329 finished after 107 timesteps. Return = -146.52048081459685
# Episode 330 finished after 126 timesteps. Return = -236.8256243998061
# Episode 331 finished after 73 timesteps. Return = -94.57737126307111
# Episode 332 finished after 71 timesteps. Return = -90.43324338278288
# Episode 333 finished after 65 timesteps. Return = -218.7524224606306
# Episode 334 finished after 71 timesteps. Return = -102.74999674181397
# Episode 335 finished after 119 timesteps. Return = -128.88565913739458
# Episode 336 finished after 68 timesteps. Return = -228.36879532929825
# Episode 337 finished after 81 timesteps. Return = -194.88494101220002
# Episode 338 finished after 84 timesteps. Return = -214.73911846050214
# Episode 339 finished after 83 timesteps. Return = -122.85345756609003
# Episode 340 finished after 76 timesteps. Return = -198.07764559910498
# Episode 341 finished after 116 timesteps. Return = -76.63926343719098
# Episode 342 finished after 96 timesteps. Return = -159.65130335145818
# Episode 343 finished after 65 timesteps. Return = 35.63028900075051
# Episode 344 finished after 69 timesteps. Return = -170.3140743588819
# Episode 345 finished after 108 timesteps. Return = -42.89951808413643
# Episode 346 finished after 94 timesteps. Return = -467.86904245315736
# Episode 347 finished after 67 timesteps. Return = -100.49589807793768
# Episode 348 finished after 103 timesteps. Return = -143.66965323054194
# Episode 349 finished after 56 timesteps. Return = -90.65196248948564
# Episode 350 finished after 121 timesteps. Return = -147.42756476112186
# Episode 351 finished after 118 timesteps. Return = -234.68550708068145
# Episode 352 finished after 61 timesteps. Return = -105.12417505753982
# Episode 353 finished after 67 timesteps. Return = -90.74907485956172
# Episode 354 finished after 91 timesteps. Return = -130.53234210158703
# Episode 355 finished after 108 timesteps. Return = -328.6033975645516
# Episode 356 finished after 66 timesteps. Return = -69.28478804840185
# Episode 357 finished after 125 timesteps. Return = -334.5759616408783
# Episode 358 finished after 61 timesteps. Return = -79.9194607385125
# Episode 359 finished after 66 timesteps. Return = -60.65654471705246
# Episode 360 finished after 79 timesteps. Return = -90.85366296836762
# Episode 361 finished after 88 timesteps. Return = -120.98350523658573
# Episode 362 finished after 106 timesteps. Return = -126.1074293081916
# Episode 363 finished after 116 timesteps. Return = -175.1043214309008
# Episode 364 finished after 98 timesteps. Return = -242.59782186744482
# Episode 365 finished after 86 timesteps. Return = -363.40105580802197
# Episode 366 finished after 95 timesteps. Return = -120.42181804918505
# Episode 367 finished after 81 timesteps. Return = -160.25555022037744
# Episode 368 finished after 71 timesteps. Return = -155.1505269637749
# Episode 369 finished after 111 timesteps. Return = -185.77258713571013
# Episode 370 finished after 116 timesteps. Return = -181.22285630196245
# Episode 371 finished after 57 timesteps. Return = -98.70522339051874
# Episode 372 finished after 112 timesteps. Return = 10.477096426421639
# Episode 373 finished after 72 timesteps. Return = -80.2169509928762
# Episode 374 finished after 108 timesteps. Return = -119.65134338049099
# Episode 375 finished after 110 timesteps. Return = -105.71824573995148
# Episode 376 finished after 56 timesteps. Return = -83.84918590680051
# Episode 377 finished after 89 timesteps. Return = -145.13886024732457
# Episode 378 finished after 92 timesteps. Return = -409.4767818366629
# Episode 379 finished after 73 timesteps. Return = -75.06836268516938
# Episode 380 finished after 94 timesteps. Return = -319.94391410122205
# Episode 381 finished after 72 timesteps. Return = -121.92925531663361
# Episode 382 finished after 80 timesteps. Return = -71.88789360176236
# Episode 383 finished after 66 timesteps. Return = -114.73706022866335
# Episode 384 finished after 65 timesteps. Return = -113.2810498094687
# Episode 385 finished after 78 timesteps. Return = -90.88185341507251
# Episode 386 finished after 69 timesteps. Return = -77.73253467072982
# Episode 387 finished after 79 timesteps. Return = -116.31351683487475
# Episode 388 finished after 61 timesteps. Return = -77.95699768752064
# Episode 389 finished after 63 timesteps. Return = -79.23559281441804
# Episode 390 finished after 79 timesteps. Return = -156.95633109270284
# Episode 391 finished after 61 timesteps. Return = -107.41958857355324
# Episode 392 finished after 112 timesteps. Return = -287.26592242971236
# Episode 393 finished after 95 timesteps. Return = -100.02753603827207
# Episode 394 finished after 101 timesteps. Return = -93.15733495427334
# Episode 395 finished after 85 timesteps. Return = -102.89599703287759
# Episode 396 finished after 118 timesteps. Return = -157.890530195954
# Episode 397 finished after 71 timesteps. Return = -64.84133351495514
# Episode 398 finished after 66 timesteps. Return = -65.839345401589
# Episode 399 finished after 110 timesteps. Return = -355.5286379402072
# Episode 400 finished after 93 timesteps. Return = -92.21042989309474
# Episode 401 finished after 157 timesteps. Return = -225.67128721910296
# Episode 402 finished after 83 timesteps. Return = -201.96103248346327
# Episode 403 finished after 107 timesteps. Return = -207.22928153338484
# Episode 404 finished after 80 timesteps. Return = -120.37090003334217
# Episode 405 finished after 77 timesteps. Return = -111.50092062168446
# Episode 406 finished after 62 timesteps. Return = -45.75351719840452
# Episode 407 finished after 95 timesteps. Return = -160.3542386655847
# Episode 408 finished after 95 timesteps. Return = -138.8980010156192
# Episode 409 finished after 132 timesteps. Return = -207.88892519364475
# Episode 410 finished after 92 timesteps. Return = -113.21680011822285
# Episode 411 finished after 90 timesteps. Return = -98.88539265925864
# Episode 412 finished after 72 timesteps. Return = -320.4238494472846
# Episode 413 finished after 68 timesteps. Return = -64.64364215083958
# Episode 414 finished after 95 timesteps. Return = -308.6433479765385
# Episode 415 finished after 68 timesteps. Return = -187.68119998959068
# Episode 416 finished after 72 timesteps. Return = -106.45896196934116
# Episode 417 finished after 75 timesteps. Return = -308.840500107999
# Episode 418 finished after 68 timesteps. Return = -32.65245322663165
# Episode 419 finished after 106 timesteps. Return = -247.75608677087263
# Episode 420 finished after 79 timesteps. Return = -348.5519095235118
# Episode 421 finished after 116 timesteps. Return = -116.47448039321512
# Episode 422 finished after 97 timesteps. Return = -239.71960783598783
# Episode 423 finished after 108 timesteps. Return = -201.62276161551995
# Episode 424 finished after 100 timesteps. Return = -230.02570657887222
# Episode 425 finished after 112 timesteps. Return = -190.60003963713797
# Episode 426 finished after 132 timesteps. Return = -92.71703491655582
# Episode 427 finished after 81 timesteps. Return = -102.48246805613442
# Episode 428 finished after 98 timesteps. Return = -383.42274383962
# Episode 429 finished after 93 timesteps. Return = -150.28398389866362
# Episode 430 finished after 64 timesteps. Return = -119.16127124050487
# Episode 431 finished after 108 timesteps. Return = -152.8031504739129
# Episode 432 finished after 112 timesteps. Return = -334.0993852179282
# Episode 433 finished after 115 timesteps. Return = -128.55269119495932
# Episode 434 finished after 97 timesteps. Return = -277.4594082856066
# Episode 435 finished after 61 timesteps. Return = -110.13927382230902
# Episode 436 finished after 86 timesteps. Return = -126.39529610575099
# Episode 437 finished after 78 timesteps. Return = -230.92339258027712
# Episode 438 finished after 71 timesteps. Return = -107.73152496490005
# Episode 439 finished after 114 timesteps. Return = -35.32676601393669
# Episode 440 finished after 107 timesteps. Return = -439.1241667609956
# Episode 441 finished after 65 timesteps. Return = -60.842838067782054
# Episode 442 finished after 123 timesteps. Return = -175.83232584532936
# Episode 443 finished after 72 timesteps. Return = -50.898740354976866
# Episode 444 finished after 97 timesteps. Return = -326.3023398268899
# Episode 445 finished after 85 timesteps. Return = -122.71614674459231
# Episode 446 finished after 130 timesteps. Return = -318.15271960400105
# Episode 447 finished after 140 timesteps. Return = -96.36008286543107
# Episode 448 finished after 91 timesteps. Return = -260.7319923870146
# Episode 449 finished after 83 timesteps. Return = -141.88518428423936
# Episode 450 finished after 70 timesteps. Return = -248.0029630607276
# Episode 451 finished after 70 timesteps. Return = -104.27671375943301
# Episode 452 finished after 78 timesteps. Return = -132.2162372241722
# Episode 453 finished after 93 timesteps. Return = -330.1456218862429
# Episode 454 finished after 97 timesteps. Return = -235.6128663898422
# Episode 455 finished after 78 timesteps. Return = -162.89354794089556
# Episode 456 finished after 70 timesteps. Return = -91.90319932566703
# Episode 457 finished after 80 timesteps. Return = -116.77920670085926
# Episode 458 finished after 70 timesteps. Return = -112.93569174557221
# Episode 459 finished after 70 timesteps. Return = -90.05095240299694
# Episode 460 finished after 120 timesteps. Return = -178.0477238113013
# Episode 461 finished after 101 timesteps. Return = -101.27167876326956
# Episode 462 finished after 107 timesteps. Return = -40.41913833033849
# Episode 463 finished after 124 timesteps. Return = -210.57304204071062
# Episode 464 finished after 104 timesteps. Return = -218.89618851708016
# Episode 465 finished after 72 timesteps. Return = -89.57812678053737
# Episode 466 finished after 83 timesteps. Return = -125.77187383122397
# Episode 467 finished after 90 timesteps. Return = -182.79933070963693
# Episode 468 finished after 64 timesteps. Return = -92.63990020488285
# Episode 469 finished after 70 timesteps. Return = -128.03318847050062
# Episode 470 finished after 94 timesteps. Return = -99.6527620725558
# Episode 471 finished after 65 timesteps. Return = -65.05124181380114
# Episode 472 finished after 80 timesteps. Return = -408.1448382552155
# Episode 473 finished after 68 timesteps. Return = -82.89226463387355
# Episode 474 finished after 109 timesteps. Return = -284.8796391101628
# Episode 475 finished after 96 timesteps. Return = -115.05035336413863
# Episode 476 finished after 63 timesteps. Return = -119.81958288320504
# Episode 477 finished after 128 timesteps. Return = -495.94388376998035
# Episode 478 finished after 98 timesteps. Return = -95.62169957932763
# Episode 479 finished after 123 timesteps. Return = -251.22390072073833
# Episode 480 finished after 115 timesteps. Return = -159.13425096797334
# Episode 481 finished after 111 timesteps. Return = -294.65890397535765
# Episode 482 finished after 70 timesteps. Return = -130.5105502206685
# Episode 483 finished after 78 timesteps. Return = -118.45433244306784
# Episode 484 finished after 74 timesteps. Return = -53.03864449962833
# Episode 485 finished after 72 timesteps. Return = -115.11062354340453
# Episode 486 finished after 131 timesteps. Return = -114.35704031425709
# Episode 487 finished after 98 timesteps. Return = -371.98453191790315
# Episode 488 finished after 68 timesteps. Return = -103.87979174110113
# Episode 489 finished after 112 timesteps. Return = -333.7584711697583
# Episode 490 finished after 59 timesteps. Return = -195.7910434548014
# Episode 491 finished after 56 timesteps. Return = -82.26065085186272
# Episode 492 finished after 64 timesteps. Return = -90.64604252952893
# Episode 493 finished after 58 timesteps. Return = -100.19791917628797
# Episode 494 finished after 75 timesteps. Return = -252.42564702207468
# Episode 495 finished after 129 timesteps. Return = -135.00522990510657
# Episode 496 finished after 65 timesteps. Return = -116.15825268967129
# Episode 497 finished after 69 timesteps. Return = -106.74989996809838
# Episode 498 finished after 67 timesteps. Return = -90.4910013881454
# Episode 499 finished after 108 timesteps. Return = -251.13480838364268
# Episode 500 finished after 113 timesteps. Return = -294.17704052875376
# Episode 501 finished after 65 timesteps. Return = -119.44981180188377
# Episode 502 finished after 68 timesteps. Return = -105.54510041300472
# Episode 503 finished after 69 timesteps. Return = -113.49057641093296
# Episode 504 finished after 93 timesteps. Return = -363.38881317175634
# Episode 505 finished after 95 timesteps. Return = -114.42297773453174
# Episode 506 finished after 61 timesteps. Return = -140.5634640635123
# Episode 507 finished after 123 timesteps. Return = -222.98887102495024
# Episode 508 finished after 75 timesteps. Return = -232.2628875034173
# Episode 509 finished after 89 timesteps. Return = 35.32200206905014
# Episode 510 finished after 76 timesteps. Return = -79.32646935410955
# Episode 511 finished after 69 timesteps. Return = -79.99326239628414
# Episode 512 finished after 89 timesteps. Return = -157.22122386012398
# Episode 513 finished after 84 timesteps. Return = -113.87387658052027
# Episode 514 finished after 128 timesteps. Return = 19.787697143148932
# Episode 515 finished after 87 timesteps. Return = -97.01287138989738
# Episode 516 finished after 111 timesteps. Return = -130.16738172310457
# Episode 517 finished after 66 timesteps. Return = -42.29804791615828
# Episode 518 finished after 92 timesteps. Return = -207.2118855531446
# Episode 519 finished after 79 timesteps. Return = -107.07200680985233
# Episode 520 finished after 108 timesteps. Return = -463.08408369417606
# Episode 521 finished after 99 timesteps. Return = -257.3175792671201
# Episode 522 finished after 118 timesteps. Return = -295.5943091258065
# Episode 523 finished after 71 timesteps. Return = -126.97410695524009
# Episode 524 finished after 108 timesteps. Return = -143.54552771830367
# Episode 525 finished after 117 timesteps. Return = -134.25420658459586
# Episode 526 finished after 77 timesteps. Return = -73.71196155963113
# Episode 527 finished after 69 timesteps. Return = -108.39723417164474
# Episode 528 finished after 103 timesteps. Return = -348.73313095896924
# Episode 529 finished after 110 timesteps. Return = -199.19545465790583
# Episode 530 finished after 137 timesteps. Return = 1.5067279749357283
# Episode 531 finished after 107 timesteps. Return = -97.8130140539487
# Episode 532 finished after 110 timesteps. Return = -113.57216581831835
# Episode 533 finished after 74 timesteps. Return = -89.54221380240719
# Episode 534 finished after 64 timesteps. Return = -249.3533325717778
# Episode 535 finished after 129 timesteps. Return = -474.5760940135383
# Episode 536 finished after 131 timesteps. Return = -184.84173486622774
# Episode 537 finished after 117 timesteps. Return = -168.9296341278432
# Episode 538 finished after 68 timesteps. Return = -180.42104042873754
# Episode 539 finished after 79 timesteps. Return = -123.42821567763775
# Episode 540 finished after 98 timesteps. Return = -121.16247434782917
# Episode 541 finished after 65 timesteps. Return = -110.64232009487272
# Episode 542 finished after 83 timesteps. Return = -122.15477485759845
# Episode 543 finished after 117 timesteps. Return = -146.28058867364254
# Episode 544 finished after 103 timesteps. Return = -152.84937556574002
# Episode 545 finished after 75 timesteps. Return = -325.97000584586505
# Episode 546 finished after 123 timesteps. Return = -167.6260695095594
# Episode 547 finished after 57 timesteps. Return = -75.4611309282453
# Episode 548 finished after 103 timesteps. Return = -282.9183557666413
# Episode 549 finished after 96 timesteps. Return = -242.36948685979172
# Episode 550 finished after 65 timesteps. Return = -154.72852966115966
# Episode 551 finished after 77 timesteps. Return = -144.5005828350042
# Episode 552 finished after 105 timesteps. Return = -104.78028691330331
# Episode 553 finished after 108 timesteps. Return = -419.33731869774704
# Episode 554 finished after 89 timesteps. Return = -129.94735924577878
# Episode 555 finished after 85 timesteps. Return = -104.81635440482451
# Episode 556 finished after 69 timesteps. Return = -78.6666350345485
# Episode 557 finished after 70 timesteps. Return = -126.8879108698388
# Episode 558 finished after 91 timesteps. Return = -162.87820148519558
# Episode 559 finished after 138 timesteps. Return = -232.27038952373059
# Episode 560 finished after 103 timesteps. Return = -172.8787200695713
# Episode 561 finished after 78 timesteps. Return = -332.39244957747786
# Episode 562 finished after 70 timesteps. Return = -228.35713114101594
# Episode 563 finished after 86 timesteps. Return = -389.20056213800274
# Episode 564 finished after 116 timesteps. Return = -121.5002538593352
# Episode 565 finished after 130 timesteps. Return = -312.75961095289915
# Episode 566 finished after 68 timesteps. Return = -106.04337015310277
# Episode 567 finished after 112 timesteps. Return = -78.74089866277927
# Episode 568 finished after 65 timesteps. Return = -260.744019255779
# Episode 569 finished after 132 timesteps. Return = -229.7525535473293
# Episode 570 finished after 59 timesteps. Return = -128.12708673074292
# Episode 571 finished after 69 timesteps. Return = -84.58169394624284
# Episode 572 finished after 74 timesteps. Return = -144.5101065023012
# Episode 573 finished after 74 timesteps. Return = -233.10569430334957
# Episode 574 finished after 70 timesteps. Return = -79.56805545115324
# Episode 575 finished after 75 timesteps. Return = -192.37218831308894
# Episode 576 finished after 96 timesteps. Return = -190.66711088323143
# Episode 577 finished after 69 timesteps. Return = -87.81391669030104
# Episode 578 finished after 70 timesteps. Return = -107.25659622726026
# Episode 579 finished after 82 timesteps. Return = -90.56611756057679
# Episode 580 finished after 133 timesteps. Return = -149.42066333903017
# Episode 581 finished after 118 timesteps. Return = -78.0164329178552
# Episode 582 finished after 104 timesteps. Return = -136.39617003597976
# Episode 583 finished after 84 timesteps. Return = -268.2810285707069
# Episode 584 finished after 64 timesteps. Return = -73.03990309238668
# Episode 585 finished after 89 timesteps. Return = -224.22438970052568
# Episode 586 finished after 99 timesteps. Return = -171.94760147538813
# Episode 587 finished after 101 timesteps. Return = -282.30996675503434
# Episode 588 finished after 116 timesteps. Return = -207.61131312052046
# Episode 589 finished after 109 timesteps. Return = -73.47644101997763
# Episode 590 finished after 103 timesteps. Return = -232.11300301964692
# Episode 591 finished after 103 timesteps. Return = -292.0155280168872
# Episode 592 finished after 113 timesteps. Return = -243.56531216491496
# Episode 593 finished after 133 timesteps. Return = -145.755854021586
# Episode 594 finished after 91 timesteps. Return = -145.59500602489263
# Episode 595 finished after 107 timesteps. Return = -131.00423840478913
# Episode 596 finished after 60 timesteps. Return = -77.17436902829068
# Episode 597 finished after 102 timesteps. Return = -228.59113368038365
# Episode 598 finished after 62 timesteps. Return = -88.4290347204951
# Episode 599 finished after 93 timesteps. Return = -327.9762624022234
# Episode 600 finished after 95 timesteps. Return = -187.03538864015212
# Episode 601 finished after 123 timesteps. Return = -215.5936323996933
# Episode 602 finished after 61 timesteps. Return = 15.245354091985206
# Episode 603 finished after 116 timesteps. Return = -33.35976625237552
# Episode 604 finished after 60 timesteps. Return = -94.50240596100063
# Episode 605 finished after 76 timesteps. Return = -120.81586150125983
# Episode 606 finished after 96 timesteps. Return = -351.51476555374893
# Episode 607 finished after 92 timesteps. Return = -98.66135247229661
# Episode 608 finished after 108 timesteps. Return = -383.6495175869566
# Episode 609 finished after 78 timesteps. Return = -118.73760641862813
# Episode 610 finished after 60 timesteps. Return = -82.44198700015775
# Episode 611 finished after 88 timesteps. Return = -181.09617091804967
# Episode 612 finished after 96 timesteps. Return = -117.20171818093692
# Episode 613 finished after 110 timesteps. Return = -388.60561524595835
# Episode 614 finished after 70 timesteps. Return = -70.1221230350619
# Episode 615 finished after 108 timesteps. Return = -170.06869148651202
# Episode 616 finished after 77 timesteps. Return = -106.89607999652316
# Episode 617 finished after 82 timesteps. Return = -156.8145672557465
# Episode 618 finished after 103 timesteps. Return = -152.7120982679769
# Episode 619 finished after 69 timesteps. Return = -116.96566122903836
# Episode 620 finished after 104 timesteps. Return = -164.83014501388368
# Episode 621 finished after 99 timesteps. Return = -124.95814287424695
# Episode 622 finished after 81 timesteps. Return = 17.78057862262723
# Episode 623 finished after 140 timesteps. Return = -140.36566630193397
# Episode 624 finished after 103 timesteps. Return = -195.74881389267915
# Episode 625 finished after 126 timesteps. Return = -95.51151363551622
# Episode 626 finished after 70 timesteps. Return = -94.94143995392302
# Episode 627 finished after 111 timesteps. Return = -110.71960456401055
# Episode 628 finished after 98 timesteps. Return = -233.00490290032172
# Episode 629 finished after 103 timesteps. Return = -198.56424947027006
# Episode 630 finished after 78 timesteps. Return = -70.41368751919953
# Episode 631 finished after 101 timesteps. Return = -118.99418543198064
# Episode 632 finished after 78 timesteps. Return = -138.00838380857343
# Episode 633 finished after 86 timesteps. Return = -130.45513896705626
# Episode 634 finished after 103 timesteps. Return = -195.76553046042244
# Episode 635 finished after 119 timesteps. Return = -78.48554636228607
# Episode 636 finished after 65 timesteps. Return = -134.1799403024957
# Episode 637 finished after 103 timesteps. Return = -116.76303011025756
# Episode 638 finished after 74 timesteps. Return = -67.83045948172659
# Episode 639 finished after 121 timesteps. Return = -639.4343875298483
# Episode 640 finished after 86 timesteps. Return = -123.88090108103995
# Episode 641 finished after 74 timesteps. Return = -140.09746114618076
# Episode 642 finished after 71 timesteps. Return = -191.55648479428436
# Episode 643 finished after 71 timesteps. Return = -115.98092990778784
# Episode 644 finished after 67 timesteps. Return = -109.37073157666744
# Episode 645 finished after 61 timesteps. Return = -67.3151145560283
# Episode 646 finished after 111 timesteps. Return = -142.84793962533692
# Episode 647 finished after 103 timesteps. Return = -383.9388749930272
# Episode 648 finished after 122 timesteps. Return = -199.29678518599317
# Episode 649 finished after 68 timesteps. Return = -111.04075430229972
# Episode 650 finished after 90 timesteps. Return = -111.75093292669305
# Episode 651 finished after 110 timesteps. Return = -304.23757627567045
# Episode 652 finished after 76 timesteps. Return = -149.13910581219056
# Episode 653 finished after 78 timesteps. Return = 3.8161700299171457
# Episode 654 finished after 98 timesteps. Return = -136.15317357199214
# Episode 655 finished after 104 timesteps. Return = 5.830013443758304
# Episode 656 finished after 97 timesteps. Return = -218.35981465152037
# Episode 657 finished after 118 timesteps. Return = -211.92950728872125
# Episode 658 finished after 81 timesteps. Return = -325.74411433940395
# Episode 659 finished after 79 timesteps. Return = -105.21769259084934
# Episode 660 finished after 118 timesteps. Return = -205.0939518333146
# Episode 661 finished after 80 timesteps. Return = -137.6865961797114
# Episode 662 finished after 78 timesteps. Return = -163.61835326333767
# Episode 663 finished after 120 timesteps. Return = -269.5305203863011
# Episode 664 finished after 118 timesteps. Return = -171.92602764644775
# Episode 665 finished after 117 timesteps. Return = -101.4464128156804
# Episode 666 finished after 122 timesteps. Return = -46.04767120387671
# Episode 667 finished after 124 timesteps. Return = -304.5842238326467
# Episode 668 finished after 73 timesteps. Return = -94.94487567261359
# Episode 669 finished after 101 timesteps. Return = -270.22855591683776
# Episode 670 finished after 118 timesteps. Return = -277.19648859627097
# Episode 671 finished after 81 timesteps. Return = -153.51333520028822
# Episode 672 finished after 78 timesteps. Return = -134.59014662303693
# Episode 673 finished after 123 timesteps. Return = -201.71208031062685
# Episode 674 finished after 129 timesteps. Return = -117.7706999574568
# Episode 675 finished after 107 timesteps. Return = -387.004045369242
# Episode 676 finished after 102 timesteps. Return = -266.47870504912095
# Episode 677 finished after 62 timesteps. Return = -65.9739223707442
# Episode 678 finished after 108 timesteps. Return = -171.4012282137781
# Episode 679 finished after 82 timesteps. Return = -99.77414564859791
# Episode 680 finished after 93 timesteps. Return = -94.67072494377899
# Episode 681 finished after 105 timesteps. Return = -281.65083023069826
# Episode 682 finished after 98 timesteps. Return = -195.35746952311442
# Episode 683 finished after 114 timesteps. Return = -332.079618982699
# Episode 684 finished after 75 timesteps. Return = -146.68938004948512
# Episode 685 finished after 87 timesteps. Return = -128.9092286567208
# Episode 686 finished after 72 timesteps. Return = -150.52493362462815
# Episode 687 finished after 139 timesteps. Return = -268.12206370165495
# Episode 688 finished after 72 timesteps. Return = -93.83722378559989
# Episode 689 finished after 149 timesteps. Return = -182.69773592746859
# Episode 690 finished after 79 timesteps. Return = -82.68967314921295
# Episode 691 finished after 107 timesteps. Return = -331.29697021287984
# Episode 692 finished after 65 timesteps. Return = -123.99685981164525
# Episode 693 finished after 131 timesteps. Return = -482.2587592440529
# Episode 694 finished after 97 timesteps. Return = -361.1224397347429
# Episode 695 finished after 100 timesteps. Return = -171.73589011548955
# Episode 696 finished after 125 timesteps. Return = -210.10897100521788
# Episode 697 finished after 87 timesteps. Return = -318.39184231814215
# Episode 698 finished after 123 timesteps. Return = -11.371983789200769
# Episode 699 finished after 109 timesteps. Return = -112.03088477955409
# Episode 700 finished after 104 timesteps. Return = -127.05886943263633
# Episode 701 finished after 69 timesteps. Return = -116.09387685639557
# Episode 702 finished after 111 timesteps. Return = -137.69778706857454
# Episode 703 finished after 100 timesteps. Return = -274.6833891708102
# Episode 704 finished after 130 timesteps. Return = -123.64807463725442
# Episode 705 finished after 96 timesteps. Return = -68.23983036414697
# Episode 706 finished after 72 timesteps. Return = -113.85506904793993
# Episode 707 finished after 96 timesteps. Return = -137.2474768434381
# Episode 708 finished after 79 timesteps. Return = -109.9735758162366
# Episode 709 finished after 129 timesteps. Return = -108.07751647962175
# Episode 710 finished after 118 timesteps. Return = -338.49956610270436
# Episode 711 finished after 95 timesteps. Return = -224.83094971927775
# Episode 712 finished after 79 timesteps. Return = -132.1530749027988
# Episode 713 finished after 73 timesteps. Return = -74.88228342362045
# Episode 714 finished after 169 timesteps. Return = -230.7922829595354
# Episode 715 finished after 121 timesteps. Return = -198.18658238324457
# Episode 716 finished after 100 timesteps. Return = -90.544771950858
# Episode 717 finished after 106 timesteps. Return = -108.08897199956301
# Episode 718 finished after 81 timesteps. Return = -105.18206785623396
# Episode 719 finished after 107 timesteps. Return = -145.36461103554367
# Episode 720 finished after 67 timesteps. Return = -66.42556130717882
# Episode 721 finished after 71 timesteps. Return = -118.60404401300949
# Episode 722 finished after 76 timesteps. Return = -312.6159666885675
# Episode 723 finished after 93 timesteps. Return = -125.59795168695709
# Episode 724 finished after 63 timesteps. Return = -82.16135520806243
# Episode 725 finished after 71 timesteps. Return = -145.3986820729915
# Episode 726 finished after 81 timesteps. Return = -170.86651737084281
# Episode 727 finished after 74 timesteps. Return = -18.50104323853772
# Episode 728 finished after 92 timesteps. Return = -159.2103785332934
# Episode 729 finished after 94 timesteps. Return = -129.48007851403904
# Episode 730 finished after 87 timesteps. Return = -94.94320661410084
# Episode 731 finished after 68 timesteps. Return = -87.27314236644025
# Episode 732 finished after 104 timesteps. Return = -201.04594152355088
# Episode 733 finished after 144 timesteps. Return = -143.9522951909992
# Episode 734 finished after 74 timesteps. Return = -127.53612137926127
# Episode 735 finished after 71 timesteps. Return = -91.46360785916734
# Episode 736 finished after 79 timesteps. Return = -263.273000881376
# Episode 737 finished after 103 timesteps. Return = -265.9294266408117
# ...
# Episode 17411 finished after 1000 timesteps. Return = 47.17554410862753
# Episode 17412 finished after 226 timesteps. Return = -8.37389823575026
# Episode 17413 finished after 139 timesteps. Return = -12.066201151198385
# Episode 17414 finished after 834 timesteps. Return = -214.091379206147
# Episode 17415 finished after 1000 timesteps. Return = 59.12693741489279
# Episode 17416 finished after 1000 timesteps. Return = 40.476191999180365
# Episode 17417 finished after 244 timesteps. Return = -47.95656773004889
# Episode 17418 finished after 598 timesteps. Return = -275.2734546489455
# Episode 17419 finished after 241 timesteps. Return = -25.164578186764047
# Episode 17420 finished after 1000 timesteps. Return = 82.22594586610417
# Episode 17421 finished after 1000 timesteps. Return = 114.58770338413137
# Episode 17422 finished after 249 timesteps. Return = -152.39756673543442
# Episode 17423 finished after 1000 timesteps. Return = -95.18954627157977
# Episode 17424 finished after 216 timesteps. Return = -107.78614422518586
# Episode 17425 finished after 359 timesteps. Return = -294.0888204114799
# Episode 17426 finished after 241 timesteps. Return = -8.285798738777814
# Episode 17427 finished after 157 timesteps. Return = 36.0314385623291
# Episode 17428 finished after 269 timesteps. Return = -214.80621703314637
# Episode 17429 finished after 335 timesteps. Return = -245.7677187949638
# Episode 17430 finished after 191 timesteps. Return = -82.16651788966793
# Episode 17431 finished after 111 timesteps. Return = 7.98657415928426
# Episode 17432 finished after 348 timesteps. Return = 4.185327366247023
# Episode 17433 finished after 276 timesteps. Return = -99.86526388919025
# Episode 17434 finished after 256 timesteps. Return = -191.947424124522
# Episode 17435 finished after 1000 timesteps. Return = -48.23859603062556
# Episode 17436 finished after 1000 timesteps. Return = 41.22586760718045
# Episode 17437 finished after 233 timesteps. Return = -25.404939845274768
# Episode 17438 finished after 376 timesteps. Return = -179.06144684424686
# Episode 17439 finished after 1000 timesteps. Return = 43.15874726344422
# Episode 17440 finished after 193 timesteps. Return = 31.1151221420279
# Episode 17441 finished after 1000 timesteps. Return = 48.859296910631905
# Episode 17442 finished after 308 timesteps. Return = -0.9789107491944691
# Episode 17443 finished after 191 timesteps. Return = -257.3622321588564
# Episode 17444 finished after 1000 timesteps. Return = 45.85201874023915
# Episode 17445 finished after 285 timesteps. Return = -256.720402923636
# Episode 17446 finished after 186 timesteps. Return = -63.0597645381398
# Episode 17447 finished after 211 timesteps. Return = -104.99107617473297
# Episode 17448 finished after 325 timesteps. Return = -205.93453060863328
# Episode 17449 finished after 264 timesteps. Return = -30.861487761808277
# Episode 17450 finished after 395 timesteps. Return = -178.30270249419323
# Episode 17451 finished after 1000 timesteps. Return = -44.66527855229852
# Episode 17452 finished after 1000 timesteps. Return = -16.86628614748921
# Episode 17453 finished after 203 timesteps. Return = -116.14593203287671
# Episode 17454 finished after 134 timesteps. Return = 13.389448057868705
# Episode 17455 finished after 192 timesteps. Return = -22.020237689290184
# Episode 17456 finished after 110 timesteps. Return = 28.50328850646838
# Episode 17457 finished after 1000 timesteps. Return = 22.722166646263904
# Episode 17458 finished after 1000 timesteps. Return = -59.65069897037128
# Episode 17459 finished after 999 timesteps. Return = -214.5525579624367
# Episode 17460 finished after 1000 timesteps. Return = 105.96362032104793
# Episode 17461 finished after 214 timesteps. Return = 8.78226155676856
# Episode 17462 finished after 793 timesteps. Return = -206.76796352530238
# Episode 17463 finished after 254 timesteps. Return = -29.413014754071682
# Episode 17464 finished after 1000 timesteps. Return = 46.471704971682264
# Episode 17465 finished after 485 timesteps. Return = -67.29762084785193
# Episode 17466 finished after 1000 timesteps. Return = 81.25164361456387
# Episode 17467 finished after 1000 timesteps. Return = 34.54635563429803
# Episode 17468 finished after 258 timesteps. Return = -15.983726675290143
# Episode 17469 finished after 271 timesteps. Return = 25.603836994260448
# Episode 17470 finished after 127 timesteps. Return = -194.75019407550144
# Episode 17471 finished after 702 timesteps. Return = -182.66218695591795
# Episode 17472 finished after 240 timesteps. Return = 18.31108145734929
# Episode 17473 finished after 1000 timesteps. Return = 25.95850552525931
# Episode 17474 finished after 87 timesteps. Return = -19.05381440810261
# Episode 17475 finished after 907 timesteps. Return = -388.42911309051084
# Episode 17476 finished after 323 timesteps. Return = -225.04347426143423
# Episode 17477 finished after 1000 timesteps. Return = -13.411568025462639
# Episode 17478 finished after 1000 timesteps. Return = 85.268462544637
# Episode 17479 finished after 121 timesteps. Return = -7.97666103202458
# Episode 17480 finished after 227 timesteps. Return = 25.001891832395714
# Episode 17481 finished after 108 timesteps. Return = -24.610216215131587
# Episode 17482 finished after 1000 timesteps. Return = 63.8886118586191
# Episode 17483 finished after 264 timesteps. Return = -6.644940662992369
# Episode 17484 finished after 1000 timesteps. Return = 115.30010605100352
# Episode 17485 finished after 672 timesteps. Return = -266.7087757248867
# Episode 17486 finished after 178 timesteps. Return = 36.57890660365453
# Episode 17487 finished after 381 timesteps. Return = -221.7741190709014
# Episode 17488 finished after 1000 timesteps. Return = 49.88871383043635
# Episode 17489 finished after 1000 timesteps. Return = 110.70838616723375
# Episode 17490 finished after 643 timesteps. Return = -298.035978842193
# Episode 17491 finished after 359 timesteps. Return = -252.27002096920742
# Episode 17492 finished after 173 timesteps. Return = 31.536156168090486
# Episode 17493 finished after 126 timesteps. Return = -133.38114407506586
# Episode 17494 finished after 207 timesteps. Return = -9.089221771248702
# Episode 17495 finished after 221 timesteps. Return = -22.114032739116084
# Episode 17496 finished after 1000 timesteps. Return = 46.93845831998821
# Episode 17497 finished after 113 timesteps. Return = -34.75960502970936
# Episode 17498 finished after 250 timesteps. Return = 27.480265407344845
# Episode 17499 finished after 296 timesteps. Return = -25.79967447054034
# Episode 17500 finished after 145 timesteps. Return = 13.459095993320261
# Episode 17501 finished after 1000 timesteps. Return = -20.457717476137965
# Episode 17502 finished after 1000 timesteps. Return = 80.53574088189916
# Episode 17503 finished after 184 timesteps. Return = 57.872926827565635
# Episode 17504 finished after 150 timesteps. Return = -46.262622724395044
# Episode 17505 finished after 266 timesteps. Return = 9.42331480891066
# Episode 17506 finished after 190 timesteps. Return = -2.824116590743685
# Episode 17507 finished after 96 timesteps. Return = -31.16823459358345
# Episode 17508 finished after 1000 timesteps. Return = 57.040756039101986
# Episode 17509 finished after 155 timesteps. Return = -74.6878214508875
# Episode 17510 finished after 1000 timesteps. Return = 59.054418008892554
# Episode 17511 finished after 1000 timesteps. Return = 75.5558782910417
# Episode 17512 finished after 147 timesteps. Return = -163.8581530714301
# Episode 17513 finished after 381 timesteps. Return = -213.8799491659452
# Episode 17514 finished after 197 timesteps. Return = -17.669592971354504
# Episode 17515 finished after 1000 timesteps. Return = 82.8577254471505
# Episode 17516 finished after 519 timesteps. Return = -185.67357783648183
# Episode 17517 finished after 473 timesteps. Return = -207.95847223995912
# Episode 17518 finished after 230 timesteps. Return = -47.64582551987726
# Episode 17519 finished after 422 timesteps. Return = -265.84381159736756
# Episode 17520 finished after 172 timesteps. Return = -50.084866393674744
# Episode 17521 finished after 259 timesteps. Return = -49.87937460316358
# Episode 17522 finished after 1000 timesteps. Return = 79.33628755087038
# Episode 17523 finished after 186 timesteps. Return = 32.418884335489764
# Episode 17524 finished after 261 timesteps. Return = -47.57276839246083
# Episode 17525 finished after 372 timesteps. Return = -9.815424151060682
# Episode 17526 finished after 359 timesteps. Return = -184.18160781287546
# Episode 17527 finished after 1000 timesteps. Return = 32.991518611751026
# Episode 17528 finished after 105 timesteps. Return = 37.3192859152048
# Episode 17529 finished after 151 timesteps. Return = -13.48854512709184
# Episode 17530 finished after 202 timesteps. Return = -2.9008664034502516
# Episode 17531 finished after 181 timesteps. Return = -217.5458071267147
# Episode 17532 finished after 161 timesteps. Return = 25.39563759079762
# Episode 17533 finished after 213 timesteps. Return = -8.438585980014082
# Episode 17534 finished after 326 timesteps. Return = -38.87671166031522
# Episode 17535 finished after 273 timesteps. Return = -57.19436417300635
# Episode 17536 finished after 219 timesteps. Return = 25.67498137848537
# Episode 17537 finished after 1000 timesteps. Return = 60.3290286971737
# Episode 17538 finished after 128 timesteps. Return = 15.16501173508206
# Episode 17539 finished after 124 timesteps. Return = 22.549705665365224
# Episode 17540 finished after 406 timesteps. Return = -172.4458713161213
# Episode 17541 finished after 296 timesteps. Return = -34.520125477688
# Episode 17542 finished after 169 timesteps. Return = -5.576197945954732
# Episode 17543 finished after 207 timesteps. Return = 11.782620212225154
# Episode 17544 finished after 120 timesteps. Return = 2.3544605826271265
# Episode 17545 finished after 1000 timesteps. Return = 27.536442783947553
# Episode 17546 finished after 164 timesteps. Return = 34.88438069309072
# Episode 17547 finished after 1000 timesteps. Return = 91.7439150214108
# Episode 17548 finished after 262 timesteps. Return = -13.002713484478647
# Episode 17549 finished after 212 timesteps. Return = -314.6799202891559
# Episode 17550 finished after 161 timesteps. Return = -16.58857889143593
# Episode 17551 finished after 788 timesteps. Return = -215.08513930554744
# Episode 17552 finished after 130 timesteps. Return = -18.55939246761345
# Episode 17553 finished after 1000 timesteps. Return = 88.67747319440576
# Episode 17554 finished after 1000 timesteps. Return = 38.72732329155353
# Episode 17555 finished after 1000 timesteps. Return = 61.251769332830335
# Episode 17556 finished after 283 timesteps. Return = -36.87898342276233
# Episode 17557 finished after 925 timesteps. Return = -181.24841734293054
# Episode 17558 finished after 166 timesteps. Return = 34.451799227015385
# Episode 17559 finished after 631 timesteps. Return = -202.2545898172858
# Episode 17560 finished after 1000 timesteps. Return = -33.58492305376207
# Episode 17561 finished after 682 timesteps. Return = -259.2761521271701
# Episode 17562 finished after 1000 timesteps. Return = 92.41154469669875
# Episode 17563 finished after 1000 timesteps. Return = -29.664847963465967
# Episode 17564 finished after 431 timesteps. Return = -264.94060451625904
# Episode 17565 finished after 294 timesteps. Return = 14.571099388699963
# Episode 17566 finished after 125 timesteps. Return = 33.250820378379046
# Episode 17567 finished after 1000 timesteps. Return = 38.85564501572546
# Episode 17568 finished after 192 timesteps. Return = -82.08484163336007
# Episode 17569 finished after 291 timesteps. Return = -167.76948968434152
# Episode 17570 finished after 1000 timesteps. Return = 77.34616063455691
# Episode 17571 finished after 244 timesteps. Return = -26.104252729241054
# Episode 17572 finished after 200 timesteps. Return = -210.23253800442984
# Episode 17573 finished after 334 timesteps. Return = -159.4678284151348
# Episode 17574 finished after 288 timesteps. Return = -194.8657972956017
# Episode 17575 finished after 999 timesteps. Return = -164.6961943302589
# Episode 17576 finished after 621 timesteps. Return = -255.83113096748033
# Episode 17577 finished after 237 timesteps. Return = -31.939241716891217
# Episode 17578 finished after 1000 timesteps. Return = -32.48870260019625
# Episode 17579 finished after 299 timesteps. Return = -104.43689675386851
# Episode 17580 finished after 149 timesteps. Return = -94.86104688854249
# Episode 17581 finished after 191 timesteps. Return = 22.558784666798275
# Episode 17582 finished after 186 timesteps. Return = 38.57139655981965
# Episode 17583 finished after 223 timesteps. Return = -253.373327997064
# Episode 17584 finished after 647 timesteps. Return = -159.31725856885308
# Episode 17585 finished after 169 timesteps. Return = -37.006719099872974
# Episode 17586 finished after 1000 timesteps. Return = 60.41182313395224
# Episode 17587 finished after 1000 timesteps. Return = 59.81594427578259
# Episode 17588 finished after 1000 timesteps. Return = 125.75275231420055
# Episode 17589 finished after 156 timesteps. Return = -36.432203035191215
# Episode 17590 finished after 269 timesteps. Return = -45.89607742407945
# Episode 17591 finished after 190 timesteps. Return = -64.18033836591997
# Episode 17592 finished after 173 timesteps. Return = -148.3467137013834
# Episode 17593 finished after 212 timesteps. Return = -145.99859426497065
# Episode 17594 finished after 148 timesteps. Return = 0.7137792395851505
# Episode 17595 finished after 201 timesteps. Return = 3.39846722296825
# Episode 17596 finished after 159 timesteps. Return = -3.9846628978661727
# Episode 17597 finished after 191 timesteps. Return = -41.163573511559264
# Episode 17598 finished after 138 timesteps. Return = 8.391018391757513
# Episode 17599 finished after 1000 timesteps. Return = 107.42098596528271
# Episode 17600 finished after 198 timesteps. Return = -12.277621787908942
# Episode 17601 finished after 292 timesteps. Return = -27.630906489693885
# Episode 17602 finished after 1000 timesteps. Return = 88.25815896685077
# Episode 17603 finished after 158 timesteps. Return = -84.63378829758804
# Episode 17604 finished after 107 timesteps. Return = -43.84988813943419
# Episode 17605 finished after 1000 timesteps. Return = 85.70137482690325
# Episode 17606 finished after 149 timesteps. Return = 1.1791601875523838
# Episode 17607 finished after 1000 timesteps. Return = 54.0681331110992
# Episode 17608 finished after 239 timesteps. Return = -266.7486482584782
# Episode 17609 finished after 383 timesteps. Return = -139.76963212612068
# Episode 17610 finished after 1000 timesteps. Return = 77.7353875414391
# Episode 17611 finished after 469 timesteps. Return = -34.85374239710664
# Episode 17612 finished after 133 timesteps. Return = 7.752565683551566
# Episode 17613 finished after 1000 timesteps. Return = 68.7107738040449
# Episode 17614 finished after 90 timesteps. Return = 9.661432124671236
# Episode 17615 finished after 1000 timesteps. Return = 46.25768645497181
# Episode 17616 finished after 97 timesteps. Return = -16.538479805652656
# Episode 17617 finished after 136 timesteps. Return = -46.01079888926012
# Episode 17618 finished after 224 timesteps. Return = 32.67149759822016
# Episode 17619 finished after 213 timesteps. Return = -31.198831542143182
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3325                 else:
# -> 3326                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3327             finally:
#
# <ipython-input-178-79b06f4f96af> in <module>
#       2 for i in range(n_iters):
# ----> 3     replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
#       4     train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
#torch.save(agent.state_dict(), 'checkpoints/lunar_lander_64x64_checkpoint_0.pt')
#agent.load_state_dict(torch.load('checkpoints/lunar_lander_32x32_checkpoint_0.pt'))

# %%
visualise_agent(greedy_policy, command=[150, 400], n=5)
# Out:
# Episode 0 finished after 833 timesteps. Return = -360.375805006002

# %%
visualise_agent(stochastic_policy, command=[150, 400], n=5)
# Out:
# Episode 0 finished after 213 timesteps. Return = -27.11786348432311
# Episode 1 finished after 271 timesteps. Return = -226.95918413035955
# Episode 2 finished after 325 timesteps. Return = -26.1805768711521

# %%
print([mem['return'] for mem in replay_buffer])

# %% [markdown]
# # Previous Code

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64):
    all_costs = []
    for i in range(n_updates):
        batch_input = np.zeros((batch_size, np.prod(env.observation_space.shape)+2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_horizon = np.random.randint(1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_mem_idx = np.random.randint(0, len(replay_buffer[sample_episode]['observation'])+1-sample_horizon)
            sample_mem = replay_buffer[sample_episode]['observation'][sample_mem_idx]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_mem_idx]
            batch_input[b] = network_input
            batch_label[b] = label
        batch_input = torch.tensor(batch_input).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_input)
        cost = F.cross_entropy(pred, batch_label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train_net(policy_net, episode_mem, n_samples = 5): #stochastic gradient descent
    all_costs = []
    for i in range(n_samples):
        sample_horizon = np.random.randint(1, len(episode_mem['observation'])+1)
        sample_mem_idx = np.random.randint(0, len(episode_mem['observation'])+1-sample_horizon)
        sample_mem = episode_mem['observation'][sample_mem_idx]
        sample_desired_reward = sum(episode_mem['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
        network_input = torch.tensor(np.append(sample_mem, [sample_desired_reward, sample_horizon])).double()
        label = torch.tensor([episode_mem['action'][sample_mem_idx]]).double()
        
        pred = policy_net(network_input)
        cost = F.binary_cross_entropy(pred, label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train(policy_net, n_episodes=100):
    global i_episode
    global epsilon
    try:
        for _ in range(n_episodes):
            observation = env.reset()
            episode_mem = {'observation':[],
                            'action':[],
                            'reward':[],
                            'done':[]}
            done=False
            while not done:
                network_input = torch.tensor(np.append(observation, [desired_reward, command_horizon])).double()
                action_prob = policy_net(network_input)
                action = np.random.binomial(1, action_prob.item())
                #action = int(action_prob.item()>0.5)
                if np.random.rand()<epsilon: action = np.random.randint(0, 2)
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                episode_mem['done'].append(done)
                
                observation=new_observation
                epsilon*=0.999
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            mean_cost = train_net(policy_net, episode_mem)
            
            i_episode+=1
            print("Episode {} finished after {} timesteps. Epsilon={} Mean Cost={}".format(i_episode, len(episode_mem['observation']), epsilon, mean_cost))
        env.close()
    except KeyboardInterrupt:
        env.close()
