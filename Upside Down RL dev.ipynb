# %% [markdown]
# ### This file is for testing radical changes to the codebase. Upside Down Reinforcement Learning.py is the working version.

# %%
import gym
env = gym.make('CartPole-v1')

# %%
import numpy as np
def random_policy(obs, command):
    return np.random.randint(env.action_space.n)

# %%
import time
from copy import deepcopy
#Visualise agent function
def visualise_agent(policy, command, n=5):
    try:
        for trial_i in range(n):
            current_command = deepcopy(command)
            observation = env.reset()
            done=False
            t=0
            episode_return=0
            while not done:
                env.render()
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                observation, reward, done, info = env.step(action)
                episode_return+=reward
                #time.sleep(0.1)
                current_command[0]-= reward
                current_command[1] = max(1, current_command[1]-1)
                
                t+=1
            env.render()
            time.sleep(1.5)
            print("Episode {} finished after {} timesteps. Return = {}".format(trial_i, t, episode_return))
        env.close()
    except KeyboardInterrupt:
        env.close()

# %%
#visualise_agent(random_policy, command=[500, 500], 1)

# %%
from copy import deepcopy
def collect_experience(policy, replay_buffer, replay_size, last_few, n_episodes=100, log_to_tensorboard=True):
    global i_episode
    init_replay_buffer = deepcopy(replay_buffer)
    try:
        for _ in range(n_episodes):
            command = sample_command(init_replay_buffer, last_few)
            writer.add_scalar('Command desired reward', command[0], i_episode)    # write loss to a graph
            writer.add_scalar('Command horizon', command[1], i_episode)    # write loss to a graph
            observation = env.reset()
            episode_mem = {'observation':[],
#                           'command':[],
                           'action':[],
                           'reward':[],}
            done=False
            while not done:
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                #episode_mem['command'].append(command)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                
                observation=new_observation
                #command[0]-= reward
                command[0] = max(1, command[0]-reward)
                command[1] = max(1, command[1]-1)
                print(command)
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            replay_buffer.append(episode_mem)
            i_episode+=1
            if log_to_tensorboard: writer.add_scalar('Return', sum(episode_mem['reward']), i_episode)    # write loss to a graph
            print("Episode {} finished after {} timesteps. Return = {}".format(i_episode, len(episode_mem['observation']), sum(episode_mem['reward'])))
        env.close()
    except KeyboardInterrupt:
        env.close()
    replay_buffer = sorted(replay_buffer, key=lambda x:x['return'])[-replay_size:]
    return replay_buffer

def sample_command(replay_buffer, last_few):
    if len(replay_buffer)==0:
        return [1, 1]
    else:
        command_samples = replay_buffer[-last_few:]
        lengths = [mem['episode_len'] for mem in command_samples]
        returns = [mem['return'] for mem in command_samples]
        mean_return, std_return = np.mean(returns), np.std(returns)
        command_horizon = np.mean(lengths)
        desired_reward = np.random.uniform(mean_return, mean_return+std_return)
        return [desired_reward, command_horizon]

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64, log_to_tensorboard=True):
    global i_updates
    all_costs = []
    for i in range(n_updates):
        batch_observations = np.zeros((batch_size, np.prod(env.observation_space.shape)))
        batch_commands = np.zeros((batch_size, 2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
            sample_t2 = len(replay_buffer[sample_episode]['observation'])
            sample_horizon = sample_t2-sample_t1
            sample_mem = replay_buffer[sample_episode]['observation'][sample_t1]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_t1:sample_t2])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_t1]
            batch_observations[b] = sample_mem
            batch_commands[b] = [sample_desired_reward, sample_horizon]
            batch_label[b] = label
        batch_observations = torch.tensor(batch_observations).double()
        batch_commands = torch.tensor(batch_commands).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_observations, batch_commands)
        cost = F.cross_entropy(pred, batch_label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def create_greedy_policy(policy_network):
    def policy(obs, command):
        action_prob = policy_network(obs, command)
        action = np.argmax(action_prob.detach().numpy())
        return action
    return policy

def create_stochastic_policy(policy_network):
    def policy(obs, command):
        action_prob = policy_network(obs, command)
        action_sample = np.random.multinomial(1, action_prob.detach().numpy())
        action = np.argmax(action_sample)
        return action
    return policy

# %%
import torch
import torch.nn.functional as F

class FCNN_AGENT(torch.nn.Module):
    def __init__(self):
        super().__init__()
        hidden_size=64
        self.observation_embedding = torch.nn.Sequential(
            torch.nn.Linear(np.prod(env.observation_space.shape), hidden_size),
            torch.nn.ReLU()
        )
        self.command_embedding = torch.nn.Sequential(
            torch.nn.Linear(2, hidden_size),
            torch.nn.Sigmoid()
        )
        self.to_output = torch.nn.Sequential(
            torch.nn.Linear(hidden_size, hidden_size),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_size, env.action_space.n)
        )
    
    def forward(self, observation, command):
        obs_emebdding = self.observation_embedding(observation)
        #print(obs_emebdding.shape)
        cmd_embedding = self.command_embedding(command)
        print(cmd_embedding.shape)
        embedding = torch.mul(obs_emebdding, cmd_embedding)
        #print(embedding.shape)
        action_probs = F.softmax(self.to_output(embedding), dim=-1)
        #print(action_probs.shape)
        #gg
        return action_probs
    
    def create_optimizer(self, lr):
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)

# %%
i_episode=0
i_updates=0
replay_buffer = []
replay_size = 500
last_few = 50
log_to_tensorboard = True 

batch_size = 128
n_warm_up_episodes = 100
n_episodes_per_iter = 50
n_updates_per_iter = 100

lr = 0.001
agent = FCNN_AGENT().double()
agent.create_optimizer(lr)

stochastic_policy = create_stochastic_policy(agent)
greedy_policy = create_greedy_policy(agent)

# %%
# SET UP TRAINING VISUALISATION
# SET UP TRAINING VISUALISATION
if log_to_tensorboard: from torch.utils.tensorboard import SummaryWriter
if log_to_tensorboard: writer = SummaryWriter() # we will use this to show our models performance on a graph using tensorboard

# %%
#Collect warm up episodes
replay_buffer = collect_experience(random_policy, replay_buffer, replay_size, last_few, n_warm_up_episodes, log_to_tensorboard)
train_net(agent, replay_buffer, n_updates=n_updates_per_iter, batch_size=batch_size, log_to_tensorboard)
# Out:
#   File "<ipython-input-129-09b1fadbae1d>", line 3
#     train_net(agent, replay_buffer, n_updates=n_updates_per_iter, batch_size=batch_size, log_to_tensorboard)
#                                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
n_iters = 10000
for i in range(n_iters):
    replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
    train_net(agent, replay_buffer, n_updates=n_updates_per_iter, batch_size=batch_size, log_to_tensorboard)
# Out:
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 101 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 102 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 103 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 104 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 105 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 106 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 107 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 108 finished after 11 timesteps. Return = 11.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 109 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 110 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 111 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 112 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 113 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 114 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 115 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 116 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 117 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 118 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 119 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 120 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 121 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 122 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 123 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 124 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 125 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 126 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 127 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 128 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 129 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 130 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 131 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 132 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 133 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 134 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 135 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 136 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 137 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 138 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 139 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 140 finished after 11 timesteps. Return = 11.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 141 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 142 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 143 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 144 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 145 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 146 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 147 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 148 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 149 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 150 finished after 10 timesteps. Return = 10.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 151 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 152 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 153 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 154 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 155 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 156 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 157 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 158 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 159 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 160 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 161 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 162 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 163 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 164 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 165 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 166 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 167 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 168 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 169 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 170 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 171 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 172 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 173 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 174 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 175 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 176 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 177 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 178 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 179 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 180 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 181 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 182 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 183 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 184 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 185 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 186 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 187 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 188 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 189 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 190 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 191 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 192 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 193 finished after 11 timesteps. Return = 11.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 194 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 195 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 196 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 197 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 198 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 199 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 200 finished after 9 timesteps. Return = 9.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 201 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 202 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 203 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 204 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 205 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 206 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 207 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 208 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 209 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 210 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 211 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 212 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 213 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 214 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 215 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 216 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 217 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 218 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 219 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 220 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 221 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 222 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 223 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 224 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 225 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 226 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 227 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 228 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 229 finished after 11 timesteps. Return = 11.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 230 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 231 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 232 finished after 11 timesteps. Return = 11.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 233 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 234 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 235 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 236 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 237 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 238 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 239 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 240 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 241 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 242 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 243 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 244 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 245 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 246 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 247 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 248 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 249 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 250 finished after 10 timesteps. Return = 10.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 251 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 252 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 253 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 254 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 255 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 256 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 257 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 258 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 259 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 260 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 261 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 262 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 263 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 264 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 265 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 266 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 267 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 268 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 269 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 270 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# ...
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 539 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 540 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 541 finished after 11 timesteps. Return = 11.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 542 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 543 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 544 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 545 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 546 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 547 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 548 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 549 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 550 finished after 8 timesteps. Return = 8.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 551 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 552 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 553 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 554 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 555 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 556 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 557 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 558 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 559 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 560 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 561 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 562 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 563 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 564 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 565 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 566 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 567 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 568 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 569 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 570 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 571 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 572 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 573 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 574 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 575 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 576 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 577 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 578 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 579 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 580 finished after 10 timesteps. Return = 10.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 581 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 582 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 583 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 584 finished after 8 timesteps. Return = 8.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 585 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 586 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 587 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# torch.Size([1, 64])
# Episode 588 finished after 9 timesteps. Return = 9.0
# torch.Size([1, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-cb7d36c641f8> in <module>
#       2 for i in range(n_iters):
#       3     replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
# ----> 4     train_net(agent, replay_buffer, n_updates=n_updates_per_iter, batch_size=batch_size)
#
# <ipython-input-112-b34e1357b4ef> in train_net(policy_net, replay_buffer, n_updates, batch_size)
#       7         for b in range(batch_size):
#       8             sample_episode = np.random.randint(0, len(replay_buffer))
# ----> 9             sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
#      10             sample_t2 = len(replay_buffer[sample_episode]['observation'])
#      11             sample_horizon = sample_t2-sample_t1
#
# KeyboardInterrupt:

# %%
#agent.load_state_dict(torch.load('checkpoints/lunar_lander_32x32_checkpoint_0.pt'))

# %%
visualise_agent(greedy_policy, command=[250, 200], n=5)
# Out:
# Episode 0 finished after 84 timesteps. Return = -134.1428887684655
# Episode 1 finished after 62 timesteps. Return = -143.282848576283
# Episode 2 finished after 72 timesteps. Return = -0.15610989654310004
# Episode 3 finished after 106 timesteps. Return = -72.03684838919166
# Episode 4 finished after 105 timesteps. Return = -37.44217835732849

# %%
visualise_agent(stochastic_policy, command=[250, 200], n=5)
# Out:
# Episode 0 finished after 97 timesteps. Return = -89.47575725612703

# %%
#torch.save(agent.state_dict(), 'checkpoints/lunar_lander_32x32_checkpoint_0.pt')

# %%
#print([mem['return'] for mem in replay_buffer])

# %% [markdown]
# # Previous Code

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64):
    all_costs = []
    for i in range(n_updates):
        batch_input = np.zeros((batch_size, np.prod(env.observation_space.shape)+2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_horizon = np.random.randint(1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_mem_idx = np.random.randint(0, len(replay_buffer[sample_episode]['observation'])+1-sample_horizon)
            sample_mem = replay_buffer[sample_episode]['observation'][sample_mem_idx]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_mem_idx]
            batch_input[b] = network_input
            batch_label[b] = label
        batch_input = torch.tensor(batch_input).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_input)
        cost = F.cross_entropy(pred, batch_label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train_net(policy_net, episode_mem, n_samples = 5): #stochastic gradient descent
    all_costs = []
    for i in range(n_samples):
        sample_horizon = np.random.randint(1, len(episode_mem['observation'])+1)
        sample_mem_idx = np.random.randint(0, len(episode_mem['observation'])+1-sample_horizon)
        sample_mem = episode_mem['observation'][sample_mem_idx]
        sample_desired_reward = sum(episode_mem['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
        network_input = torch.tensor(np.append(sample_mem, [sample_desired_reward, sample_horizon])).double()
        label = torch.tensor([episode_mem['action'][sample_mem_idx]]).double()
        
        pred = policy_net(network_input)
        cost = F.binary_cross_entropy(pred, label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train(policy_net, n_episodes=100):
    global i_episode
    global epsilon
    try:
        for _ in range(n_episodes):
            observation = env.reset()
            episode_mem = {'observation':[],
                            'action':[],
                            'reward':[],
                            'done':[]}
            done=False
            while not done:
                network_input = torch.tensor(np.append(observation, [desired_reward, command_horizon])).double()
                action_prob = policy_net(network_input)
                action = np.random.binomial(1, action_prob.item())
                #action = int(action_prob.item()>0.5)
                if np.random.rand()<epsilon: action = np.random.randint(0, 2)
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                episode_mem['done'].append(done)
                
                observation=new_observation
                epsilon*=0.999
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            mean_cost = train_net(policy_net, episode_mem)
            
            i_episode+=1
            print("Episode {} finished after {} timesteps. Epsilon={} Mean Cost={}".format(i_episode, len(episode_mem['observation']), epsilon, mean_cost))
        env.close()
    except KeyboardInterrupt:
        env.close()
