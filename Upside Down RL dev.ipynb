# %% [markdown]
# ### This file is for testing radical changes to the codebase. Upside Down Reinforcement Learning.py is the working version.

# %%
import time
from copy import deepcopy
import gym
import numpy as np
import torch
import torch.nn.functional as F

# %%
env = gym.make('LunarLander-v2')

# %%
#command takes form [derired reward, desired horizon]
def random_policy(obs, command):
    return np.random.randint(env.action_space.n)

# %%
#Visualise agent function
def visualise_agent(policy, command, n=5):
    try:
        for trial_i in range(n):
            current_command = deepcopy(command)
            observation = env.reset()
            done=False
            t=0
            episode_return=0
            while not done:
                env.render()
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                observation, reward, done, info = env.step(action)
                episode_return+=reward
                current_command[0]-= reward
                current_command[1] = max(1, current_command[1]-1)
                t+=1
            env.render()
            time.sleep(1.5)
            print("Episode {} finished after {} timesteps. Return = {}".format(trial_i, t, episode_return))
        env.close()
    except KeyboardInterrupt:
        env.close()

# %%
#visualise_agent(random_policy, command=[500, 500], n=3)

# %%
class FCNN_AGENT(torch.nn.Module):
    def __init__(self, command_scale):
        super().__init__()
        embedding_size=32
        hidden_size=64
        self.command_scale=command_scale
        self.observation_embedding = torch.nn.Sequential(
            torch.nn.Linear(np.prod(env.observation_space.shape), embedding_size),
            torch.nn.Tanh()
        )
        self.command_embedding = torch.nn.Sequential(
            torch.nn.Linear(2, embedding_size),
            torch.nn.Sigmoid()
        )
        self.to_output = torch.nn.Sequential(
            torch.nn.Linear(embedding_size, hidden_size),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_size, hidden_size),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_size, env.action_space.n)
        )
    
    def forward(self, observation, command):
        obs_emebdding = self.observation_embedding(observation)
        cmd_embedding = self.command_embedding(command*self.command_scale)
        embedding = torch.mul(obs_emebdding, cmd_embedding)
        action_prob_logits = self.to_output(embedding)
        return action_prob_logits
    
    def create_optimizer(self, lr):
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)

# %%
def collect_experience(policy, replay_buffer, replay_size, last_few, n_episodes=100, log_to_tensorboard=True):
    global i_episode
    init_replay_buffer = deepcopy(replay_buffer)
    try:
        for _ in range(n_episodes):
            command = sample_command(init_replay_buffer, last_few)
            writer.add_scalar('Command desired reward/Episode', command[0], i_episode)    # write loss to a graph
            writer.add_scalar('Command horizon/Episode', command[1], i_episode)    # write loss to a graph
            observation = env.reset()
            episode_mem = {'observation':[],
                           'action':[],
                           'reward':[],}
            done=False
            while not done:
                action = policy(torch.tensor([observation]).double(), torch.tensor([command]).double())
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                
                observation=new_observation
                command[0]-= reward
                command[1] = max(1, command[1]-1)
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            replay_buffer.append(episode_mem)
            i_episode+=1
            if log_to_tensorboard: writer.add_scalar('Return/Episode', sum(episode_mem['reward']), i_episode)    # write loss to a graph
            print("Episode {} finished after {} timesteps. Return = {}".format(i_episode, len(episode_mem['observation']), sum(episode_mem['reward'])))
        env.close()
    except KeyboardInterrupt:
        env.close()
    replay_buffer = sorted(replay_buffer, key=lambda x:x['return'])[-replay_size:]
    return replay_buffer

def sample_command(replay_buffer, last_few):
    if len(replay_buffer)==0:
        return [1, 1]
    else:
        command_samples = replay_buffer[-last_few:]
        lengths = [mem['episode_len'] for mem in command_samples]
        returns = [mem['return'] for mem in command_samples]
        mean_return, std_return = np.mean(returns), np.std(returns)
        command_horizon = np.mean(lengths)
        desired_reward = np.random.uniform(mean_return, mean_return+std_return)
        return [desired_reward, command_horizon]

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64, log_to_tensorboard=True):
    global i_updates
    all_costs = []
    for i in range(n_updates):
        batch_observations = np.zeros((batch_size, np.prod(env.observation_space.shape)))
        batch_commands = np.zeros((batch_size, 2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
            sample_t2 = len(replay_buffer[sample_episode]['observation'])
            ##sample_t2 = np.random.randint(sample_t1+1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_horizon = sample_t2-sample_t1
            sample_mem = replay_buffer[sample_episode]['observation'][sample_t1]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_t1:sample_t2])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_t1]
            batch_observations[b] = sample_mem
            batch_commands[b] = [sample_desired_reward, sample_horizon]
            batch_label[b] = label
        batch_observations = torch.tensor(batch_observations).double()
        batch_commands = torch.tensor(batch_commands).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_observations, batch_commands)
        cost = F.cross_entropy(pred, batch_label)
        if log_to_tensorboard: writer.add_scalar('Cost/NN update', cost.item() , i_updates)    # write loss to a graph
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
        i_updates+=1
    return np.mean(all_costs)

# %%
def create_greedy_policy(policy_network):
    def policy(obs, command):
        action_logits = policy_network(obs, command)
        action = np.argmax(action_logits.detach().numpy())
        return action
    return policy

def create_stochastic_policy(policy_network):
    def policy(obs, command):
        action_logits = policy_network(obs, command)
        action_probs = F.softmax(action_logits, dim=-1)
        action = torch.distributions.Categorical(action_probs).sample().item()
        return action
    return policy

# %%
i_episode=0
i_updates=0 #number of parameter updates to the neural network
replay_buffer = []
log_to_tensorboard = True

replay_size = 600
last_few = 50
batch_size = 128
n_warm_up_episodes = 50
n_episodes_per_iter = 50
n_updates_per_iter = 100
command_scale = 0.02
lr = 0.001

agent = FCNN_AGENT(command_scale).double()
agent.create_optimizer(lr)

stochastic_policy = create_stochastic_policy(agent)
greedy_policy = create_greedy_policy(agent)

# %%
# SET UP TRAINING VISUALISATION
# SET UP TRAINING VISUALISATION
if log_to_tensorboard: from torch.utils.tensorboard import SummaryWriter
if log_to_tensorboard: writer = SummaryWriter() # we will use this to show our models performance on a graph using tensorboard

# %%
#Collect warm up episodes
replay_buffer = collect_experience(random_policy, replay_buffer, replay_size, last_few, n_warm_up_episodes, log_to_tensorboard)
train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
# Out:
# Episode 1 finished after 113 timesteps. Return = -390.6940084980434
# Episode 2 finished after 95 timesteps. Return = -120.41847788549137
# Episode 3 finished after 83 timesteps. Return = -63.466702803711684
# Episode 4 finished after 92 timesteps. Return = -483.2119955776536
# Episode 5 finished after 76 timesteps. Return = -65.54904155474622
# Episode 6 finished after 85 timesteps. Return = -330.4744824335155
# Episode 7 finished after 71 timesteps. Return = -101.51475416269122
# Episode 8 finished after 132 timesteps. Return = -106.36861748934871
# Episode 9 finished after 80 timesteps. Return = -139.41218679279342
# Episode 10 finished after 90 timesteps. Return = -118.64424067999293
# Episode 11 finished after 122 timesteps. Return = -123.55016476157775
# Episode 12 finished after 77 timesteps. Return = -129.0480454451287
# Episode 13 finished after 76 timesteps. Return = -159.92647263149016
# Episode 14 finished after 137 timesteps. Return = -358.05057496315317
# Episode 15 finished after 62 timesteps. Return = -78.70511194824151
# Episode 16 finished after 75 timesteps. Return = -196.13527546573795
# Episode 17 finished after 64 timesteps. Return = -101.04524762216595
# Episode 18 finished after 62 timesteps. Return = -208.29367999886603
# Episode 19 finished after 136 timesteps. Return = -30.91920611850557
# Episode 20 finished after 93 timesteps. Return = -476.39102322807986
# Episode 21 finished after 78 timesteps. Return = -67.6332196926254
# Episode 22 finished after 74 timesteps. Return = -291.49735702008684
# Episode 23 finished after 84 timesteps. Return = -292.6208750542253
# Episode 24 finished after 89 timesteps. Return = -152.71841441497298
# Episode 25 finished after 102 timesteps. Return = -119.6614510517698
# Episode 26 finished after 141 timesteps. Return = -135.9423894685916
# Episode 27 finished after 62 timesteps. Return = -98.82689774390309
# Episode 28 finished after 92 timesteps. Return = -310.8055735361299
# Episode 29 finished after 62 timesteps. Return = -142.8018608869976
# Episode 30 finished after 75 timesteps. Return = -131.18412270622568
# Episode 31 finished after 105 timesteps. Return = -127.70452037193601
# Episode 32 finished after 121 timesteps. Return = -410.0746428646208
# Episode 33 finished after 91 timesteps. Return = -313.6564971448681
# Episode 34 finished after 68 timesteps. Return = -169.78171510002613
# Episode 35 finished after 87 timesteps. Return = -124.34711241504516
# Episode 36 finished after 73 timesteps. Return = -75.15056740376549
# Episode 37 finished after 75 timesteps. Return = -98.20110966287695
# Episode 38 finished after 82 timesteps. Return = -625.8027207123968
# Episode 39 finished after 74 timesteps. Return = -121.17926342592098
# Episode 40 finished after 96 timesteps. Return = -352.4122257787809
# Episode 41 finished after 92 timesteps. Return = -318.32583980459344
# Episode 42 finished after 108 timesteps. Return = -128.12560253556404
# Episode 43 finished after 98 timesteps. Return = -177.14582433038527
# Episode 44 finished after 77 timesteps. Return = -76.29059009323686
# Episode 45 finished after 74 timesteps. Return = -321.3181481222573
# Episode 46 finished after 96 timesteps. Return = -112.03041441766095
# Episode 47 finished after 105 timesteps. Return = -94.15706888754316
# Episode 48 finished after 85 timesteps. Return = -202.79156017906345
# Episode 49 finished after 66 timesteps. Return = -67.49653677241557
# Episode 50 finished after 114 timesteps. Return = -220.51345430586866
# 1.3842409914766693

# %%
n_iters = 1000
for i in range(n_iters):
    replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
    train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
# Out:
# Episode 51 finished after 89 timesteps. Return = -382.6634132320046
# Episode 52 finished after 66 timesteps. Return = -96.67326599693764
# Episode 53 finished after 83 timesteps. Return = -90.11398104032524
# Episode 54 finished after 101 timesteps. Return = -240.75159988453566
# Episode 55 finished after 95 timesteps. Return = -428.78147663886165
# Episode 56 finished after 70 timesteps. Return = -119.74727539795562
# Episode 57 finished after 62 timesteps. Return = -63.50740351740876
# Episode 58 finished after 90 timesteps. Return = -113.2061045242965
# Episode 59 finished after 60 timesteps. Return = -64.30061205143289
# Episode 60 finished after 144 timesteps. Return = -245.41588137987995
# Episode 61 finished after 75 timesteps. Return = -260.00580021195094
# Episode 62 finished after 90 timesteps. Return = -372.659845652631
# Episode 63 finished after 79 timesteps. Return = -96.01097819183681
# Episode 64 finished after 90 timesteps. Return = -238.6632391503006
# Episode 65 finished after 66 timesteps. Return = -226.7202661263325
# Episode 66 finished after 113 timesteps. Return = -173.60883173983746
# Episode 67 finished after 100 timesteps. Return = -322.8404592202462
# Episode 68 finished after 92 timesteps. Return = -100.13130711782654
# Episode 69 finished after 79 timesteps. Return = -216.21071411725038
# Episode 70 finished after 62 timesteps. Return = -60.268322170599376
# Episode 71 finished after 87 timesteps. Return = -215.2861567719179
# Episode 72 finished after 127 timesteps. Return = -118.56637391080793
# Episode 73 finished after 94 timesteps. Return = -430.0808826162649
# Episode 74 finished after 60 timesteps. Return = -91.09915026129453
# Episode 75 finished after 95 timesteps. Return = -301.8253063941454
# Episode 76 finished after 93 timesteps. Return = -439.0421594022694
# Episode 77 finished after 71 timesteps. Return = -125.92809290481104
# Episode 78 finished after 69 timesteps. Return = -88.01279654066838
# Episode 79 finished after 80 timesteps. Return = -113.47203100187339
# Episode 80 finished after 101 timesteps. Return = -148.46547638375557
# Episode 81 finished after 99 timesteps. Return = -297.1377373980852
# Episode 82 finished after 75 timesteps. Return = -126.50882577662038
# Episode 83 finished after 110 timesteps. Return = -395.91922555905245
# Episode 84 finished after 72 timesteps. Return = -170.52239963652244
# Episode 85 finished after 70 timesteps. Return = -99.995171705936
# Episode 86 finished after 121 timesteps. Return = -67.97209598885385
# Episode 87 finished after 115 timesteps. Return = -244.02490546525758
# Episode 88 finished after 86 timesteps. Return = -61.8821786673591
# Episode 89 finished after 103 timesteps. Return = -279.945372988118
# Episode 90 finished after 81 timesteps. Return = -292.0365163770273
# Episode 91 finished after 57 timesteps. Return = -212.14910120823163
# Episode 92 finished after 105 timesteps. Return = -134.0232339294302
# Episode 93 finished after 108 timesteps. Return = -117.89172572181033
# Episode 94 finished after 80 timesteps. Return = -156.09866032300874
# Episode 95 finished after 117 timesteps. Return = -146.01861283144999
# Episode 96 finished after 78 timesteps. Return = 12.365892011575596
# Episode 97 finished after 91 timesteps. Return = -80.87455983655208
# Episode 98 finished after 77 timesteps. Return = -112.63329009370334
# Episode 99 finished after 109 timesteps. Return = -73.53529763241383
# Episode 100 finished after 67 timesteps. Return = -101.79024206887112
# Episode 101 finished after 102 timesteps. Return = -262.0326571107777
# Episode 102 finished after 63 timesteps. Return = -103.06353256644049
# Episode 103 finished after 119 timesteps. Return = -1.2066574747636736
# Episode 104 finished after 97 timesteps. Return = -128.88179289160738
# Episode 105 finished after 80 timesteps. Return = -170.13925216611605
# Episode 106 finished after 91 timesteps. Return = -128.4837624039979
# Episode 107 finished after 76 timesteps. Return = -320.69318391675705
# Episode 108 finished after 82 timesteps. Return = -80.32909026668997
# Episode 109 finished after 98 timesteps. Return = -269.2208330759407
# Episode 110 finished after 95 timesteps. Return = -99.3242220784634
# Episode 111 finished after 100 timesteps. Return = -152.7514948563669
# Episode 112 finished after 77 timesteps. Return = -88.38375427469626
# Episode 113 finished after 100 timesteps. Return = -119.05017668509112
# Episode 114 finished after 76 timesteps. Return = -118.86578124805355
# Episode 115 finished after 77 timesteps. Return = -113.02582741693121
# Episode 116 finished after 128 timesteps. Return = -181.96604747036588
# Episode 117 finished after 101 timesteps. Return = -198.6263159158026
# Episode 118 finished after 100 timesteps. Return = -79.0450087409714
# Episode 119 finished after 75 timesteps. Return = -123.67971915265726
# Episode 120 finished after 96 timesteps. Return = -395.62626054106005
# Episode 121 finished after 67 timesteps. Return = -114.98676111867624
# Episode 122 finished after 59 timesteps. Return = -81.9062380464207
# Episode 123 finished after 125 timesteps. Return = -68.14559161235502
# Episode 124 finished after 105 timesteps. Return = -98.19590915542071
# Episode 125 finished after 102 timesteps. Return = -292.58730507891886
# Episode 126 finished after 84 timesteps. Return = -291.0265425223004
# Episode 127 finished after 81 timesteps. Return = -90.32317918242983
# Episode 128 finished after 84 timesteps. Return = -186.6327303773919
# Episode 129 finished after 71 timesteps. Return = -126.77685186846497
# Episode 130 finished after 63 timesteps. Return = -121.65969404234893
# Episode 131 finished after 118 timesteps. Return = -126.34545135865983
# Episode 132 finished after 118 timesteps. Return = -474.9647988060036
# Episode 133 finished after 81 timesteps. Return = -143.60448795218238
# Episode 134 finished after 75 timesteps. Return = -125.81025948849795
# Episode 135 finished after 95 timesteps. Return = -137.3670610801459
# Episode 136 finished after 76 timesteps. Return = -290.99128705322056
# Episode 137 finished after 69 timesteps. Return = -234.7616864076503
# Episode 138 finished after 96 timesteps. Return = -464.7335952850145
# Episode 139 finished after 89 timesteps. Return = -131.71622117361596
# Episode 140 finished after 79 timesteps. Return = -90.3271901009891
# Episode 141 finished after 113 timesteps. Return = -114.8750375639701
# Episode 142 finished after 92 timesteps. Return = -308.68240478616906
# Episode 143 finished after 67 timesteps. Return = -234.0397111524343
# Episode 144 finished after 89 timesteps. Return = -144.9792330740572
# Episode 145 finished after 96 timesteps. Return = -321.5364308615359
# Episode 249 finished after 86 timesteps. Return = 0.0259269865428422
# Episode 250 finished after 80 timesteps. Return = -265.29224451238275
# Episode 251 finished after 58 timesteps. Return = -150.88130733619954
# Episode 252 finished after 58 timesteps. Return = -97.45887850368103
# Episode 253 finished after 68 timesteps. Return = -155.60028024931862
# Episode 254 finished after 96 timesteps. Return = -155.4240215043152
# Episode 255 finished after 70 timesteps. Return = -291.9870037878359
# Episode 256 finished after 109 timesteps. Return = -13.810532642644063
# Episode 257 finished after 64 timesteps. Return = -72.94340659650737
# Episode 258 finished after 64 timesteps. Return = -94.57804309344033
# Episode 259 finished after 98 timesteps. Return = -145.62225396075456
# Episode 260 finished after 75 timesteps. Return = -166.53370827649167
# Episode 261 finished after 89 timesteps. Return = -91.03303307795505
# Episode 262 finished after 85 timesteps. Return = -100.07781875503565
# Episode 263 finished after 96 timesteps. Return = -171.88464767772086
# Episode 264 finished after 102 timesteps. Return = -108.52516584673572
# Episode 265 finished after 78 timesteps. Return = -114.25458065998248
# Episode 266 finished after 92 timesteps. Return = -261.6698492193611
# Episode 267 finished after 81 timesteps. Return = -102.33655003796201
# Episode 268 finished after 84 timesteps. Return = -138.52597130453705
# Episode 269 finished after 97 timesteps. Return = -136.3778574086092
# Episode 270 finished after 66 timesteps. Return = -65.05581504784902
# Episode 271 finished after 92 timesteps. Return = -76.38374470195066
# Episode 272 finished after 92 timesteps. Return = -124.15890358824763
# Episode 273 finished after 76 timesteps. Return = -182.69156628032903
# Episode 274 finished after 109 timesteps. Return = -332.8981800473428
# Episode 275 finished after 107 timesteps. Return = -138.4185792800144
# Episode 276 finished after 70 timesteps. Return = -115.14398779087112
# Episode 277 finished after 67 timesteps. Return = -87.10997822925454
# Episode 278 finished after 83 timesteps. Return = -170.6171233494798
# Episode 279 finished after 114 timesteps. Return = -163.86922108238042
# Episode 280 finished after 113 timesteps. Return = -135.6407929108665
# Episode 281 finished after 116 timesteps. Return = -154.2741000283404
# Episode 282 finished after 119 timesteps. Return = -115.59022431318739
# Episode 283 finished after 70 timesteps. Return = -84.00301598822745
# Episode 284 finished after 91 timesteps. Return = -130.2161246383855
# Episode 285 finished after 67 timesteps. Return = -87.49159046347813
# Episode 286 finished after 68 timesteps. Return = -55.31526008095634
# Episode 287 finished after 110 timesteps. Return = -162.36391331818982
# Episode 288 finished after 90 timesteps. Return = -122.93751155072607
# Episode 289 finished after 71 timesteps. Return = -48.38713405678293
# Episode 290 finished after 89 timesteps. Return = -234.2705958663608
# Episode 291 finished after 93 timesteps. Return = -288.36433018901107
# Episode 292 finished after 94 timesteps. Return = -89.03490930147856
# Episode 293 finished after 124 timesteps. Return = -122.74732759471013
# Episode 294 finished after 112 timesteps. Return = -303.41056760790195
# Episode 295 finished after 100 timesteps. Return = -125.1671671613999
# Episode 296 finished after 105 timesteps. Return = -483.78897310718884
# Episode 297 finished after 78 timesteps. Return = -179.34726002064474
# Episode 298 finished after 113 timesteps. Return = -132.6269211254701
# Episode 299 finished after 102 timesteps. Return = -122.54722847844738
# Episode 300 finished after 91 timesteps. Return = -113.98932139236821
# Episode 353 finished after 76 timesteps. Return = -87.7910901880725
# Episode 354 finished after 115 timesteps. Return = -214.82876606828216
# Episode 355 finished after 80 timesteps. Return = -136.89915431744353
# Episode 356 finished after 105 timesteps. Return = -107.16849110832983
# Episode 357 finished after 82 timesteps. Return = -82.47448834730423
# Episode 358 finished after 75 timesteps. Return = -101.13649315008281
# Episode 359 finished after 88 timesteps. Return = -122.08810970429613
# Episode 360 finished after 108 timesteps. Return = -206.17115525027066
# Episode 361 finished after 77 timesteps. Return = -102.84238099242386
# Episode 362 finished after 69 timesteps. Return = -65.70207890371935
# Episode 363 finished after 96 timesteps. Return = 64.91066740487776
# Episode 364 finished after 106 timesteps. Return = -133.84119276457443
# Episode 365 finished after 100 timesteps. Return = -110.09936058935818
# Episode 366 finished after 118 timesteps. Return = -140.9918861313319
# Episode 367 finished after 121 timesteps. Return = -94.4844295251487
# Episode 368 finished after 74 timesteps. Return = -88.00788875157059
# Episode 369 finished after 62 timesteps. Return = -55.072773309347625
# Episode 370 finished after 67 timesteps. Return = -108.14446009460268
# Episode 371 finished after 70 timesteps. Return = -103.17809692849417
# Episode 372 finished after 69 timesteps. Return = -151.6356406766608
# Episode 373 finished after 109 timesteps. Return = -140.06582192745262
# Episode 374 finished after 65 timesteps. Return = -90.72338566458511
# Episode 375 finished after 96 timesteps. Return = -318.30346175817783
# Episode 376 finished after 82 timesteps. Return = -96.99605414669898
# Episode 377 finished after 77 timesteps. Return = -105.23136232390226
# Episode 378 finished after 123 timesteps. Return = -191.456129827839
# Episode 379 finished after 110 timesteps. Return = -109.21883732448488
# Episode 380 finished after 79 timesteps. Return = -106.65224107965884
# Episode 381 finished after 97 timesteps. Return = -74.04125866652004
# Episode 382 finished after 134 timesteps. Return = 17.925425569135186
# Episode 383 finished after 59 timesteps. Return = -71.45839211141711
# Episode 384 finished after 65 timesteps. Return = -73.2475588282045
# Episode 385 finished after 85 timesteps. Return = -129.6380041427706
# Episode 386 finished after 106 timesteps. Return = -173.69538036400246
# Episode 387 finished after 130 timesteps. Return = -93.07207355122029
# Episode 388 finished after 129 timesteps. Return = -144.4301744603807
# Episode 389 finished after 65 timesteps. Return = -106.62772340915693
# Episode 390 finished after 75 timesteps. Return = -86.83033091521426
# Episode 391 finished after 83 timesteps. Return = -85.22588835677524
# Episode 392 finished after 126 timesteps. Return = -163.13517221496272
# Episode 393 finished after 86 timesteps. Return = -168.60888625961417
# Episode 394 finished after 105 timesteps. Return = -141.14980667995803
# Episode 395 finished after 59 timesteps. Return = -87.89948456583515
# Episode 396 finished after 83 timesteps. Return = -91.22531706212919
# Episode 397 finished after 73 timesteps. Return = -41.885655462933244
# Episode 398 finished after 80 timesteps. Return = -115.22041291114463
# Episode 399 finished after 62 timesteps. Return = -68.02317469256266
# Episode 400 finished after 64 timesteps. Return = -91.81718819343514
# Episode 401 finished after 122 timesteps. Return = -125.49317652884818
# Episode 402 finished after 85 timesteps. Return = -52.62053893303058
# Episode 403 finished after 62 timesteps. Return = -55.56686446436071
# Episode 456 finished after 75 timesteps. Return = -104.08144458868689
# Episode 457 finished after 64 timesteps. Return = -89.99161202097201
# Episode 458 finished after 148 timesteps. Return = -185.2635281067416
# Episode 459 finished after 114 timesteps. Return = -142.78168806734885
# Episode 460 finished after 63 timesteps. Return = -97.67881041102434
# Episode 461 finished after 106 timesteps. Return = -240.09262199154568
# Episode 462 finished after 131 timesteps. Return = -310.8858743975493
# Episode 463 finished after 84 timesteps. Return = -114.96907850581661
# Episode 464 finished after 82 timesteps. Return = -182.72472545501986
# Episode 465 finished after 82 timesteps. Return = -100.34954760447397
# Episode 466 finished after 73 timesteps. Return = -80.68637394330666
# Episode 467 finished after 67 timesteps. Return = -75.10591032146003
# Episode 468 finished after 75 timesteps. Return = -152.29335320319794
# Episode 469 finished after 99 timesteps. Return = -225.55559786453244
# Episode 470 finished after 103 timesteps. Return = -159.75710280143574
# Episode 471 finished after 109 timesteps. Return = -134.612782862115
# Episode 472 finished after 65 timesteps. Return = -87.16826868588828
# Episode 473 finished after 72 timesteps. Return = 32.810966967312766
# Episode 474 finished after 90 timesteps. Return = -133.2548033011506
# Episode 475 finished after 129 timesteps. Return = -109.3364201940187
# Episode 476 finished after 65 timesteps. Return = -84.5473477527337
# Episode 477 finished after 61 timesteps. Return = -8.507848501263666
# Episode 478 finished after 104 timesteps. Return = -85.2927283410151
# Episode 479 finished after 88 timesteps. Return = -104.77230559286103
# Episode 480 finished after 124 timesteps. Return = -125.1528709371228
# Episode 481 finished after 94 timesteps. Return = -116.03191257152915
# Episode 482 finished after 95 timesteps. Return = -141.63236505272909
# Episode 483 finished after 95 timesteps. Return = -127.68338324549711
# Episode 484 finished after 64 timesteps. Return = -128.5075423916293
# Episode 485 finished after 144 timesteps. Return = -15.858251824288857
# Episode 486 finished after 70 timesteps. Return = -94.53384107285855
# Episode 487 finished after 93 timesteps. Return = -67.80761957910171
# Episode 488 finished after 101 timesteps. Return = -140.17771282520954
# Episode 489 finished after 67 timesteps. Return = -73.89548815049068
# Episode 490 finished after 130 timesteps. Return = -139.52513023935296
# Episode 491 finished after 67 timesteps. Return = -97.70316364096286
# Episode 492 finished after 121 timesteps. Return = -126.91061228936869
# Episode 493 finished after 123 timesteps. Return = -19.659416488769068
# Episode 494 finished after 107 timesteps. Return = -131.21340575193693
# Episode 495 finished after 102 timesteps. Return = -76.69843414406776
# Episode 496 finished after 122 timesteps. Return = -213.7362793259315
# Episode 497 finished after 102 timesteps. Return = -103.87989569675399
# Episode 498 finished after 98 timesteps. Return = -278.2521867013472
# Episode 499 finished after 76 timesteps. Return = -79.70009317833453
# Episode 500 finished after 114 timesteps. Return = -64.49889338348461
# Episode 501 finished after 106 timesteps. Return = -115.68615239431341
# Episode 502 finished after 80 timesteps. Return = -14.293678337533805
# Episode 503 finished after 78 timesteps. Return = -128.88243156059514
# Episode 504 finished after 103 timesteps. Return = -116.82424196697258
# Episode 505 finished after 84 timesteps. Return = -115.86074100886546
# Episode 506 finished after 112 timesteps. Return = -122.8755634350762
# Episode 507 finished after 135 timesteps. Return = -244.33244134766122
# Episode 508 finished after 65 timesteps. Return = -66.68560927247013
# Episode 509 finished after 77 timesteps. Return = -104.65432505065915
# Episode 510 finished after 100 timesteps. Return = -102.7966150176698
# Episode 511 finished after 103 timesteps. Return = -95.968467421445
# Episode 512 finished after 124 timesteps. Return = -107.6715260147301
# Episode 513 finished after 94 timesteps. Return = -160.6638092195342
# Episode 514 finished after 112 timesteps. Return = -64.11931331654182
# Episode 515 finished after 117 timesteps. Return = -8.282183666846436
# Episode 516 finished after 63 timesteps. Return = -132.81679950445562
# Episode 517 finished after 127 timesteps. Return = -163.44763862207054
# Episode 518 finished after 123 timesteps. Return = -276.9217116216114
# Episode 519 finished after 63 timesteps. Return = -80.99699633022026
# Episode 520 finished after 113 timesteps. Return = -169.85867737077115
# Episode 521 finished after 90 timesteps. Return = -101.44685477613676
# Episode 522 finished after 77 timesteps. Return = -100.35459610137907
# Episode 523 finished after 64 timesteps. Return = -110.6036623658624
# Episode 524 finished after 62 timesteps. Return = -94.70764894972321
# Episode 525 finished after 113 timesteps. Return = -137.9126722101658
# Episode 526 finished after 108 timesteps. Return = -171.39640440996487
# Episode 527 finished after 134 timesteps. Return = -10.202622617660325
# Episode 528 finished after 109 timesteps. Return = -62.95202549306547
# Episode 529 finished after 70 timesteps. Return = -92.10981110341132
# Episode 530 finished after 95 timesteps. Return = -200.6142229999056
# Episode 531 finished after 88 timesteps. Return = -172.82860469039377
# Episode 532 finished after 103 timesteps. Return = -152.11067626795335
# Episode 533 finished after 69 timesteps. Return = -76.24558910404483
# Episode 534 finished after 101 timesteps. Return = 10.60104922971729
# Episode 535 finished after 90 timesteps. Return = -146.4172374854249
# Episode 536 finished after 81 timesteps. Return = -141.82492359367524
# Episode 537 finished after 68 timesteps. Return = -85.90298487671994
# Episode 538 finished after 127 timesteps. Return = -102.10353714031793
# Episode 539 finished after 61 timesteps. Return = -118.91272534123863
# Episode 540 finished after 71 timesteps. Return = -121.16697081074602
# Episode 541 finished after 138 timesteps. Return = -140.38418268276484
# Episode 542 finished after 134 timesteps. Return = -341.0148507021874
# Episode 543 finished after 86 timesteps. Return = -132.48753123742733
# Episode 544 finished after 107 timesteps. Return = -134.97071038142502
# Episode 545 finished after 56 timesteps. Return = -93.0747473823195
# Episode 546 finished after 61 timesteps. Return = -62.25213987671873
# Episode 547 finished after 67 timesteps. Return = -62.296819692297284
# Episode 548 finished after 123 timesteps. Return = -135.9170623854852
# Episode 549 finished after 119 timesteps. Return = -122.44812014021304
# Episode 550 finished after 69 timesteps. Return = -69.06637213520537
# Episode 551 finished after 89 timesteps. Return = -412.5929132128175
# Episode 552 finished after 137 timesteps. Return = -82.51609049502667
# Episode 553 finished after 129 timesteps. Return = -107.1857321956515
# Episode 554 finished after 86 timesteps. Return = -133.80056634039562
# Episode 555 finished after 84 timesteps. Return = -127.61228900654396
# Episode 556 finished after 87 timesteps. Return = -136.09265500075787
# Episode 557 finished after 80 timesteps. Return = -111.33055001168445
# Episode 558 finished after 93 timesteps. Return = -50.2554767674564
# Episode 559 finished after 96 timesteps. Return = -112.4892142211775
# Episode 560 finished after 80 timesteps. Return = -83.04861842774154
# Episode 561 finished after 94 timesteps. Return = -152.69284331694467
# Episode 562 finished after 107 timesteps. Return = -276.94495272532754
# Episode 563 finished after 120 timesteps. Return = -197.1335199962931
# Episode 564 finished after 77 timesteps. Return = -127.6808029990037
# Episode 565 finished after 67 timesteps. Return = -148.3953532114557
# Episode 566 finished after 76 timesteps. Return = -48.38941454125083
# Episode 567 finished after 88 timesteps. Return = -101.96355677475425
# Episode 568 finished after 92 timesteps. Return = -94.5537294549811
# Episode 569 finished after 103 timesteps. Return = -122.3542921445431
# Episode 570 finished after 63 timesteps. Return = -67.48177368068193
# Episode 571 finished after 94 timesteps. Return = -291.9180564225654
# Episode 572 finished after 66 timesteps. Return = -71.27248225039374
# Episode 573 finished after 68 timesteps. Return = -85.93547624448851
# Episode 574 finished after 105 timesteps. Return = -119.3219931351516
# Episode 575 finished after 74 timesteps. Return = -98.83586539581987
# Episode 576 finished after 72 timesteps. Return = -93.33136119607151
# Episode 577 finished after 89 timesteps. Return = -63.735348663338456
# Episode 578 finished after 95 timesteps. Return = -121.45900519563384
# Episode 579 finished after 83 timesteps. Return = -100.88966508558251
# Episode 580 finished after 59 timesteps. Return = -67.56028721624898
# Episode 581 finished after 85 timesteps. Return = -135.76239907209725
# Episode 582 finished after 139 timesteps. Return = -318.6177586859479
# Episode 583 finished after 124 timesteps. Return = -106.88927665805546
# Episode 584 finished after 90 timesteps. Return = -132.95063947660532
# Episode 585 finished after 107 timesteps. Return = -295.85062259824565
# Episode 586 finished after 72 timesteps. Return = -90.79382892718552
# Episode 587 finished after 87 timesteps. Return = -116.4428729750966
# Episode 588 finished after 106 timesteps. Return = -186.12548862201194
# Episode 589 finished after 104 timesteps. Return = -97.66705534274693
# Episode 590 finished after 112 timesteps. Return = -100.96356865543596
# Episode 591 finished after 102 timesteps. Return = -191.29362924100818
# Episode 592 finished after 73 timesteps. Return = 41.59666458490187
# Episode 593 finished after 135 timesteps. Return = -90.99694986645957
# Episode 594 finished after 64 timesteps. Return = -219.11674122137964
# Episode 595 finished after 84 timesteps. Return = -117.51057443790776
# Episode 596 finished after 78 timesteps. Return = -66.15881239746591
# Episode 597 finished after 71 timesteps. Return = -94.52014962546511
# Episode 598 finished after 120 timesteps. Return = -164.91208527584013
# Episode 599 finished after 82 timesteps. Return = -310.5339258698212
# Episode 600 finished after 102 timesteps. Return = -21.89858621130628
# Episode 601 finished after 91 timesteps. Return = -245.16420391648842
# Episode 602 finished after 113 timesteps. Return = -162.3351597826179
# Episode 603 finished after 99 timesteps. Return = -86.3518693358821
# Episode 604 finished after 86 timesteps. Return = -133.43998008670386
# Episode 605 finished after 107 timesteps. Return = -118.76180616047431
# Episode 606 finished after 80 timesteps. Return = -76.37842856036909
# Episode 607 finished after 98 timesteps. Return = -156.5638917925127
# Episode 608 finished after 68 timesteps. Return = -116.22221503065336
# Episode 609 finished after 109 timesteps. Return = -127.10591521069564
# Episode 610 finished after 87 timesteps. Return = -53.636039271588345
# Episode 611 finished after 94 timesteps. Return = -107.93878035555687
# Episode 612 finished after 94 timesteps. Return = -130.85978711487633
# Episode 613 finished after 87 timesteps. Return = -48.10451174482036
# Episode 614 finished after 106 timesteps. Return = -68.92153193112397
# Episode 615 finished after 106 timesteps. Return = -142.3978951692753
# Episode 616 finished after 95 timesteps. Return = -141.45681145568426
# Episode 617 finished after 93 timesteps. Return = -123.16602843330078
# Episode 618 finished after 69 timesteps. Return = -54.97940902087993
# Episode 619 finished after 88 timesteps. Return = -106.1393546511948
# Episode 620 finished after 88 timesteps. Return = -135.35061976095022
# Episode 621 finished after 84 timesteps. Return = -135.64626159848865
# Episode 622 finished after 95 timesteps. Return = -120.57262387210598
# Episode 623 finished after 66 timesteps. Return = -69.68782943196094
# Episode 624 finished after 65 timesteps. Return = -86.61326873304797
# Episode 625 finished after 75 timesteps. Return = -73.26239270576257
# Episode 626 finished after 66 timesteps. Return = -63.33191167595827
# Episode 627 finished after 62 timesteps. Return = -104.38725556269685
# Episode 628 finished after 69 timesteps. Return = -73.9663322522003
# Episode 629 finished after 112 timesteps. Return = -127.0888272645383
# Episode 630 finished after 70 timesteps. Return = -162.32754247229758
# Episode 631 finished after 87 timesteps. Return = -138.11821566542363
# Episode 632 finished after 102 timesteps. Return = -104.78307627431943
# Episode 633 finished after 78 timesteps. Return = -96.33762586471688
# Episode 634 finished after 126 timesteps. Return = -135.0396556256747
# Episode 635 finished after 91 timesteps. Return = -160.0879423794552
# Episode 636 finished after 71 timesteps. Return = -110.76483897372766
# Episode 637 finished after 103 timesteps. Return = -104.12977475705289
# Episode 638 finished after 133 timesteps. Return = -256.14219351192526
# Episode 639 finished after 63 timesteps. Return = -63.923391158800506
# Episode 640 finished after 114 timesteps. Return = -56.92640227733537
# Episode 641 finished after 89 timesteps. Return = -111.20137083754851
# Episode 642 finished after 130 timesteps. Return = -164.2087305553414
# Episode 643 finished after 104 timesteps. Return = -159.9185252618625
# Episode 644 finished after 64 timesteps. Return = -100.66989640210502
# Episode 645 finished after 95 timesteps. Return = -123.29688179742519
# Episode 646 finished after 110 timesteps. Return = -128.81493535064425
# Episode 647 finished after 79 timesteps. Return = -116.43648342247515
# Episode 648 finished after 78 timesteps. Return = -112.81491076637094
# Episode 649 finished after 101 timesteps. Return = -96.31567588831392
# Episode 650 finished after 96 timesteps. Return = -164.17325866264335
# Episode 651 finished after 81 timesteps. Return = -111.87351531157204
# Episode 652 finished after 121 timesteps. Return = -104.08456736556414
# Episode 653 finished after 144 timesteps. Return = -219.32148596399287
# Episode 654 finished after 82 timesteps. Return = -95.49011464900212
# Episode 655 finished after 94 timesteps. Return = -123.08118670820714
# Episode 656 finished after 90 timesteps. Return = -130.5924676656058
# Episode 657 finished after 82 timesteps. Return = -112.46489329631183
# Episode 658 finished after 112 timesteps. Return = -122.06208652736747
# Episode 659 finished after 90 timesteps. Return = -132.23583748964245
# Episode 660 finished after 129 timesteps. Return = -78.38527289576243
# Episode 661 finished after 122 timesteps. Return = -133.75853779768534
# Episode 662 finished after 102 timesteps. Return = -161.68176894661224
# Episode 663 finished after 138 timesteps. Return = -109.47651307435751
# Episode 664 finished after 81 timesteps. Return = -106.57510215020747
# Episode 665 finished after 68 timesteps. Return = -105.47842509737082
# Episode 666 finished after 100 timesteps. Return = -99.18570147927662
# Episode 667 finished after 77 timesteps. Return = -66.48612336019178
# Episode 668 finished after 132 timesteps. Return = -148.0942640805314
# Episode 669 finished after 79 timesteps. Return = -102.81318275258
# Episode 670 finished after 68 timesteps. Return = -117.38769305952425
# Episode 671 finished after 129 timesteps. Return = -92.58557903496845
# Episode 672 finished after 93 timesteps. Return = -179.18902538138082
# Episode 673 finished after 101 timesteps. Return = -114.48169973364857
# Episode 674 finished after 82 timesteps. Return = -83.90175105621802
# Episode 675 finished after 85 timesteps. Return = -106.32410557267045
# Episode 676 finished after 71 timesteps. Return = -99.22383675220006
# Episode 677 finished after 110 timesteps. Return = -107.42701753295131
# Episode 678 finished after 96 timesteps. Return = -142.5960143804085
# Episode 679 finished after 103 timesteps. Return = -163.11624760452383
# Episode 680 finished after 79 timesteps. Return = -124.15103749874794
# Episode 681 finished after 82 timesteps. Return = -87.33867723660418
# Episode 682 finished after 83 timesteps. Return = -145.64418101982955
# Episode 683 finished after 80 timesteps. Return = -94.82358293897323
# Episode 684 finished after 90 timesteps. Return = -80.6979017271839
# Episode 685 finished after 94 timesteps. Return = -325.64961056991336
# Episode 686 finished after 83 timesteps. Return = -127.01249076828896
# Episode 687 finished after 103 timesteps. Return = -78.42923390598065
# Episode 688 finished after 89 timesteps. Return = -203.39562600646155
# Episode 689 finished after 102 timesteps. Return = -97.45929449457638
# Episode 690 finished after 67 timesteps. Return = -134.601222733097
# Episode 691 finished after 77 timesteps. Return = -134.04605456112506
# Episode 692 finished after 89 timesteps. Return = -98.32837553207114
# Episode 693 finished after 115 timesteps. Return = -105.24126720783735
# Episode 694 finished after 94 timesteps. Return = -22.450622507719913
# Episode 695 finished after 104 timesteps. Return = -233.75837383272673
# Episode 696 finished after 76 timesteps. Return = -114.68138196913608
# Episode 697 finished after 116 timesteps. Return = -151.5219281920189
# Episode 698 finished after 131 timesteps. Return = -138.54588105980145
# Episode 699 finished after 91 timesteps. Return = -151.8649639699922
# Episode 700 finished after 89 timesteps. Return = -152.14432623938922
# Episode 701 finished after 100 timesteps. Return = -118.59575801947517
# Episode 702 finished after 82 timesteps. Return = -133.4304285501929
# Episode 703 finished after 88 timesteps. Return = -76.8557425142925
# Episode 704 finished after 105 timesteps. Return = -251.58691675980253
# Episode 705 finished after 78 timesteps. Return = -117.02881184597005
# Episode 706 finished after 89 timesteps. Return = -155.607323208747
# Episode 707 finished after 63 timesteps. Return = -110.26176826092062
# Episode 708 finished after 100 timesteps. Return = -117.09540666559393
# Episode 709 finished after 107 timesteps. Return = -153.41332422183552
# Episode 710 finished after 92 timesteps. Return = -95.72393933557913
# Episode 711 finished after 71 timesteps. Return = -130.74237111641722
# Episode 712 finished after 129 timesteps. Return = -119.80012131756726
# Episode 713 finished after 88 timesteps. Return = -134.62195614181297
# Episode 11032 finished after 208 timesteps. Return = 40.66100826269022
# Episode 11033 finished after 101 timesteps. Return = -70.51491953110667
# Episode 11034 finished after 255 timesteps. Return = -123.17979662113795
# Episode 11035 finished after 186 timesteps. Return = -109.47014867245566
# Episode 11036 finished after 236 timesteps. Return = -106.05772953420269
# Episode 11037 finished after 267 timesteps. Return = -210.6335325155767
# Episode 11038 finished after 128 timesteps. Return = -154.14119391097978
# Episode 11039 finished after 451 timesteps. Return = -216.2599847745956
# Episode 11040 finished after 79 timesteps. Return = -112.44607036993597
# Episode 11041 finished after 336 timesteps. Return = -143.4395686784531
# Episode 11042 finished after 141 timesteps. Return = -58.390128641759816
# Episode 11043 finished after 230 timesteps. Return = -109.12425142175644
# Episode 11044 finished after 135 timesteps. Return = -137.34335011785888
# Episode 11045 finished after 523 timesteps. Return = -195.25386251009132
# Episode 11046 finished after 241 timesteps. Return = -146.21624575784654
# Episode 11047 finished after 290 timesteps. Return = -40.90206669391263
# Episode 11048 finished after 147 timesteps. Return = -129.50464735614545
# Episode 11049 finished after 1000 timesteps. Return = -4.95208345235039
# Episode 11050 finished after 192 timesteps. Return = -65.93786241554314
# Episode 11051 finished after 86 timesteps. Return = -139.14905491131753
# Episode 11052 finished after 282 timesteps. Return = -50.99740346132022
# Episode 11053 finished after 64 timesteps. Return = -65.82717925503687
# Episode 11054 finished after 124 timesteps. Return = -70.91127690790671
# Episode 11055 finished after 244 timesteps. Return = -158.16036206828016
# Episode 11056 finished after 285 timesteps. Return = -253.37103869894207
# Episode 11057 finished after 86 timesteps. Return = -79.91924394369258
# Episode 11058 finished after 572 timesteps. Return = -332.41402880133046
# Episode 11059 finished after 277 timesteps. Return = -49.85803333856235
# Episode 11060 finished after 123 timesteps. Return = -12.718705501252856
# Episode 11061 finished after 183 timesteps. Return = -42.98119648208622
# Episode 11062 finished after 165 timesteps. Return = -118.54705960590005
# Episode 11063 finished after 246 timesteps. Return = -73.76343081858968
# Episode 11064 finished after 146 timesteps. Return = -210.14523994602973
# Episode 11065 finished after 232 timesteps. Return = 7.224521088960927
# Episode 11066 finished after 326 timesteps. Return = -306.9953258911508
# Episode 11067 finished after 359 timesteps. Return = -134.37964938683143
# Episode 11068 finished after 77 timesteps. Return = -80.88679462350508
# Episode 11069 finished after 115 timesteps. Return = -58.86003631142811
# Episode 11070 finished after 308 timesteps. Return = -138.10914229454693
# Episode 11071 finished after 96 timesteps. Return = -62.11229184974515
# Episode 11072 finished after 130 timesteps. Return = -56.58562063974194
# Episode 11073 finished after 215 timesteps. Return = -199.44575035003174
# Episode 11074 finished after 155 timesteps. Return = -71.69043870918348
# Episode 11075 finished after 621 timesteps. Return = -271.3211203388466
# Episode 11076 finished after 620 timesteps. Return = -187.8473303248491
# Episode 11077 finished after 339 timesteps. Return = -262.1346810372802
# Episode 11078 finished after 92 timesteps. Return = -9.417724126709828
# Episode 11079 finished after 106 timesteps. Return = -215.19083732170384
# Episode 11080 finished after 216 timesteps. Return = -138.0907612385591
# Episode 11081 finished after 151 timesteps. Return = -1.9515855874326604
# Episode 11132 finished after 297 timesteps. Return = -263.9126604156462
# Episode 11133 finished after 91 timesteps. Return = -50.890587783384206
# Episode 11134 finished after 113 timesteps. Return = -170.00421703117166
# Episode 11135 finished after 65 timesteps. Return = -156.07772395889884
# Episode 11136 finished after 213 timesteps. Return = -27.240110498040252
# Episode 11137 finished after 116 timesteps. Return = -123.65096909311099
# Episode 11138 finished after 73 timesteps. Return = -93.66343324461492
# Episode 11139 finished after 134 timesteps. Return = -122.61736013886721
# Episode 11140 finished after 365 timesteps. Return = -333.2588784864535
# Episode 11141 finished after 214 timesteps. Return = -88.37805799608178
# Episode 11142 finished after 161 timesteps. Return = -80.5904897878022
# Episode 11143 finished after 518 timesteps. Return = -198.57011321120154
# Episode 11144 finished after 551 timesteps. Return = -84.61646319492932
# Episode 11145 finished after 375 timesteps. Return = -258.7738327152502
# Episode 11146 finished after 294 timesteps. Return = -145.12945109035422
# Episode 11147 finished after 268 timesteps. Return = -231.18098775171848
# Episode 11148 finished after 426 timesteps. Return = -261.94205398457075
# Episode 11149 finished after 135 timesteps. Return = -71.74612582831077
# Episode 11150 finished after 177 timesteps. Return = -214.67790921357488
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-79b06f4f96af> in <module>
#       2 for i in range(n_iters):
#       3     replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, log_to_tensorboard)
# ----> 4     train_net(agent, replay_buffer, n_updates_per_iter, batch_size, log_to_tensorboard)
#
# <ipython-input-24-d4848dabccac> in train_net(policy_net, replay_buffer, n_updates, batch_size, log_to_tensorboard)
#      24         pred = policy_net(batch_observations, batch_commands)
#      25         cost = F.cross_entropy(pred, batch_label)
# ---> 26         if log_to_tensorboard: writer.add_scalar('Cost/NN update', cost.item() , i_updates)    # write loss to a graph
#      27         all_costs.append(cost.item())
#      28         cost.backward()
#
# ~/.local/lib/python3.6/site-packages/torch/utils/tensorboard/writer.py in add_scalar(self, tag, scalar_value, global_step, walltime)
#     327             scalar_value = workspace.FetchBlob(scalar_value)
#     328         self._get_file_writer().add_summary(
# --> 329             scalar(tag, scalar_value), global_step, walltime)
#     330
#     331     def add_scalars(self, main_tag, tag_scalar_dict, global_step=None, walltime=None):
#
# ~/.local/lib/python3.6/site-packages/torch/utils/tensorboard/summary.py in scalar(name, scalar, collections)
#     194     """
#     195     name = _clean_tag(name)
# --> 196     scalar = make_np(scalar)
#     197     assert(scalar.squeeze().ndim == 0), 'scalar should be 0D'
#     198     scalar = float(scalar)
#
# ~/.local/lib/python3.6/site-packages/torch/utils/tensorboard/_convert_np.py in make_np(x)
#      24         return _prepare_caffe2(x)
#      25     if np.isscalar(x):
# ---> 26         return np.array([x])
#      27     if isinstance(x, torch.Tensor):
#      28         return _prepare_pytorch(x)
#
# KeyboardInterrupt:

# %%
#torch.save(agent.state_dict(), 'checkpoints/lunar_lander_64x64_checkpoint_0.pt')
#agent.load_state_dict(torch.load('checkpoints/lunar_lander_32x32_checkpoint_0.pt'))

# %%
visualise_agent(greedy_policy, command=[150, 400], n=5)
# Out:
, -56.69750752912218, -56.63003009452369, -56.57717933190456, -56.55285874920199, -56.43287337593468, -56.41958989562853, -56.384186053146955, -56.36697871250924, -56.3104312449084, -56.300176671674585, -56.274253516639696, -56.267808683905336, -56.22267747011205, -56.193807710305904, -56.1703367565696, -56.11191158942033, -56.077939891293326, -55.93140847365147, -55.90299822253307, -55.893738990395725, -55.65922528324657, -55.65032050439427, -55.59501222567876, -55.44229710372763, -55.258734749168575, -55.159865405437294, -55.129330655107516, -55.099454857726855, -55.037976757584175, -54.99937278320171, -54.76582389440709, -54.758649810458905, -54.758065159609174, -54.7571931055855, -54.71482624890963, -54.696450546945584, -54.67046404902763, -54.63477969721541, -54.59008466179011, -54.54888621231758, -54.54832564043903, -54.44702569218868, -54.438274698966644, -54.341786067370805, -54.26960359117863, -54.05958403117087, -53.776987406599034, -53.75027348734851, -53.50896586864481, -53.507277556873355, -53.49058085861022, -53.47632575657567, -53.42857 ...

# %% [markdown]
# # Previous Code

# %%
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64):
    all_costs = []
    for i in range(n_updates):
        batch_input = np.zeros((batch_size, np.prod(env.observation_space.shape)+2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_horizon = np.random.randint(1, len(replay_buffer[sample_episode]['observation'])+1)
            sample_mem_idx = np.random.randint(0, len(replay_buffer[sample_episode]['observation'])+1-sample_horizon)
            sample_mem = replay_buffer[sample_episode]['observation'][sample_mem_idx]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_mem_idx]
            batch_input[b] = network_input
            batch_label[b] = label
        batch_input = torch.tensor(batch_input).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_input)
        cost = F.cross_entropy(pred, batch_label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train_net(policy_net, episode_mem, n_samples = 5): #stochastic gradient descent
    all_costs = []
    for i in range(n_samples):
        sample_horizon = np.random.randint(1, len(episode_mem['observation'])+1)
        sample_mem_idx = np.random.randint(0, len(episode_mem['observation'])+1-sample_horizon)
        sample_mem = episode_mem['observation'][sample_mem_idx]
        sample_desired_reward = sum(episode_mem['reward'][sample_mem_idx:sample_mem_idx+sample_horizon])
        network_input = torch.tensor(np.append(sample_mem, [sample_desired_reward, sample_horizon])).double()
        label = torch.tensor([episode_mem['action'][sample_mem_idx]]).double()
        
        pred = policy_net(network_input)
        cost = F.binary_cross_entropy(pred, label)
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
    return np.mean(all_costs)

# %%
def train(policy_net, n_episodes=100):
    global i_episode
    global epsilon
    try:
        for _ in range(n_episodes):
            observation = env.reset()
            episode_mem = {'observation':[],
                            'action':[],
                            'reward':[],
                            'done':[]}
            done=False
            while not done:
                network_input = torch.tensor(np.append(observation, [desired_reward, command_horizon])).double()
                action_prob = policy_net(network_input)
                action = np.random.binomial(1, action_prob.item())
                #action = int(action_prob.item()>0.5)
                if np.random.rand()<epsilon: action = np.random.randint(0, 2)
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                episode_mem['done'].append(done)
                
                observation=new_observation
                epsilon*=0.999
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            mean_cost = train_net(policy_net, episode_mem)
            
            i_episode+=1
            print("Episode {} finished after {} timesteps. Epsilon={} Mean Cost={}".format(i_episode, len(episode_mem['observation']), epsilon, mean_cost))
        env.close()
    except KeyboardInterrupt:
        env.close()

# %% [markdown]
# ## Previous version

# %%
import gym
import time
import torch
import numpy as np
from copy import deepcopy
import torch.nn.functional as F

def random_policy(obs):
    return np.random.randint(env.action_space.n)

#Visualise agent function
def visualise_agent(policy, command, command_scale, n=5):
    try:
        for trial_i in range(n):
            current_command = deepcopy(command)
            observation = env.reset()
            done=False
            t=0
            episode_return=0
            while not done:
                env.render()
                network_input = torch.tensor(np.append(observation, np.array(current_command)*command_scale)).double()
                policy_action = policy(network_input)
                observation, reward, done, info = env.step(policy_action)
                episode_return+=reward
                #time.sleep(0.1)
                current_command[0]-= reward
                current_command[1] = max(1, current_command[1]-1)
                
                t+=1
            env.render()
            time.sleep(1.5)
            print("Episode {} finished after {} timesteps. Return = {}".format(trial_i, t, episode_return))
        env.close()
    except KeyboardInterrupt:
        env.close()
        
#Behaviour function - Neural Network
class FCNN_AGENT(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(np.prod(env.observation_space.shape)+2, 10),
            torch.nn.ReLU(),
            torch.nn.Linear(10, 10),
            torch.nn.ReLU(),
            torch.nn.Linear(10, env.action_space.n)
        )
    
    def forward(self, x):
        x = self.fc(x)
        return x
    
    def create_optimizer(self, lr):
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)

#Full the replay buffer with more experience
def collect_experience(policy, replay_buffer, replay_size, last_few, n_episodes=100, command_scale=0.01, log_to_tensorboard=True):
    global i_episode
    init_replay_buffer = deepcopy(replay_buffer)
    try:
        for _ in range(n_episodes):
            command = sample_command(init_replay_buffer, last_few)
            if log_to_tensorboard: writer.add_scalar('Command desired reward/Episode', command[0], i_episode)    # write loss to a graph
            if log_to_tensorboard: writer.add_scalar('Command horizon/Episode', command[1], i_episode)    # write loss to a graph
            observation = env.reset()
            episode_mem = {'observation':[],
                            'action':[],
                            'reward':[]}
            done=False
            while not done:
                network_input = torch.tensor(np.append(observation, np.array(command)*command_scale)).double()
                action = policy(network_input)
                new_observation, reward, done, info = env.step(action)
                
                episode_mem['observation'].append(observation)
                episode_mem['action'].append(action)
                episode_mem['reward'].append(reward)
                
                observation=new_observation
                #command[0]-= reward
                command[0] = max(1, command[0]-reward)
                command[1] = max(1, command[1]-1)
            episode_mem['return']=sum(episode_mem['reward'])
            episode_mem['episode_len']=len(episode_mem['observation'])
            replay_buffer.append(episode_mem)
            i_episode+=1
            if log_to_tensorboard: writer.add_scalar('Return/Episode', sum(episode_mem['reward']), i_episode)    # write loss to a graph
            print("Episode {} finished after {} timesteps. Return = {}".format(i_episode, len(episode_mem['observation']), sum(episode_mem['reward'])))
        env.close()
    except KeyboardInterrupt:
        env.close()
    replay_buffer = sorted(replay_buffer, key=lambda x:x['return'])[-replay_size:]
    return replay_buffer

#Sample exploratory command
def sample_command(replay_buffer, last_few):
    if len(replay_buffer)==0:
        return [1, 1]
    else:
        command_samples = replay_buffer[-last_few:]
        lengths = [mem['episode_len'] for mem in command_samples]
        returns = [mem['return'] for mem in command_samples]
        mean_return, std_return = np.mean(returns), np.std(returns)
        command_horizon = np.mean(lengths)
        desired_reward = np.random.uniform(mean_return, mean_return+std_return)
        return [desired_reward, command_horizon]

#Improve behviour function by training on replay buffer
def train_net(policy_net, replay_buffer, n_updates=100, batch_size=64, command_scale=0.01):
    global i_updates
    all_costs = []
    for i in range(n_updates):
        batch_input = np.zeros((batch_size, np.prod(env.observation_space.shape)+2))
        batch_label = np.zeros((batch_size))
        for b in range(batch_size):
            sample_episode = np.random.randint(0, len(replay_buffer))
            sample_t1 = np.random.randint(0, len(replay_buffer[sample_episode]['observation']))
            sample_t2 = len(replay_buffer[sample_episode]['observation'])
            sample_horizon = (sample_t2-sample_t1) * command_scale
            sample_mem = replay_buffer[sample_episode]['observation'][sample_t1]
            sample_desired_reward = sum(replay_buffer[sample_episode]['reward'][sample_t1:sample_t2])*command_scale
            network_input = np.append(sample_mem, [sample_desired_reward, sample_horizon])
            label = replay_buffer[sample_episode]['action'][sample_t1]
            batch_input[b] = network_input
            batch_label[b] = label
        batch_input = torch.tensor(batch_input).double()
        batch_label = torch.tensor(batch_label).long()
        pred = policy_net(batch_input)
        cost = F.cross_entropy(pred, batch_label)
        if log_to_tensorboard: writer.add_scalar('Cost/NN update', cost.item() , i_updates)    # write loss to a graph
        all_costs.append(cost.item())
        cost.backward()
        policy_net.optimizer.step()
        policy_net.optimizer.zero_grad()
        i_updates+=1
    return np.mean(all_costs)

#Return a greedy policy from a given network
def create_greedy_policy(policy_network):
    def policy(obs):
        action_logits = policy_network(obs)
        action = np.argmax(action_logits.detach().numpy())
        return action
    return policy

#Return a stochastic policy from a given network
def create_stochastic_policy(policy_network):
    def policy(obs):
        action_logits = policy_network(obs)
        action_probs = F.softmax(action_logits, dim=-1)
        action = torch.distributions.Categorical(action_probs).sample().item()
        return action
    return policy

# %%
#Define hyperparameters, initialize behaviour function
env = gym.make('LunarLander-v2')
i_episode=0
i_updates=0
replay_buffer = []
log_to_tensorboard = True 

replay_size = 600
last_few = 75
batch_size = 32
n_warm_up_episodes = 50
n_episodes_per_iter = 50
n_updates_per_iter = 300
command_scale = 0.01
lr = 0.001

agent = FCNN_AGENT().double()
agent.create_optimizer(lr)

stochastic_policy = create_stochastic_policy(agent)
greedy_policy = create_greedy_policy(agent)

# SET UP TRAINING VISUALISATION
if log_to_tensorboard: from torch.utils.tensorboard import SummaryWriter
if log_to_tensorboard: writer = SummaryWriter() # we will use this to show our models performance on a graph using tensorboard

#Collect warm up episodes
replay_buffer = collect_experience(random_policy, replay_buffer, replay_size, last_few, n_warm_up_episodes, command_scale, log_to_tensorboard)
train_net(agent, replay_buffer, n_updates_per_iter, batch_size, command_scale)
# Out:
# Episode 1 finished after 78 timesteps. Return = -128.4480682875527
# Episode 2 finished after 89 timesteps. Return = -387.88715583374216
# Episode 3 finished after 77 timesteps. Return = -95.10879230530807
# Episode 4 finished after 72 timesteps. Return = -102.74438279096503
# Episode 5 finished after 116 timesteps. Return = -253.90123618001869
# Episode 6 finished after 107 timesteps. Return = -178.8621093404991
# Episode 7 finished after 110 timesteps. Return = -424.2903105389424
# Episode 8 finished after 69 timesteps. Return = -90.45928541886127
# Episode 9 finished after 85 timesteps. Return = -90.34062619706825
# Episode 10 finished after 110 timesteps. Return = -257.37052024828347
# Episode 11 finished after 95 timesteps. Return = -171.70578091801366
# Episode 12 finished after 65 timesteps. Return = -264.4237434177501
# Episode 13 finished after 128 timesteps. Return = -146.38984817020642
# Episode 14 finished after 73 timesteps. Return = -95.87199679628412
# Episode 15 finished after 67 timesteps. Return = -107.21044058424631
# Episode 16 finished after 94 timesteps. Return = -200.91625948341937
# Episode 17 finished after 112 timesteps. Return = -119.30663969919934
# Episode 18 finished after 86 timesteps. Return = -336.207871546178
# Episode 19 finished after 121 timesteps. Return = -214.85642305937913
# Episode 20 finished after 85 timesteps. Return = -195.03431822478234
# Episode 21 finished after 111 timesteps. Return = -128.09993942613576
# Episode 22 finished after 74 timesteps. Return = -117.02910606671895
# Episode 23 finished after 72 timesteps. Return = -77.54214978770256
# Episode 24 finished after 127 timesteps. Return = -164.85619180891194
# Episode 25 finished after 115 timesteps. Return = -140.17448816737584
# Episode 26 finished after 123 timesteps. Return = -200.8600255151409
# Episode 27 finished after 65 timesteps. Return = -98.40648696022782
# Episode 28 finished after 59 timesteps. Return = -130.692502984335
# Episode 29 finished after 112 timesteps. Return = -185.86008467646008
# Episode 30 finished after 115 timesteps. Return = -211.65519358633543
# Episode 31 finished after 132 timesteps. Return = -227.31640135762217
# Episode 32 finished after 122 timesteps. Return = -399.7285380496536
# Episode 33 finished after 62 timesteps. Return = -101.10561805846261
# Episode 34 finished after 65 timesteps. Return = -130.0754063218909
# Episode 35 finished after 125 timesteps. Return = -109.85845444734045
# Episode 36 finished after 109 timesteps. Return = -198.29567520084834
# Episode 37 finished after 61 timesteps. Return = -173.04002512216263
# Episode 38 finished after 111 timesteps. Return = -295.02504846125834
# Episode 39 finished after 94 timesteps. Return = -346.92554597655965
# Episode 40 finished after 73 timesteps. Return = -114.67086421361888
# Episode 41 finished after 95 timesteps. Return = -94.5913393484921
# Episode 42 finished after 67 timesteps. Return = -60.430696478085096
# Episode 43 finished after 94 timesteps. Return = -274.8983030203936
# Episode 44 finished after 128 timesteps. Return = -431.10342805651726
# Episode 45 finished after 79 timesteps. Return = -320.71882099136576
# Episode 46 finished after 74 timesteps. Return = -93.42708124041397
# Episode 47 finished after 138 timesteps. Return = -108.49401307605251
# Episode 48 finished after 122 timesteps. Return = -103.69784882008918
# Episode 49 finished after 103 timesteps. Return = -101.33993440109997
# Episode 50 finished after 85 timesteps. Return = -135.06021464732044
# 1.3918637607680855

# %%
#Collect experience and train behaviour function for given number of iterations
n_iters = 1000
for i in range(n_iters):
    replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, command_scale, log_to_tensorboard)
    train_net(agent, replay_buffer, n_updates_per_iter, batch_size, command_scale)
# Out:
# Episode 51 finished after 137 timesteps. Return = -446.3506995863737
# Episode 52 finished after 77 timesteps. Return = -140.5196864731071
# Episode 53 finished after 70 timesteps. Return = -85.56728471718694
# Episode 54 finished after 71 timesteps. Return = -94.78256978743447
# Episode 55 finished after 114 timesteps. Return = -65.1801625049948
# Episode 56 finished after 71 timesteps. Return = -315.67881711784116
# Episode 57 finished after 120 timesteps. Return = -67.65283374333278
# Episode 58 finished after 92 timesteps. Return = -413.1242067143709
# Episode 59 finished after 96 timesteps. Return = -134.2708548742756
# Episode 60 finished after 96 timesteps. Return = -115.75873117970687
# Episode 61 finished after 88 timesteps. Return = -127.17007197006436
# Episode 62 finished after 112 timesteps. Return = -301.4526746821167
# Episode 63 finished after 113 timesteps. Return = -211.53988109680003
# Episode 64 finished after 68 timesteps. Return = -119.3757190542396
# Episode 65 finished after 93 timesteps. Return = -313.233892145411
# Episode 66 finished after 89 timesteps. Return = -124.08632563113309
# Episode 67 finished after 110 timesteps. Return = -159.27272264333865
# Episode 68 finished after 108 timesteps. Return = -238.8947199867632
# Episode 69 finished after 96 timesteps. Return = -510.87555472110483
# Episode 70 finished after 65 timesteps. Return = -110.0273382854946
# Episode 71 finished after 78 timesteps. Return = -314.46580388911514
# Episode 72 finished after 77 timesteps. Return = -212.55849705537065
# Episode 73 finished after 124 timesteps. Return = -351.3707797517703
# Episode 74 finished after 114 timesteps. Return = -87.93805655384736
# Episode 75 finished after 116 timesteps. Return = -202.1069901916193
# Episode 76 finished after 92 timesteps. Return = -132.3078469431852
# Episode 77 finished after 82 timesteps. Return = -126.66440357221477
# Episode 78 finished after 77 timesteps. Return = -336.0552391249927
# Episode 79 finished after 87 timesteps. Return = -91.0993654575681
# Episode 80 finished after 103 timesteps. Return = -321.3442888416018
# Episode 81 finished after 62 timesteps. Return = -68.05512513438582
# Episode 82 finished after 65 timesteps. Return = -51.43512627560327
# Episode 83 finished after 99 timesteps. Return = -120.83861072934334
# Episode 84 finished after 71 timesteps. Return = -298.67341703417856
# Episode 85 finished after 69 timesteps. Return = -104.97507583697936
# Episode 86 finished after 94 timesteps. Return = -96.26925752171445
# Episode 87 finished after 83 timesteps. Return = -114.07226332385358
# Episode 88 finished after 102 timesteps. Return = -355.9438950656075
# Episode 89 finished after 86 timesteps. Return = -121.07345295856456
# Episode 90 finished after 114 timesteps. Return = -449.54397047754424
# Episode 143 finished after 100 timesteps. Return = -79.03305215446792
# Episode 144 finished after 129 timesteps. Return = -280.2386269193097
# Episode 145 finished after 88 timesteps. Return = -147.72345864987764
# Episode 146 finished after 104 timesteps. Return = -368.2385653468922
# Episode 147 finished after 82 timesteps. Return = -86.27182798146295
# Episode 148 finished after 109 timesteps. Return = -127.19560527602776
# Episode 149 finished after 86 timesteps. Return = -258.91654500846334
# Episode 150 finished after 116 timesteps. Return = -493.0923265004124
# Episode 151 finished after 58 timesteps. Return = -116.89388536586011
# Episode 152 finished after 78 timesteps. Return = -186.42375023279044
# Episode 153 finished after 81 timesteps. Return = -87.98890572080727
# Episode 154 finished after 114 timesteps. Return = -163.93528323429655
# Episode 155 finished after 122 timesteps. Return = -112.55210012148423
# Episode 156 finished after 68 timesteps. Return = -60.468424715070185
# Episode 157 finished after 81 timesteps. Return = -110.17066799584505
# Episode 158 finished after 68 timesteps. Return = -155.1461103083039
# Episode 159 finished after 105 timesteps. Return = -220.09063314375476
# Episode 160 finished after 82 timesteps. Return = -114.71278348497603
# Episode 161 finished after 64 timesteps. Return = -41.705799212091826
# Episode 162 finished after 88 timesteps. Return = -61.846539742594516
# Episode 163 finished after 125 timesteps. Return = -216.77418131650964
# Episode 164 finished after 82 timesteps. Return = -128.66972291480238
# Episode 165 finished after 133 timesteps. Return = -262.29597782345013
# Episode 166 finished after 62 timesteps. Return = -104.98238291353826
# Episode 167 finished after 67 timesteps. Return = -107.37077795748652
# Episode 168 finished after 112 timesteps. Return = -162.23599502227876
# Episode 169 finished after 76 timesteps. Return = -190.9125823288796
# Episode 170 finished after 74 timesteps. Return = -145.1580381477114
# Episode 171 finished after 81 timesteps. Return = -185.81141519042382
# Episode 172 finished after 112 timesteps. Return = -262.19610597998167
# Episode 173 finished after 110 timesteps. Return = -196.60018250107777
# Episode 174 finished after 69 timesteps. Return = -104.16899601506384
# Episode 175 finished after 84 timesteps. Return = -96.07286939569624
# Episode 176 finished after 131 timesteps. Return = -139.4199800131397
# Episode 177 finished after 74 timesteps. Return = -91.46291264096092
# Episode 178 finished after 115 timesteps. Return = -90.51635088079755
# Episode 179 finished after 98 timesteps. Return = -292.12224853522514
# Episode 180 finished after 79 timesteps. Return = -143.27721094359757
# Episode 181 finished after 63 timesteps. Return = -124.11629519864661
# Episode 182 finished after 84 timesteps. Return = -133.22669053051544
# Episode 183 finished after 95 timesteps. Return = -171.2783776465923
# Episode 184 finished after 96 timesteps. Return = -93.28849817463086
# Episode 185 finished after 92 timesteps. Return = -114.1557484370562
# Episode 186 finished after 62 timesteps. Return = -102.55848158584956
# Episode 187 finished after 121 timesteps. Return = -151.4838767167584
# Episode 188 finished after 125 timesteps. Return = -196.0212459848779
# Episode 189 finished after 97 timesteps. Return = -145.1694107000726
# Episode 190 finished after 57 timesteps. Return = -74.97018147168033
# Episode 191 finished after 72 timesteps. Return = -85.33314900425353
# Episode 192 finished after 124 timesteps. Return = -268.6912120836371
# Episode 193 finished after 74 timesteps. Return = -60.80301763074711
# Episode 194 finished after 82 timesteps. Return = -250.00246109587076
# Episode 246 finished after 107 timesteps. Return = -399.5721263063631
# Episode 247 finished after 106 timesteps. Return = -222.76022056457623
# Episode 248 finished after 111 timesteps. Return = -203.17631850872797
# Episode 249 finished after 107 timesteps. Return = -574.219686004252
# Episode 250 finished after 121 timesteps. Return = -365.07610522873233
# Episode 251 finished after 70 timesteps. Return = -145.44832529899236
# Episode 252 finished after 60 timesteps. Return = -127.58388698733971
# Episode 253 finished after 131 timesteps. Return = -229.64508327946163
# Episode 254 finished after 95 timesteps. Return = -213.29101567303388
# Episode 255 finished after 83 timesteps. Return = -256.3597200192436
# Episode 256 finished after 69 timesteps. Return = -73.82715605783997
# Episode 257 finished after 102 timesteps. Return = -111.31934962476673
# Episode 258 finished after 112 timesteps. Return = -119.0919450916749
# Episode 259 finished after 109 timesteps. Return = -300.6019248271442
# Episode 260 finished after 60 timesteps. Return = -93.63758250077385
# Episode 261 finished after 104 timesteps. Return = -177.81091167505127
# Episode 262 finished after 95 timesteps. Return = -136.57448149015687
# Episode 263 finished after 93 timesteps. Return = -347.41420077095063
# Episode 264 finished after 107 timesteps. Return = -346.55614735460057
# Episode 265 finished after 78 timesteps. Return = -3.129067149858841
# Episode 266 finished after 99 timesteps. Return = -94.28666726933349
# Episode 267 finished after 86 timesteps. Return = -159.48105229826564
# Episode 268 finished after 88 timesteps. Return = -92.28559203341409
# Episode 269 finished after 87 timesteps. Return = -101.97479828459652
# Episode 270 finished after 71 timesteps. Return = -56.70205043036395
# Episode 271 finished after 76 timesteps. Return = 2.0550964313626565
# Episode 272 finished after 85 timesteps. Return = -62.21005571322094
# Episode 273 finished after 94 timesteps. Return = -213.45721281005916
# Episode 274 finished after 100 timesteps. Return = -98.42173801118773
# Episode 275 finished after 100 timesteps. Return = -100.80302423491202
# Episode 276 finished after 75 timesteps. Return = 41.33996240752754
# Episode 277 finished after 110 timesteps. Return = -77.40103542084584
# Episode 278 finished after 92 timesteps. Return = -474.44651383838846
# Episode 279 finished after 70 timesteps. Return = -82.62827793907717
# Episode 280 finished after 105 timesteps. Return = -98.63575534000813
# Episode 281 finished after 71 timesteps. Return = -177.636339386438
# Episode 282 finished after 129 timesteps. Return = -240.4889013830674
# Episode 283 finished after 101 timesteps. Return = -390.9030618563859
# Episode 284 finished after 70 timesteps. Return = -92.01814284917272
# Episode 285 finished after 104 timesteps. Return = -130.1857582916578
# Episode 286 finished after 64 timesteps. Return = -105.38989879656623
# Episode 287 finished after 78 timesteps. Return = -31.679493477401564
# Episode 288 finished after 95 timesteps. Return = -211.49299122292308
# Episode 289 finished after 67 timesteps. Return = -72.59829179067326
# Episode 290 finished after 68 timesteps. Return = -191.02033115537344
# Episode 291 finished after 116 timesteps. Return = -41.5166897808713
# Episode 292 finished after 110 timesteps. Return = -301.30195817797824
# Episode 293 finished after 98 timesteps. Return = -126.0177373450193
# Episode 294 finished after 85 timesteps. Return = -41.33706913169587
# Episode 295 finished after 110 timesteps. Return = -104.89408300251816
# Episode 296 finished after 122 timesteps. Return = -122.06720661409226
# Episode 297 finished after 67 timesteps. Return = -93.27479221165001
# Episode 298 finished after 92 timesteps. Return = -111.51403266195848
# Episode 299 finished after 96 timesteps. Return = -278.2307061737931
# Episode 300 finished after 59 timesteps. Return = -68.63417569381657
# Episode 301 finished after 113 timesteps. Return = -174.5064029495523
# Episode 302 finished after 108 timesteps. Return = -138.43405525667737
# Episode 303 finished after 87 timesteps. Return = -364.50838279260915
# Episode 304 finished after 122 timesteps. Return = -90.0417980348177
# Episode 305 finished after 63 timesteps. Return = -74.82944791207059
# Episode 306 finished after 78 timesteps. Return = 12.349499040470633
# Episode 307 finished after 89 timesteps. Return = -164.86833598957227
# Episode 308 finished after 66 timesteps. Return = -102.99398329758637
# Episode 309 finished after 98 timesteps. Return = -118.5751696659217
# Episode 310 finished after 96 timesteps. Return = -355.7378909208139
# Episode 311 finished after 90 timesteps. Return = -285.4564896708546
# Episode 312 finished after 104 timesteps. Return = -168.49976352458845
# Episode 313 finished after 100 timesteps. Return = -165.46007523055252
# Episode 314 finished after 99 timesteps. Return = -125.14736171644915
# Episode 315 finished after 72 timesteps. Return = -116.46354231314434
# Episode 316 finished after 85 timesteps. Return = -256.27310584452283
# Episode 317 finished after 118 timesteps. Return = -553.0003005932774
# Episode 318 finished after 74 timesteps. Return = -146.42394297455905
# Episode 319 finished after 80 timesteps. Return = -181.06945237836862
# Episode 320 finished after 68 timesteps. Return = -130.86239192620695
# Episode 321 finished after 87 timesteps. Return = -307.6555623432933
# Episode 322 finished after 95 timesteps. Return = -323.9471032587458
# Episode 323 finished after 91 timesteps. Return = -366.29064648782514
# Episode 324 finished after 96 timesteps. Return = -63.452914072143656
# Episode 325 finished after 113 timesteps. Return = -135.81950439872136
# Episode 326 finished after 125 timesteps. Return = -210.24929849030994
# Episode 327 finished after 77 timesteps. Return = -265.85344613693894
# Episode 328 finished after 128 timesteps. Return = -178.8587901518901
# Episode 329 finished after 100 timesteps. Return = -117.3623657048285
# Episode 330 finished after 75 timesteps. Return = -249.16687032938805
# Episode 331 finished after 74 timesteps. Return = -78.33477925746521
# Episode 332 finished after 79 timesteps. Return = -77.90773825629046
# Episode 333 finished after 139 timesteps. Return = -173.2439302481702
# Episode 334 finished after 124 timesteps. Return = -226.64552538870967
# Episode 335 finished after 71 timesteps. Return = -99.48161961418161
# Episode 336 finished after 86 timesteps. Return = -129.9891262941177
# Episode 337 finished after 105 timesteps. Return = -91.02970156727979
# Episode 338 finished after 86 timesteps. Return = -190.96362428296794
# Episode 339 finished after 66 timesteps. Return = -79.9860861893391
# Episode 340 finished after 108 timesteps. Return = -188.58235612900768
# Episode 341 finished after 120 timesteps. Return = -141.41163373636505
# Episode 342 finished after 82 timesteps. Return = -230.427145100625
# Episode 343 finished after 100 timesteps. Return = -235.0028092378147
# Episode 344 finished after 78 timesteps. Return = -106.79618644929629
# Episode 345 finished after 89 timesteps. Return = -114.57168124430801
# Episode 346 finished after 111 timesteps. Return = -409.25545591117026
# Episode 347 finished after 77 timesteps. Return = -210.8171036131875
# Episode 348 finished after 83 timesteps. Return = -114.51477930146545
# Episode 349 finished after 121 timesteps. Return = -202.65990210530518
# Episode 350 finished after 118 timesteps. Return = -150.7491537343497
# Episode 351 finished after 102 timesteps. Return = -417.61214921510367
# Episode 352 finished after 117 timesteps. Return = -150.0873748074124
# Episode 353 finished after 86 timesteps. Return = -233.84631995708864
# Episode 354 finished after 82 timesteps. Return = -147.41059023383957
# Episode 355 finished after 129 timesteps. Return = -118.7334816424426
# Episode 356 finished after 112 timesteps. Return = -103.5126000487102
# Episode 357 finished after 122 timesteps. Return = -164.53740157290832
# Episode 358 finished after 96 timesteps. Return = -86.99472080122534
# Episode 359 finished after 79 timesteps. Return = -232.71650830703828
# Episode 360 finished after 114 timesteps. Return = -108.99891331358505
# Episode 361 finished after 112 timesteps. Return = -136.2954861183897
# Episode 362 finished after 82 timesteps. Return = 48.77731515152567
# Episode 363 finished after 98 timesteps. Return = -192.62965461723996
# Episode 364 finished after 67 timesteps. Return = -90.63338926327633
# Episode 365 finished after 68 timesteps. Return = -98.58202957812844
# Episode 366 finished after 107 timesteps. Return = -189.0084071048105
# Episode 367 finished after 79 timesteps. Return = -68.30760318873129
# Episode 368 finished after 91 timesteps. Return = -425.49201842089093
# Episode 369 finished after 149 timesteps. Return = -353.3773090543027
# Episode 370 finished after 103 timesteps. Return = -239.2587942195144
# Episode 371 finished after 59 timesteps. Return = -77.36935093527973
# Episode 372 finished after 81 timesteps. Return = -110.47522773098132
# Episode 373 finished after 88 timesteps. Return = -195.2468103759618
# Episode 374 finished after 96 timesteps. Return = -176.42694636250582
# Episode 375 finished after 114 timesteps. Return = -109.84162246802694
# Episode 376 finished after 62 timesteps. Return = -59.918603855319766
# Episode 377 finished after 125 timesteps. Return = -107.45627730027775
# Episode 378 finished after 62 timesteps. Return = -88.64445051221163
# Episode 379 finished after 98 timesteps. Return = -351.4911231261352
# Episode 380 finished after 117 timesteps. Return = -353.2475873032072
# Episode 381 finished after 69 timesteps. Return = -51.31498912357776
# Episode 382 finished after 76 timesteps. Return = -208.5280441063212
# Episode 383 finished after 110 timesteps. Return = -284.04448521681627
# Episode 384 finished after 83 timesteps. Return = -147.72810350326705
# Episode 385 finished after 106 timesteps. Return = -379.2803822465759
# Episode 386 finished after 63 timesteps. Return = -126.75494278406464
# Episode 387 finished after 53 timesteps. Return = -79.5054479623283
# Episode 388 finished after 101 timesteps. Return = -178.79365594272684
# Episode 389 finished after 82 timesteps. Return = -116.99507386130696
# Episode 390 finished after 79 timesteps. Return = -115.49358437518943
# Episode 391 finished after 105 timesteps. Return = -104.0662600322616
# Episode 392 finished after 93 timesteps. Return = -125.76321456028573
# Episode 393 finished after 65 timesteps. Return = -87.44593771780714
# Episode 394 finished after 83 timesteps. Return = -104.72194454570176
# Episode 395 finished after 81 timesteps. Return = -97.52650357639656
# Episode 396 finished after 123 timesteps. Return = -292.1470059689921
# Episode 397 finished after 80 timesteps. Return = -153.38460607342023
# Episode 398 finished after 59 timesteps. Return = -91.66985843865751
# Episode 399 finished after 62 timesteps. Return = -65.76825004088589
# Episode 400 finished after 102 timesteps. Return = -145.84141097253718
# Episode 401 finished after 68 timesteps. Return = -123.7588304918531
# Episode 402 finished after 78 timesteps. Return = -91.79737898790941
# Episode 403 finished after 79 timesteps. Return = -109.41087355196629
# Episode 404 finished after 87 timesteps. Return = -209.81017864626727
# Episode 405 finished after 129 timesteps. Return = -346.623076061892
# Episode 406 finished after 125 timesteps. Return = -308.04239696178274
# Episode 407 finished after 98 timesteps. Return = -149.08914304583794
# Episode 408 finished after 91 timesteps. Return = -123.8753435033675
# Episode 409 finished after 77 timesteps. Return = -115.98615147465324
# Episode 410 finished after 110 timesteps. Return = -301.32129355406596
# Episode 411 finished after 73 timesteps. Return = -71.25766460242389
# Episode 412 finished after 107 timesteps. Return = -190.50868161911495
# Episode 413 finished after 89 timesteps. Return = -91.3439183969028
# Episode 414 finished after 65 timesteps. Return = -95.84527173026802
# Episode 415 finished after 106 timesteps. Return = -191.69772948261556
# Episode 416 finished after 64 timesteps. Return = -120.5916127759939
# Episode 417 finished after 69 timesteps. Return = -99.47554883556316
# Episode 418 finished after 69 timesteps. Return = -138.91836274515907
# Episode 419 finished after 64 timesteps. Return = -117.55656377805636
# Episode 420 finished after 112 timesteps. Return = -100.63873253717723
# Episode 421 finished after 73 timesteps. Return = -171.74789328967256
# Episode 422 finished after 88 timesteps. Return = -80.93309778150977
# Episode 423 finished after 95 timesteps. Return = -227.75923425296233
# Episode 424 finished after 72 timesteps. Return = -122.62037874926172
# Episode 425 finished after 61 timesteps. Return = -145.92015232939673
# Episode 426 finished after 157 timesteps. Return = -421.2072808183099
# Episode 427 finished after 71 timesteps. Return = -90.34999191368102
# Episode 428 finished after 105 timesteps. Return = -261.05115656555273
# Episode 429 finished after 72 timesteps. Return = -107.59719894761798
# Episode 430 finished after 68 timesteps. Return = -80.14666698030209
# Episode 431 finished after 134 timesteps. Return = -120.42038785047625
# Episode 432 finished after 92 timesteps. Return = -115.92917984666668
# Episode 433 finished after 78 timesteps. Return = -388.71436225513645
# Episode 434 finished after 65 timesteps. Return = -35.5211844842205
# Episode 435 finished after 119 timesteps. Return = -96.36101597112336
# Episode 436 finished after 82 timesteps. Return = -179.35618200646093
# Episode 437 finished after 115 timesteps. Return = -335.69371732614303
# Episode 438 finished after 111 timesteps. Return = -135.16753761303852
# Episode 439 finished after 83 timesteps. Return = -116.27606603019169
# Episode 440 finished after 87 timesteps. Return = -109.14957582456795
# Episode 441 finished after 117 timesteps. Return = -249.410799598072
# Episode 442 finished after 127 timesteps. Return = -399.6531406406771
# Episode 443 finished after 91 timesteps. Return = -146.72086135488848
# Episode 444 finished after 89 timesteps. Return = -146.27755918755113
# Episode 445 finished after 111 timesteps. Return = -178.65944813835995
# Episode 446 finished after 91 timesteps. Return = -70.79815483525901
# Episode 447 finished after 67 timesteps. Return = -92.69409073819502
# Episode 448 finished after 120 timesteps. Return = -117.01886365426613
# Episode 449 finished after 63 timesteps. Return = -37.86590856324817
# Episode 450 finished after 128 timesteps. Return = 5.830545474035006
# Episode 451 finished after 89 timesteps. Return = -181.19069234088454
# Episode 452 finished after 59 timesteps. Return = -137.37882162052364
# Episode 453 finished after 66 timesteps. Return = -155.8980600645338
# Episode 454 finished after 98 timesteps. Return = -125.4484110923985
# Episode 455 finished after 122 timesteps. Return = -192.32600660859734
# Episode 456 finished after 109 timesteps. Return = -112.6538415599872
# Episode 457 finished after 59 timesteps. Return = -90.12069492679461
# Episode 458 finished after 84 timesteps. Return = -189.740865993069
# Episode 459 finished after 104 timesteps. Return = -196.97575174394234
# Episode 460 finished after 76 timesteps. Return = -145.66970310563718
# Episode 461 finished after 89 timesteps. Return = -384.3812539426306
# Episode 462 finished after 60 timesteps. Return = -73.07889444311266
# Episode 463 finished after 84 timesteps. Return = -224.13297895465467
# Episode 464 finished after 113 timesteps. Return = -92.03502850270473
# Episode 465 finished after 69 timesteps. Return = -219.50766667629364
# Episode 466 finished after 60 timesteps. Return = -139.33126011113936
# Episode 467 finished after 114 timesteps. Return = -244.8400639533525
# Episode 468 finished after 103 timesteps. Return = -136.12505507667274
# Episode 469 finished after 118 timesteps. Return = -228.57980316461752
# Episode 470 finished after 68 timesteps. Return = -104.77695725123334
# Episode 471 finished after 77 timesteps. Return = -93.25551148473441
# Episode 472 finished after 65 timesteps. Return = -96.04714459904861
# Episode 473 finished after 87 timesteps. Return = 57.75615253021337
# Episode 474 finished after 61 timesteps. Return = -111.20534054121138
# Episode 475 finished after 76 timesteps. Return = -110.0732802929073
# Episode 476 finished after 77 timesteps. Return = -84.06263750942583
# Episode 477 finished after 66 timesteps. Return = -102.67917922152895
# Episode 478 finished after 132 timesteps. Return = -308.8632732258974
# Episode 479 finished after 103 timesteps. Return = -324.959473797967
# Episode 480 finished after 75 timesteps. Return = -127.55034633942871
# Episode 481 finished after 71 timesteps. Return = -47.56874162106999
# Episode 482 finished after 79 timesteps. Return = -86.11935499376375
# Episode 483 finished after 66 timesteps. Return = -96.30161148543878
# Episode 484 finished after 122 timesteps. Return = -119.40522059931533
# Episode 485 finished after 76 timesteps. Return = -112.27378579806616
# Episode 486 finished after 65 timesteps. Return = -141.63582668611105
# Episode 487 finished after 107 timesteps. Return = -123.1115469726698
# Episode 488 finished after 83 timesteps. Return = -149.01996836211495
# Episode 489 finished after 112 timesteps. Return = -182.63643671985324
# Episode 490 finished after 103 timesteps. Return = -126.01944551736743
# Episode 491 finished after 132 timesteps. Return = -302.57150523075427
# Episode 492 finished after 106 timesteps. Return = -125.00769944786322
# Episode 493 finished after 97 timesteps. Return = -374.5718424974381
# Episode 494 finished after 77 timesteps. Return = -149.1648943917114
# Episode 495 finished after 58 timesteps. Return = -146.85929202770546
# Episode 496 finished after 118 timesteps. Return = -156.14975097262013
# Episode 497 finished after 75 timesteps. Return = -112.6759659983397
# Episode 498 finished after 62 timesteps. Return = -161.05684785651448
# Episode 499 finished after 81 timesteps. Return = -144.1729955867283
# Episode 500 finished after 94 timesteps. Return = -142.54738186489158
# Episode 501 finished after 71 timesteps. Return = -139.95731778514178
# Episode 502 finished after 120 timesteps. Return = -173.70099557088724
# Episode 503 finished after 69 timesteps. Return = -115.36648694679533
# Episode 504 finished after 77 timesteps. Return = -167.3452690034481
# Episode 505 finished after 107 timesteps. Return = -337.8017579849337
# Episode 506 finished after 69 timesteps. Return = -72.88274751819226
# Episode 507 finished after 85 timesteps. Return = -330.96943730212774
# Episode 508 finished after 86 timesteps. Return = -128.88900887465684
# Episode 509 finished after 66 timesteps. Return = -206.83766120352905
# Episode 510 finished after 101 timesteps. Return = -151.55868005968512
# Episode 511 finished after 100 timesteps. Return = -360.6239636199608
# Episode 512 finished after 82 timesteps. Return = -105.85948030779346
# Episode 513 finished after 101 timesteps. Return = -127.38616303194244
# Episode 514 finished after 59 timesteps. Return = -60.864253334763156
# Episode 515 finished after 108 timesteps. Return = -98.65049559090521
# Episode 516 finished after 74 timesteps. Return = -126.2765537080345
# Episode 517 finished after 95 timesteps. Return = -114.70999949634061
# Episode 518 finished after 66 timesteps. Return = -48.74924211937956
# Episode 519 finished after 113 timesteps. Return = -107.53066141304157
# Episode 520 finished after 112 timesteps. Return = -146.86650593700438
# Episode 521 finished after 67 timesteps. Return = -45.90716073751751
# Episode 522 finished after 103 timesteps. Return = -356.61571961629573
# Episode 523 finished after 115 timesteps. Return = -190.5384126497216
# Episode 524 finished after 137 timesteps. Return = -111.16473733153717
# Episode 525 finished after 89 timesteps. Return = -193.30190737797273
# Episode 526 finished after 82 timesteps. Return = -19.361240254176266
# Episode 527 finished after 109 timesteps. Return = -218.48569048255825
# Episode 528 finished after 68 timesteps. Return = -211.45700733290238
# Episode 529 finished after 94 timesteps. Return = -93.89896799083404
# Episode 530 finished after 100 timesteps. Return = -375.3528574558353
# Episode 531 finished after 61 timesteps. Return = -246.37178230884416
# Episode 532 finished after 69 timesteps. Return = -184.35148436013293
# Episode 533 finished after 88 timesteps. Return = -162.70473431205681
# Episode 534 finished after 71 timesteps. Return = -110.32276938173662
# Episode 535 finished after 89 timesteps. Return = -191.55526324541177
# Episode 536 finished after 88 timesteps. Return = -137.48470208927156
# Episode 537 finished after 104 timesteps. Return = -347.35429462174017
# Episode 538 finished after 83 timesteps. Return = -128.69897913425598
# Episode 539 finished after 101 timesteps. Return = -321.2059091532176
# Episode 540 finished after 112 timesteps. Return = -138.7140622015092
# Episode 541 finished after 100 timesteps. Return = -186.51693224204348
# Episode 542 finished after 60 timesteps. Return = -83.74087998108158
# Episode 543 finished after 91 timesteps. Return = -271.50812190237775
# Episode 544 finished after 92 timesteps. Return = -82.63524718879307
# Episode 545 finished after 97 timesteps. Return = -5.395291893454626
# Episode 546 finished after 69 timesteps. Return = -108.67078297642975
# Episode 547 finished after 58 timesteps. Return = -131.67133329699703
# Episode 548 finished after 63 timesteps. Return = -62.97790249734259
# Episode 549 finished after 121 timesteps. Return = -429.43206725851746
# Episode 550 finished after 84 timesteps. Return = -156.68408325704866
# Episode 551 finished after 72 timesteps. Return = -25.431229576426304
# Episode 552 finished after 62 timesteps. Return = -180.313407872941
# Episode 553 finished after 67 timesteps. Return = -81.5058754632716
# Episode 554 finished after 84 timesteps. Return = -76.39650744773179
# Episode 555 finished after 85 timesteps. Return = -122.31367432203125
# Episode 556 finished after 107 timesteps. Return = -114.64144948525842
# Episode 557 finished after 61 timesteps. Return = -76.7539581622535
# Episode 558 finished after 67 timesteps. Return = -80.34497547101452
# Episode 559 finished after 91 timesteps. Return = -149.0842706606481
# Episode 560 finished after 111 timesteps. Return = -252.90915199504158
# Episode 561 finished after 62 timesteps. Return = -94.55026180220537
# Episode 562 finished after 108 timesteps. Return = -87.60855051252321
# Episode 563 finished after 101 timesteps. Return = -298.8207940530557
# Episode 564 finished after 58 timesteps. Return = -88.72525587794539
# Episode 565 finished after 77 timesteps. Return = -197.33096404200813
# Episode 566 finished after 75 timesteps. Return = -164.37943082815843
# Episode 567 finished after 100 timesteps. Return = -134.77652548621325
# Episode 568 finished after 85 timesteps. Return = -119.33835628042254
# Episode 569 finished after 82 timesteps. Return = -92.58257990584889
# Episode 570 finished after 111 timesteps. Return = -114.75378416494377
# Episode 571 finished after 113 timesteps. Return = -280.0843943987012
# Episode 572 finished after 106 timesteps. Return = -270.50680251890634
# Episode 573 finished after 74 timesteps. Return = -117.41315549717226
# Episode 574 finished after 60 timesteps. Return = -112.21360962993373
# Episode 575 finished after 75 timesteps. Return = -121.64980413497439
# Episode 576 finished after 115 timesteps. Return = -583.656179363559
# Episode 577 finished after 78 timesteps. Return = -172.76994568921043
# Episode 578 finished after 98 timesteps. Return = -104.77423174955926
# Episode 579 finished after 74 timesteps. Return = -85.90802172219311
# Episode 580 finished after 93 timesteps. Return = -132.95273358591797
# Episode 581 finished after 66 timesteps. Return = -65.95515329338497
# Episode 582 finished after 81 timesteps. Return = -120.14489949551114
# Episode 583 finished after 65 timesteps. Return = -150.59748545340963
# Episode 584 finished after 70 timesteps. Return = -104.25463254696766
# Episode 585 finished after 68 timesteps. Return = -151.41078078017273
# Episode 586 finished after 76 timesteps. Return = -79.65736007933229
# Episode 587 finished after 70 timesteps. Return = -121.95785466357192
# Episode 588 finished after 93 timesteps. Return = -57.253117080314425
# Episode 589 finished after 102 timesteps. Return = -165.17887579511148
# Episode 590 finished after 91 timesteps. Return = -98.71931740374234
# Episode 591 finished after 69 timesteps. Return = -54.60828121239956
# Episode 592 finished after 102 timesteps. Return = -130.4509409581679
# Episode 593 finished after 57 timesteps. Return = -94.29182580364944
# Episode 594 finished after 89 timesteps. Return = -466.75926591208804
# Episode 595 finished after 100 timesteps. Return = -401.9505159902255
# Episode 596 finished after 105 timesteps. Return = -110.0009535245478
# Episode 597 finished after 108 timesteps. Return = -79.23278846803477
# Episode 598 finished after 109 timesteps. Return = -96.22010446097974
# Episode 599 finished after 67 timesteps. Return = -102.55238896934152
# Episode 600 finished after 95 timesteps. Return = -232.44880558231955
# Episode 601 finished after 96 timesteps. Return = -141.83426657010892
# Episode 602 finished after 79 timesteps. Return = -166.260963860925
# Episode 603 finished after 123 timesteps. Return = -99.73035370989453
# Episode 604 finished after 86 timesteps. Return = -119.03453885281078
# Episode 605 finished after 100 timesteps. Return = -430.96878367104006
# Episode 606 finished after 118 timesteps. Return = -128.39241180004908
# Episode 607 finished after 118 timesteps. Return = -123.73096161082033
# Episode 608 finished after 70 timesteps. Return = -162.35547563096225
# Episode 609 finished after 76 timesteps. Return = -121.51020240853425
# Episode 610 finished after 58 timesteps. Return = -79.5355497486321
# Episode 611 finished after 100 timesteps. Return = -89.35180529573769
# Episode 612 finished after 71 timesteps. Return = -105.86536674196238
# Episode 613 finished after 93 timesteps. Return = -137.58898557934754
# Episode 614 finished after 117 timesteps. Return = -295.78111306688794
# Episode 615 finished after 129 timesteps. Return = -38.09932998099087
# Episode 616 finished after 59 timesteps. Return = -113.49122003147914
# Episode 617 finished after 61 timesteps. Return = -84.1089119019118
# Episode 618 finished after 103 timesteps. Return = -149.78601978475072
# Episode 619 finished after 87 timesteps. Return = -150.26134882322222
# Episode 620 finished after 70 timesteps. Return = -125.0574816864093
# Episode 621 finished after 89 timesteps. Return = -329.12215813131957
# Episode 622 finished after 69 timesteps. Return = -131.05557606333113
# Episode 623 finished after 108 timesteps. Return = -374.0857232336891
# Episode 624 finished after 62 timesteps. Return = -136.07094446863312
# Episode 625 finished after 85 timesteps. Return = -229.8166473392963
# Episode 626 finished after 63 timesteps. Return = -203.72197572743744
# Episode 627 finished after 70 timesteps. Return = -9.79512660028999
# Episode 628 finished after 72 timesteps. Return = -63.28011924915353
# Episode 629 finished after 80 timesteps. Return = 1.999553328578429
# Episode 630 finished after 100 timesteps. Return = -289.17890317156383
# Episode 631 finished after 109 timesteps. Return = -81.1648554912803
# Episode 632 finished after 100 timesteps. Return = -355.25219793058324
# Episode 633 finished after 91 timesteps. Return = -259.728748026756
# Episode 634 finished after 70 timesteps. Return = -89.09741492619983
# Episode 635 finished after 71 timesteps. Return = -103.09792510458787
# Episode 636 finished after 99 timesteps. Return = -106.16382330467626
# Episode 637 finished after 76 timesteps. Return = -73.5478186222987
# Episode 638 finished after 70 timesteps. Return = -98.67617191049067
# Episode 639 finished after 101 timesteps. Return = -156.1185374969565
# Episode 640 finished after 94 timesteps. Return = -99.90323229601496
# Episode 641 finished after 84 timesteps. Return = -53.90963522163676
# Episode 642 finished after 106 timesteps. Return = -102.56780957176875
# Episode 643 finished after 74 timesteps. Return = -169.75645336140155
# Episode 644 finished after 88 timesteps. Return = -185.3335517971429
# Episode 645 finished after 76 timesteps. Return = -165.1543704567331
# Episode 646 finished after 119 timesteps. Return = -91.5503106225233
# Episode 647 finished after 83 timesteps. Return = -150.86712230493166
# Episode 648 finished after 77 timesteps. Return = -156.7751188821407
# Episode 649 finished after 93 timesteps. Return = -216.4331904662887
# Episode 650 finished after 64 timesteps. Return = -233.59271205526167
# Episode 651 finished after 89 timesteps. Return = -228.12220614249142
# Episode 652 finished after 100 timesteps. Return = -185.45600648118116
# Episode 653 finished after 76 timesteps. Return = -143.29087653051056
# Episode 654 finished after 118 timesteps. Return = -102.72088375033732
# Episode 655 finished after 147 timesteps. Return = -174.84816168079723
# Episode 656 finished after 87 timesteps. Return = -210.20080940540765
# Episode 657 finished after 103 timesteps. Return = -247.27492503958965
# Episode 658 finished after 65 timesteps. Return = -173.65910815190708
# Episode 659 finished after 69 timesteps. Return = -136.58032105500303
# Episode 660 finished after 61 timesteps. Return = -48.947477507433305
# Episode 661 finished after 97 timesteps. Return = -320.6362398486302
# Episode 662 finished after 82 timesteps. Return = -94.23389179871761
# Episode 663 finished after 115 timesteps. Return = -143.3302872722158
# Episode 664 finished after 63 timesteps. Return = -110.19392325927913
# Episode 665 finished after 68 timesteps. Return = -85.69244688054835
# Episode 666 finished after 116 timesteps. Return = -153.5144789120214
# Episode 667 finished after 63 timesteps. Return = -151.16819752509815
# Episode 668 finished after 97 timesteps. Return = -153.6489234435823
# Episode 669 finished after 70 timesteps. Return = -216.57136255011068
# Episode 670 finished after 89 timesteps. Return = -230.23714542438123
# Episode 671 finished after 91 timesteps. Return = -108.8500666027875
# Episode 672 finished after 109 timesteps. Return = -72.42224080200043
# Episode 673 finished after 91 timesteps. Return = -136.2554695702854
# Episode 674 finished after 118 timesteps. Return = -167.20385159684906
# Episode 675 finished after 115 timesteps. Return = -65.06453236226798
# Episode 676 finished after 77 timesteps. Return = -260.83584903290205
# Episode 677 finished after 73 timesteps. Return = -90.80823382402546
# Episode 678 finished after 116 timesteps. Return = -264.9433112191274
# Episode 679 finished after 105 timesteps. Return = -295.4165909360689
# Episode 680 finished after 61 timesteps. Return = -78.22713416373867
# Episode 681 finished after 81 timesteps. Return = -124.71033353626613
# Episode 682 finished after 65 timesteps. Return = -119.78864509466386
# Episode 683 finished after 126 timesteps. Return = -137.4762175702202
# Episode 684 finished after 72 timesteps. Return = -147.1665676088614
# Episode 685 finished after 108 timesteps. Return = -238.02805448518367
# Episode 686 finished after 95 timesteps. Return = -179.80379062079757
# Episode 687 finished after 118 timesteps. Return = -328.9496778396891
# Episode 688 finished after 112 timesteps. Return = -256.13822284870764
# Episode 689 finished after 84 timesteps. Return = -134.4038103696604
# Episode 690 finished after 106 timesteps. Return = -146.0224542516924
# Episode 691 finished after 103 timesteps. Return = 20.567522717079854
# Episode 692 finished after 117 timesteps. Return = -140.8704280876396
# Episode 693 finished after 74 timesteps. Return = -138.32801244713252
# Episode 694 finished after 64 timesteps. Return = -85.98372011944923
# Episode 695 finished after 70 timesteps. Return = -119.7745618991196
# Episode 696 finished after 105 timesteps. Return = -125.88322948753842
# Episode 697 finished after 63 timesteps. Return = -65.76785415649269
# Episode 698 finished after 110 timesteps. Return = -147.00670711319947
# Episode 699 finished after 104 timesteps. Return = -274.9560401138996
# Episode 700 finished after 67 timesteps. Return = -90.42772884593091
# Episode 701 finished after 72 timesteps. Return = -94.0775978769957
# Episode 702 finished after 85 timesteps. Return = -158.05188432934
# Episode 703 finished after 71 timesteps. Return = -85.9637735936115
# Episode 704 finished after 104 timesteps. Return = -178.2980292973778
# Episode 705 finished after 73 timesteps. Return = -161.3321521508889
# Episode 706 finished after 107 timesteps. Return = -232.01898430909716
# Episode 707 finished after 70 timesteps. Return = -123.93729427029385
# Episode 708 finished after 114 timesteps. Return = -107.09503876634076
# Episode 709 finished after 81 timesteps. Return = -75.10308188039156
# Episode 710 finished after 105 timesteps. Return = -178.78463465992382
# Episode 711 finished after 70 timesteps. Return = -214.51536277480398
# Episode 712 finished after 77 timesteps. Return = -113.11209508823468
# Episode 713 finished after 113 timesteps. Return = -93.47284637642088
# Episode 714 finished after 81 timesteps. Return = -113.26893821200399
# Episode 715 finished after 109 timesteps. Return = -224.50436700236065
# Episode 716 finished after 108 timesteps. Return = -181.19903932844028
# Episode 717 finished after 114 timesteps. Return = -175.96210050379176
# Episode 718 finished after 92 timesteps. Return = -154.32658133161178
# Episode 719 finished after 61 timesteps. Return = -134.6506492726793
# Episode 720 finished after 83 timesteps. Return = -121.2415007786108
# Episode 721 finished after 113 timesteps. Return = -271.43051767901477
# Episode 722 finished after 92 timesteps. Return = -331.38020059134067
# Episode 723 finished after 76 timesteps. Return = -119.86164069329323
# Episode 724 finished after 91 timesteps. Return = -109.37847962493554
# Episode 725 finished after 74 timesteps. Return = -123.25976785370644
# Episode 726 finished after 90 timesteps. Return = -133.5650748129621
# Episode 727 finished after 67 timesteps. Return = -76.13431429652661
# Episode 728 finished after 68 timesteps. Return = -105.7724757322894
# Episode 729 finished after 115 timesteps. Return = -312.06143000575463
# Episode 730 finished after 92 timesteps. Return = -310.6141622223864
# Episode 731 finished after 126 timesteps. Return = -176.54705518273482
# Episode 732 finished after 135 timesteps. Return = -135.90895905514574
# Episode 733 finished after 59 timesteps. Return = -102.48602517514117
# Episode 734 finished after 102 timesteps. Return = -98.41114041780313
# Episode 735 finished after 123 timesteps. Return = -146.71416213846996
# Episode 736 finished after 159 timesteps. Return = -255.22746818220452
# Episode 737 finished after 72 timesteps. Return = -223.23488587713106
# Episode 738 finished after 61 timesteps. Return = -63.34023322960491
# ...
# Episode 10344 finished after 107 timesteps. Return = -149.31891424307548
# Episode 10345 finished after 82 timesteps. Return = -231.3517291713811
# Episode 10346 finished after 90 timesteps. Return = -287.01101145691257
# Episode 10347 finished after 109 timesteps. Return = -112.37647843463206
# Episode 10348 finished after 77 timesteps. Return = -240.16742846816632
# Episode 10349 finished after 95 timesteps. Return = -102.49180991078919
# Episode 10350 finished after 116 timesteps. Return = -258.74071867170454
# Episode 10351 finished after 65 timesteps. Return = -102.17726880098013
# Episode 10352 finished after 100 timesteps. Return = -186.94323922852877
# Episode 10353 finished after 85 timesteps. Return = -147.42958562478134
# Episode 10354 finished after 89 timesteps. Return = -238.5441499941689
# Episode 10355 finished after 115 timesteps. Return = -82.55645240239646
# Episode 10356 finished after 85 timesteps. Return = -118.34607917644509
# Episode 10357 finished after 121 timesteps. Return = -298.4669829682066
# Episode 10358 finished after 117 timesteps. Return = -171.56848817518733
# Episode 10359 finished after 70 timesteps. Return = -8.675782918049592
# Episode 10360 finished after 63 timesteps. Return = -89.69995930712406
# Episode 10361 finished after 127 timesteps. Return = -240.54487060018073
# Episode 10362 finished after 118 timesteps. Return = -183.7883344639995
# Episode 10363 finished after 66 timesteps. Return = -86.14476684018796
# Episode 10364 finished after 85 timesteps. Return = -204.24831139582346
# Episode 10365 finished after 58 timesteps. Return = -112.52949135114532
# Episode 10516 finished after 107 timesteps. Return = -157.85977173483252
# Episode 10517 finished after 109 timesteps. Return = -257.35626312492485
# Episode 10518 finished after 105 timesteps. Return = -141.0079672767202
# Episode 10519 finished after 101 timesteps. Return = -141.3437528559973
# Episode 10520 finished after 104 timesteps. Return = -137.7383336996806
# Episode 10521 finished after 133 timesteps. Return = -340.2242535212547
# Episode 10522 finished after 131 timesteps. Return = -284.79322395139525
# Episode 10523 finished after 81 timesteps. Return = -231.65478853138498
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-09e84f0a654e> in <module>
#       3 for i in range(n_iters):
#       4     replay_buffer = collect_experience(stochastic_policy, replay_buffer, replay_size, last_few, n_episodes_per_iter, command_scale, log_to_tensorboard)
# ----> 5     train_net(agent, replay_buffer, n_updates_per_iter, batch_size, command_scale)
#
# <ipython-input-55-ef54ac1fda18> in train_net(policy_net, replay_buffer, n_updates, batch_size, command_scale)
#     127         batch_input = torch.tensor(batch_input).double()
#     128         batch_label = torch.tensor(batch_label).long()
# --> 129         pred = policy_net(batch_input)
#     130         cost = F.cross_entropy(pred, batch_label)
#     131         if log_to_tensorboard: writer.add_scalar('Cost/NN update', cost.item() , i_updates)    # write loss to a graph
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-55-ef54ac1fda18> in forward(self, x)
#      49
#      50     def forward(self, x):
# ---> 51         x = self.fc(x)
#      52         return x
#      53
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/.local/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
#Visualise final trained agent
visualise_agent(greedy_policy, command=[400, 400], command_scale=command_scale, n=3)
# Out:
# Episode 0 finished after 125 timesteps. Return = 125.0
